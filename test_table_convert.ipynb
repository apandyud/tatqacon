# %%
# %load_ext autoreload
# %autoreload 2
import table_convert    
import pandas as pd

# %%
devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')

# %%
from tqdm.notebook import tqdm as log_progress

res = []
for i, item in log_progress(devdf.iterrows()):
    print(item['table']['uid'])
    table = item['table']['table']
    try:
        value_list = table_convert.convert_multitable(table)
        #print(len(table), len(table[0]), len(value_list))
    except Exception as e:
        s = '[Error]'+ str(e)
        print(s)
# Out:
# 0it [00:00, ?it/s]
# 3ffd9053-a45d-491c-957a-1b2fa0af0570
# 53474060-2736-46cb-bd97-1eb42f0ff3c1
# 52164b70-6973-4844-af6a-76e8f1298d64
# 6bf238a5-0a3e-492d-91f8-7f62d3b37fba
# f8ac9ddd-9872-4681-902d-a0ee7c0ee83a
# e9a946ce-72a9-4b42-86d6-4d91fceb14db
# 789efd09-04a2-45c7-84e5-47d3543695d1
# 403df8e0-6045-4dba-90b3-5c9d8ca55bfb
# 77d8e381-01d0-4cf9-882e-e1162db2cff2
# 644a6917-7add-4751-9e3b-bcc2150a8f49
# cc4f089d-e7bf-4b00-a096-48a3eed39f86
# 22f634eb-a76a-424d-b8d3-3994dab52826
# 1c9e6c58-fd11-4711-986e-1d86b626d1dd
# 8749fc7b-19fb-4014-8eed-f96a05da50cf
# 32edf644-acb0-4260-9392-f0baa4253f5a
# 386352cf-f7e3-4148-920c-63bc57cf156b
# [Error]list index out of range
# 285a1ced-709e-4f45-a227-b6cd04e725f9
# c3d2669c-a641-4c28-80d3-bda1c847027c
# 5127ef77-7d11-4b1c-93f8-1818f39070a8
# b3f4d2dd-a59b-45da-9608-e3401041a2b1
# 0f012382-d9ba-409c-94db-0b9bf50d0746
# 13bb283b-4b9c-42b9-9b02-f1b2e1a87abf
# 8692f92d-668a-452d-be7a-2b491ee27585
# 2061da6a-894b-4eaa-9a35-e784fee8ba4f
# 4232c6c1-97cf-48ad-8b8b-f956871a3212
# 5edfd497-7fc1-467c-a68e-825584370718
# ba26cd64-e448-4ffb-bfaa-c6ad4760fba7
# 54719676-874d-439c-a095-b0776e1de331
# 00a5764e-8bb7-48f1-a4cb-bea0edf188b1
# b05fde22-386f-442b-a606-0ef9db39ff51
# 68bafc82-b795-4c7b-9506-e901223c3526
# bcbd7783-86ad-430d-aa96-48808bb0426c
# 4145912c-86dc-434b-8990-1cfe78f298f5
# 82dca6c3-9259-4be6-9c9f-fc74aa6c81f7
# a9ddf64a-2806-4476-b341-05d7d06fdcf6
# 361835e5-b8ba-49c5-9ebb-ce0aa5eca2bf
# a3aadeea-1c1a-4449-9244-d5e8e1d7f277
# 8ba4089b-a3d7-403b-860a-40a9cbdf3d8c
# 75c4ce3e-859b-4c3c-8443-6b8b3a70724f
# e8a14965-257d-4945-9f13-d0e2e84d9ff8
# d873a0cf-2e57-46f3-b9a5-2596808ffa00
# d7d65228-96c1-4890-951c-c3d7578f8031
# 9989ca79-5332-47be-a08e-85f2648cdde7
# 5e72a0cd-a892-4d3e-bfa8-403c33aaf40f
# 9b0abd12-8d9e-48ba-9ac2-baacfa92e7eb
# 5f71e969-c63e-4b46-ad47-5fce09490ab6
# 69d42a72-0262-4962-94aa-a7c456f6b9d5
# 02913daf-213d-46e7-bf29-a65a8e64550f
# a65ebf76-856b-4336-850b-f5c619115783
# fdc2dbb8-0066-473e-95c1-43eb17223093
# e614befa-40ae-43c0-93b1-385899b6b181
# 98db5a3a-5b9e-4f91-aea4-bdc2672f1661
# 483ae181-20b3-49f4-9d7b-6d75e8356250
# a98c60cd-3990-47d0-9d30-351743be74c7
# 861ad987-4b1b-40e0-bef3-1fbd25a33c6b
# 708fa58a-083d-4a97-80a1-5fe9de71a36b
# 03ef04b2-1710-4176-81b9-350134a9b49f
# 3b51990b-6604-4af1-947a-98e6a499ad58
# d8d662b8-dbd2-4450-a1fd-7cf111b4236a
# a9357df7-2d20-4f8e-afb5-944d75e60f9b
# 21a432eb-166c-4178-adf9-08b6ad3fde7d
# a10e0909-77e4-40ba-bc71-94413b04e8ac
# 2a704bb9-4bd3-4071-b8e6-212957b04ada
# 687d09ee-4aa8-402a-ae27-96ce063115a5
# eb122e2e-12b4-4e59-a018-7045192b021d
# 1aef0c1f-6ded-4d8e-bb9c-4c0fe62e9ab6
# a8559ad7-3e4c-41c5-a3de-d2927413484c
# 5ce66c1d-89ff-48d1-8689-ec08918dc634
# 0e8b88af-9af5-4bfd-865f-ca0dd3f85939
# d9fd4f62-fd62-4254-a96d-70d23f08fc61
# 62d958c0-fb12-4683-b503-e5c01da9aea6
# 2962bec4-7159-4b72-ba5e-07cd553d0186
# bee68d71-44ca-4177-a1c7-8c127f6f9203
# 981e181b-57fa-42ff-a2d9-b8603eafdd4c
# 7a9fdd23-2adc-4cf5-8761-5c7fbec53e6e
# 8db2d2a5-fdcd-45c2-be2f-813cba4fbca7

# %%
table = None
devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')

tid = 'ba6783f3-8207-419a-b407-3f688682caef'
qid = 'ba6783f3-8207-419a-b407-3f688682caef'
#qid = 'a0414f81-8dc2-44b2-a441-2c9d9c805c4d'
#qid = '6100c476-160a-4f1e-bfc1-a16f4cc18b52'
qid = 'ef274d2b-fbd6-4e9f-95f9-79b37827d91c'
#qid = '65ec782c-691e-45df-b541-caecb85154ff'
#qid = '94916f79-4b6d-487f-8fa2-39f81a085760'
#qid = '72325ec6-41ad-4648-9798-b22a61122cb4'
qid = '35d602ae-9131-4291-a30c-49a40f32bbe4'
for i, item in devdf.iterrows():
    if  item['table']['uid'] == tid:
        table = item['table']['table']
    for q in item['questions']:        
        if q['uid'] == qid:
            table = item['table']['table']
            
[print(r) for r in table]

#table_convert.convert_multitable(table_convert.split_multitables(table)[0])
#table_convert.fill_table_headers_v2(table_convert.split_multitables(table)[0])
#table_convert.split_multitables(table)

#table_convert.detect_header_rows_v2(table)
table_convert.convert_multitable(table)
# Out:
# ['', 'December 31,', '']
# ['', '2019', '2018']
# ['Trade accounts receivable, net, noncurrent (Note 2)', '$26,496', '$15,948']
# ['Equity method investments (Note 1)', '9,254', '9,702']
# ['Net deferred tax assets, noncurrent (Note 20)', '6,774', '5,797']
# ['Rent and other deposits', '6,106', '5,687']
# ['Value added tax receivables, net, noncurrent', '592', '519']
# ['Other', '6,723', '5,711']
# ['', '$55,945', '$43,364']
# [{'number_value': 26496.0,
#   'scale': '',
#   'category': 'Trade accounts receivable, net, noncurrent (Note 2)',
#   'header1': '2019',
#   'header2': 'December 31,'},
#  {'number_value': 15948.0,
#   'scale': '',
#   'category': 'Trade accounts receivable, net, noncurrent (Note 2)',
#   'header1': '2018',
#   'header2': 'December 31,'},
#  {'number_value': 9254.0,
#   'scale': '',
#   'category': 'Equity method investments (Note 1)',
#   'header1': '2019',
#   'header2': 'December 31,'},
#  {'number_value': 9702.0,
#   'scale': '',
#   'category': 'Equity method investments (Note 1)',
#   'header1': '2018',
#   'header2': 'December 31,'},
#  {'number_value': 6774.0,
#   'scale': '',
#   'category': 'Net deferred tax assets, noncurrent (Note 20)',
#   'header1': '2019',
#   'header2': 'December 31,'},
#  {'number_value': 5797.0,
#   'scale': '',
#   'category': 'Net deferred tax assets, noncurrent (Note 20)',
#   'header1': '2018',
#   'header2': 'December 31,'},
#  {'number_value': 6106.0,
#   'scale': '',
#   'category': 'Rent and other deposits',
#   'header1': '2019',
#   'header2': 'December 31,'},
#  {'number_value': 5687.0,
#   'scale': '',
#   'category': 'Rent and other deposits',
#   'header1': '2018',
#   'header2': 'December 31,'},
#  {'number_value': 592.0,
#   'scale': '',
#   'category': 'Value added tax receivables, net, noncurrent',
#   'header1': '2019',
#   'header2': 'December 31,'},
#  {'number_value': 519.0,
#   'scale': '',
#   'category': 'Value added tax receivables, net, noncurrent',
#   'header1': '2018',
#   'header2': 'December 31,'},
#  {'number_value': 6723.0,
#   'scale': '',
#   'category': 'Other',
#   'header1': '2019',
#   'header2': 'December 31,'},
#  {'number_value': 5711.0,
#   'scale': '',
#   'category': 'Other',
#   'header1': '2018',
#   'header2': 'December 31,'},
#  {'number_value': 55945.0,
#   'scale': '',
#   'category': '',
#   'header1': '2019',
#   'header2': 'December 31,'},
#  {'number_value': 43364.0,
#   'scale': '',
#   'category': '',
#   'header1': '2018',
#   'header2': 'December 31,'}]

# %%
table = None
devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')
ec = 0
for i, item in devdf.iterrows():
    table = item['table']['table']
    #[print(''.join( categorize_items(r)), base_categorize_row(r), r )for r in table]
    try:
        [base_categorize_row(r) for r in table]
    except Exception as e:
        ec = ec + 1
        print(item['table']['uid'])
        s = '[Error]'+ str(e)
        print(s)

#[print(''.join( categorize_items(r)), base_categorize_row(r), r )for r in table]
ec
# Out:
# 0

# %%
re.fullmatch('^S+N+$', 'SSNN')
# Out:
# <re.Match object; span=(0, 4), match='SSNN'>

# %%
pd.DataFrame(table)
# Out:
#                                                  0     1        2        3
# 0                                                            2019     2018
# 1                                                   Note       £m       £m
# 2                                     Fixed assets
# 3                                      Investments     3  1,216.0  1,212.9
# 4                                                         1,216.0  1,212.9
# 5                                   Current assets
# 6                                          Debtors     4    415.9    440.7
# 7                        Cash and cash equivalents     5        –      0.2
# 8                                                           415.9    440.9
# 9   Creditors: amounts falling due within one year     6  (411.4)  (288.4)
# 10                              Net current assets            4.5    152.5
# 11                                      Net assets        1,220.5  1,365.4
# 12                            Capital and reserves
# 13                         Called-up share capital     9      9.3      9.5
# 14                                 Own shares held    10   (16.5)   (16.9)
# 15                      Capital redemption reserve            0.7      0.5
# 16                               Retained earnings        1,227.0  1,372.3
# 17                                    Total equity        1,220.5  1,365.4

# %%
def detect_numbers(row):
    res = ''
    for item in row:
        if item.trim()  = ''
            res.append('S')
            continue
        if item.trim()  = '-'
            res.append('U')
            continue
            
        r = table_convert.extract_number(item)
        if r == None:
            res.append('O')
        else:
            res.append('N')
    return res

# %%
def extract_data_general(tables):
    results = []

    for table in tables:
        headers = table[0]
        context_stack = []

        for row in table[1:]:
            # Use the first cell of the row as a label if it's not empty
            label = row[0].strip()
            if label:
                context_stack = [label]

            # Iterate through the row's values (skipping the first label cell)
            for i in range(1, len(row)):
                value = row[i].strip()
                if value and value != '—':
                    # Clean and convert the value
                    numeric_value = float(value.replace('$', '').replace(',', '').replace('(', '-').replace(')', ''))

                    # Gather contextual information
                    info = context_stack + [headers[i]]

                    results.append({
                        "value": numeric_value,
                        "info": [item for item in info if item]  # Exclude empty strings
                    })

    return results

# %%
table = None
devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')

tid = 'ba6783f3-8207-419a-b407-3f688682caef'
#qid = 'ba6783f3-8207-419a-b407-3f688682caef'
#qid = 'a0414f81-8dc2-44b2-a441-2c9d9c805c4d'
#qid = '6100c476-160a-4f1e-bfc1-a16f4cc18b52'
#qid = 'ef274d2b-fbd6-4e9f-95f9-79b37827d91c'
#qid = '65ec782c-691e-45df-b541-caecb85154ff'
qid = '94916f79-4b6d-487f-8fa2-39f81a085760'
#qid = '72325ec6-41ad-4648-9798-b22a61122cb4'
#qid = '35d602ae-9131-4291-a30c-49a40f32bbe4'
for i, item in devdf.iterrows():
    if  item['table']['uid'] == tid:
        table = item['table']['table']
    for q in item['questions']:        
        if q['uid'] == qid:
            table = item['table']['table']
            
extract_data_general([table])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[209], line 20
#      17         if q['uid'] == qid:
#      18             table = item['table']['table']
# ---> 20 extract_data_general([table])
#
# Cell In[206], line 19, in extract_data_general(tables)
#      16 value = row[i].strip()
#      17 if value and value != '—':
#      18     # Clean and convert the value
# ---> 19     numeric_value = float(value.replace('$', '').replace(',', '').replace('(', '-').replace(')', ''))
#      21     # Gather contextual information
#      22     info = context_stack + [headers[i]]
#
# ValueError: could not convert string to float: 'Note'
