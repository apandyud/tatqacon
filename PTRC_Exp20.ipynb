# %%
import tatqa_utils
import pandas as pd

# %%
devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')

# %%
import pandas as pd
import pyreadstat
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
import utils
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
import numpy as np
from progress.bar import Bar
# %load_ext autoreload
# %autoreload 2

# %%
import os
with open('dataset_raw/openai.api.key', 'r') as filek: 
    openai_key = filek.read()
os.environ["OPENAI_API_KEY"] =  openai_key

# %%
from langchain.globals import set_llm_cache
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAI
from langchain_community.cache import SQLiteCache

llm = ChatOpenAI(temperature=0)
#llm = OpenAI(temperature=0) 
set_llm_cache(SQLiteCache(database_path=".langchain.db"))

# %%
import re 
def remove_thousand_separators(text):
    # This regular expression matches numbers with commas as thousand separators
    return re.sub(r'(?<=\d),(?=\d{3})', '', text)
    
def transform_elements(list_of_lists, transform_func):    
    return [
        [transform_func(item) for item in sublist]
        for sublist in list_of_lists
    ]
    
def replace_bracketed_numbers(text):
    return re.sub(r"\((\d+)\)", lambda x: f"-{x.group(1)}", text)

# %%
def gen_code(llm, question, table):    
    prompt = f"Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: {question} \n Table: {table}"
    prompt = remove_thousand_separators(prompt)
    #prompt = replace_bracketed_numbers(prompt)
    prompt = prompt.replace('$','') 
    res = llm.invoke(prompt)
    code = res.content.replace('```python','').replace('```','')
    return (prompt, code)

def exec_code(code, table):  
    table = remove_thousand_separators(f"{table}")
    #table = replace_bracketed_numbers(table)
    table = table.replace('$','')
    #code = code.replace("* 1000000","").replace("*1000000","").replace("/ 1000000","").replace("/1000000","").replace("/ 1000","").replace("/1000","")
    #code = code.replace('abs(','(')
    try: 
        loc = locals()   
        if not "run()" in code:
            exec(code + f"\nr = run({table})\n", globals(), loc)
        else: 
            exec(code + "\nr = run()\n", globals(), loc)
        return loc['r']
    except Exception as e:
            s = '[Error]'+ str(e)
            print(s)
            return (s,'')
#table = "[['', '', 'Years Ended September 30,', ''], ['', '2019', '2018', '2017'], ['Fixed Price', '$  1,452.4', '$  1,146.2', '$  1,036.9'], ['Other', '44.1', '56.7', '70.8'], ['Total sales', '$1,496.5', '$1,202.9', '$1,107.7']]"
#question = 'What is the change in Fixed Price in 2019 from 2018?'
table = "[['', 'December 31,', ''], ['', '2019', '2018'], ['Trade accounts receivable, net, noncurrent (Note 2)', '$26,496', '$15,948'], ['Equity method investments (Note 1)', '9,254', '9,702'], ['Net deferred tax assets, noncurrent (Note 20)', '6,774', '5,797'], ['Rent and other deposits', '6,106', '5,687'], ['Value added tax receivables, net, noncurrent', '592', '519'], ['Other', '6,723', '5,711'], ['', '$55,945', '$43,364']]"
#table = remove_thousand_separators(table)
print(table)
question = 'What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018?'
( prompt, code) = gen_code(llm, question, table)
res = exec_code(code, table)
print(code, res)
# Out:
# [['', 'December 31,', ''], ['', '2019', '2018'], ['Trade accounts receivable, net, noncurrent (Note 2)', '$26,496', '$15,948'], ['Equity method investments (Note 1)', '9,254', '9,702'], ['Net deferred tax assets, noncurrent (Note 20)', '6,774', '5,797'], ['Rent and other deposits', '6,106', '5,687'], ['Value added tax receivables, net, noncurrent', '592', '519'], ['Other', '6,723', '5,711'], ['', '$55,945', '$43,364']]
# def run():
#     current_year = 2019
#     previous_year = 2018
#     current_value = 592
#     previous_value = 519
#
#     percentage_change = ((current_value - previous_value) / previous_value) * 100
#
#     return round(percentage_change, 2), 'percent' (14.07, 'percent')

# %%
from tqdm.notebook import tqdm as log_progress

res = []
for i, item in log_progress(devdf.iterrows()):
    table = item['table']['table']
    #table = transform_elements(table, remove_thousand_separators)
    #table = [remove_thousand_separators(cell) for row in table for cell in row]
    #table = [cell.replace('$', '') for row in table for cell in row]
    #print (table)
    for q in item['questions']:        
        if q['answer_type'] == 'arithmetic' and 'table' in q['answer_from']:             
            ( prompt, code)  = gen_code(llm, q['question'], table)
            r = exec_code(code, table)
            err =  None
            if r is None:
                (pred_value, pred_unit) = ("", "")
            else:                
                if len(r) == 2:
                    (pred_value, pred_scale) = r    
                    if isinstance(pred_value, tuple) and len(pred_value) == 2:
                        print('$$$$')
                        (pred_value, pred_scale) = pred_value 
                    
                    if pred_unit == "%" or pred_unit == "percentage"  :
                        pred_unit = 'percent'
                    if pred_unit not in ["", 'thousand', 'million', 'billion', 'percent']:
                        print('Invalid ', pred_unit)
                        pred_unit = ""    
                    if isinstance(pred_value, str):
                        print("string")
                        if  pred_value.startswith('[Error]'):
                            (pred_value, pred_unit) = ("", "")
                            err,_ = r                                                        
                        
                elif len(r) == 1:
                    (pred_value, pred_unit) = (r, "")        
                else:
                    (pred_value, pred_unit) = ("", "")        
                
            #res.append({"table":table, "q":q, "pred":pred, "code": code})
            res.append(({"answer_type":q["answer_type"], "answer": q["answer"], 'scale': q["scale"]}, pred_value, pred_unit, q, code, prompt, item['table'], err))
# Out:
# 0it [00:00, ?it/s]
# (87.31, 'percent')
# (3680.0, 'million')
# (1.9000000000000001, '')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 12
#      10 for q in item['questions']:
#      11     if q['answer_type'] == 'arithmetic' and 'table' in q['answer_from']:
# ---> 12         ( prompt, code)  = gen_code(llm, q['question'], table)
#      13         r = exec_code(code, table)
#      14         err =  None
#
# Cell In[31], line 6, in gen_code(llm, question, table)
#       4 #prompt = replace_bracketed_numbers(prompt)
#       5 prompt = prompt.replace('$','')
# ----> 6 res = llm.invoke(prompt)
#       7 code = res.content.replace('```python','').replace('```','')
#       8 return (prompt, code)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:683, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     681     generation_info = {"headers": dict(raw_response.headers)}
#     682 else:
# --> 683     response = self.client.create(**payload)
#     684 return self._create_chat_result(response, generation_info)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/openai/_utils/_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/openai/resources/chat/completions.py:742, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     704 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     705 def create(
#     706     self,
#    (...)
#     739     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     740 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     741     validate_response_format(response_format)
# --> 742     return self._post(
#     743         "/chat/completions",
#     744         body=maybe_transform(
#     745             {
#     746                 "messages": messages,
#     747                 "model": model,
#     748                 "frequency_penalty": frequency_penalty,
#     749                 "function_call": function_call,
#     750                 "functions": functions,
#     751                 "logit_bias": logit_bias,
#     752                 "logprobs": logprobs,
#     753                 "max_completion_tokens": max_completion_tokens,
#     754                 "max_tokens": max_tokens,
#     755                 "metadata": metadata,
#     756                 "n": n,
#     757                 "parallel_tool_calls": parallel_tool_calls,
#     758                 "presence_penalty": presence_penalty,
#     759                 "response_format": response_format,
#     760                 "seed": seed,
#     761                 "service_tier": service_tier,
#     762                 "stop": stop,
#     763                 "store": store,
#     764                 "stream": stream,
#     765                 "stream_options": stream_options,
#     766                 "temperature": temperature,
#     767                 "tool_choice": tool_choice,
#     768                 "tools": tools,
#     769                 "top_logprobs": top_logprobs,
#     770                 "top_p": top_p,
#     771                 "user": user,
#     772             },
#     773             completion_create_params.CompletionCreateParams,
#     774         ),
#     775         options=make_request_options(
#     776             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     777         ),
#     778         cast_to=ChatCompletion,
#     779         stream=stream or False,
#     780         stream_cls=Stream[ChatCompletionChunk],
#     781     )
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/openai/_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/openai/_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/openai/_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     987 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#     996     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
res
# Out:
# [({'answer_type': 'arithmetic', 'answer': -12.6, 'scale': 'million'},
#   -12.6,
#   '',
#   {'uid': 'eb787966-fa02-401f-bfaf-ccabf3828b23',
#    'order': 5,
#    'question': 'What is the change in Other in 2019 from 2018?',
#    'answer': -12.6,
#    'derivation': '44.1-56.7',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['2'],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    other_2019 = float(table[3][1])\n    other_2018 = float(table[3][2])\n    \n    change = other_2019 - other_2018\n    \n    if abs(change) >= 1000000:\n        return (round(change/1000000, 2), 'million')\n    elif abs(change) >= 1000:\n        return (round(change/1000, 2), 'thousand')\n    else:\n        return (round(change, 2), '')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the change in Other in 2019 from 2018? \n Table: [['', '', 'Years Ended September 30,', ''], ['', '2019', '2018', '2017'], ['Fixed Price', '  1452.4', '  1146.2', '  1036.9'], ['Other', '44.1', '56.7', '70.8'], ['Total sales', '1496.5', '1202.9', '1107.7']]",
#   {'uid': '3ffd9053-a45d-491c-957a-1b2fa0af0570',
#    'table': [['', '', 'Years Ended September 30,', ''],
#     ['', '2019', '2018', '2017'],
#     ['Fixed Price', '$  1,452.4', '$  1,146.2', '$  1,036.9'],
#     ['Other', '44.1', '56.7', '70.8'],
#     ['Total sales', '$1,496.5', '$1,202.9', '$1,107.7']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -22.22, 'scale': 'percent'},
#   -22.22,
#   '',
#   {'uid': '05b670d3-5b19-438c-873f-9bf6de29c69e',
#    'order': 6,
#    'question': 'What is the percentage change in Other in 2019 from 2018?',
#    'answer': -22.22,
#    'derivation': '(44.1-56.7)/56.7',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['2'],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    other_2019 = float(table[3][1])\n    other_2018 = float(table[3][2])\n    \n    percentage_change = ((other_2019 - other_2018) / other_2018) * 100\n    \n    return round(percentage_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the percentage change in Other in 2019 from 2018? \n Table: [['', '', 'Years Ended September 30,', ''], ['', '2019', '2018', '2017'], ['Fixed Price', '  1452.4', '  1146.2', '  1036.9'], ['Other', '44.1', '56.7', '70.8'], ['Total sales', '1496.5', '1202.9', '1107.7']]",
#   {'uid': '3ffd9053-a45d-491c-957a-1b2fa0af0570',
#    'table': [['', '', 'Years Ended September 30,', ''],
#     ['', '2019', '2018', '2017'],
#     ['Fixed Price', '$  1,452.4', '$  1,146.2', '$  1,036.9'],
#     ['Other', '44.1', '56.7', '70.8'],
#     ['Total sales', '$1,496.5', '$1,202.9', '$1,107.7']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -94, 'scale': 'million'},
#   -0.09,
#   '',
#   {'uid': 'b2786c1a-37de-4120-b03c-32bf5c81f157',
#    'order': 5,
#    'question': 'What was the change in the amount for Appliances in 2019 from 2018?',
#    'answer': -94,
#    'derivation': '680-774',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    appliances_2019 = 680\n    appliances_2018 = 774\n    \n    change = (appliances_2019 - appliances_2018) / 1000\n    \n    return (round(change, 2), 'thousand')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What was the change in the amount for Appliances in 2019 from 2018? \n Table: [['', '', 'Fiscal', ''], ['', '2019', '2018', '2017'], ['', '', '(in millions)', ''], ['Transportation Solutions:', '', '', ''], ['Automotive', ' 5686', ' 6092', '  5228'], ['Commercial transportation', '1221', '1280', '997'], ['Sensors', '914', '918', '814'], ['Total Transportation Solutions', '7821', '8290', '7039'], ['Industrial Solutions:', '', '', ''], ['Industrial equipment', '1949', '1987', '1747'], ['Aerospace, defense, oil, and gas', '1306', '1157', '1075'], ['Energy', '699', '712', '685'], ['Total Industrial Solutions', '3954', '3856', '3507'], ['Communications Solutions:', '', '', ''], ['Data and devices', '993', '1068', '963'], ['Appliances', '680', '774', '676'], ['Total Communications Solutions', '1673', '1842', '1639'], ['Total', ' 13448', ' 13988', ' 12185']]",
#   {'uid': '53474060-2736-46cb-bd97-1eb42f0ff3c1',
#    'table': [['', '', 'Fiscal', ''],
#     ['', '2019', '2018', '2017'],
#     ['', '', '(in millions)', ''],
#     ['Transportation Solutions:', '', '', ''],
#     ['Automotive', '$ 5,686', '$ 6,092', '$  5,228'],
#     ['Commercial transportation', '1,221', '1,280', '997'],
#     ['Sensors', '914', '918', '814'],
#     ['Total Transportation Solutions', '7,821', '8,290', '7,039'],
#     ['Industrial Solutions:', '', '', ''],
#     ['Industrial equipment', '1,949', '1,987', '1,747'],
#     ['Aerospace, defense, oil, and gas', '1,306', '1,157', '1,075'],
#     ['Energy', '699', '712', '685'],
#     ['Total Industrial Solutions', '3,954', '3,856', '3,507'],
#     ['Communications Solutions:', '', '', ''],
#     ['Data and devices', '993', '1,068', '963'],
#     ['Appliances', '680', '774', '676'],
#     ['Total Communications Solutions', '1,673', '1,842', '1,639'],
#     ['Total', '$ 13,448', '$ 13,988', '$ 12,185']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -12.14, 'scale': 'percent'},
#   -12.14,
#   '',
#   {'uid': 'fe11f001-3bfe-4089-8108-412676f0a780',
#    'order': 6,
#    'question': 'What was the percentage change in the amount for Appliances in 2019 from 2018?',
#    'answer': -12.14,
#    'derivation': '(680-774)/774',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    amount_2018 = 774\n    amount_2019 = 680\n    \n    percentage_change = ((amount_2019 - amount_2018) / amount_2018) * 100\n    \n    return round(percentage_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What was the percentage change in the amount for Appliances in 2019 from 2018? \n Table: [['', '', 'Fiscal', ''], ['', '2019', '2018', '2017'], ['', '', '(in millions)', ''], ['Transportation Solutions:', '', '', ''], ['Automotive', ' 5686', ' 6092', '  5228'], ['Commercial transportation', '1221', '1280', '997'], ['Sensors', '914', '918', '814'], ['Total Transportation Solutions', '7821', '8290', '7039'], ['Industrial Solutions:', '', '', ''], ['Industrial equipment', '1949', '1987', '1747'], ['Aerospace, defense, oil, and gas', '1306', '1157', '1075'], ['Energy', '699', '712', '685'], ['Total Industrial Solutions', '3954', '3856', '3507'], ['Communications Solutions:', '', '', ''], ['Data and devices', '993', '1068', '963'], ['Appliances', '680', '774', '676'], ['Total Communications Solutions', '1673', '1842', '1639'], ['Total', ' 13448', ' 13988', ' 12185']]",
#   {'uid': '53474060-2736-46cb-bd97-1eb42f0ff3c1',
#    'table': [['', '', 'Fiscal', ''],
#     ['', '2019', '2018', '2017'],
#     ['', '', '(in millions)', ''],
#     ['Transportation Solutions:', '', '', ''],
#     ['Automotive', '$ 5,686', '$ 6,092', '$  5,228'],
#     ['Commercial transportation', '1,221', '1,280', '997'],
#     ['Sensors', '914', '918', '814'],
#     ['Total Transportation Solutions', '7,821', '8,290', '7,039'],
#     ['Industrial Solutions:', '', '', ''],
#     ['Industrial equipment', '1,949', '1,987', '1,747'],
#     ['Aerospace, defense, oil, and gas', '1,306', '1,157', '1,075'],
#     ['Energy', '699', '712', '685'],
#     ['Total Industrial Solutions', '3,954', '3,856', '3,507'],
#     ['Communications Solutions:', '', '', ''],
#     ['Data and devices', '993', '1,068', '963'],
#     ['Appliances', '680', '774', '676'],
#     ['Total Communications Solutions', '1,673', '1,842', '1,639'],
#     ['Total', '$ 13,448', '$ 13,988', '$ 12,185']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 2.1, 'scale': 'percent'},
#   2.1,
#   '',
#   {'uid': '5103aed0-b4e8-4fae-bf78-e2c9f4ba84cf',
#    'order': 4,
#    'question': 'What is the difference between the domestic and international discount rates as at September 30, 2019?',
#    'answer': 2.1,
#    'derivation': '4.00 - 1.90 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    domestic_discount_rate = 4.00\n    international_discount_rate = 1.90\n    difference = abs(domestic_discount_rate - international_discount_rate)\n    return round(difference, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the difference between the domestic and international discount rates as at September 30, 2019? \n Table: [['', 'Domestic', '', 'International', ''], ['', 'September 30,', '', 'September 30,', ''], ['', '2019', '2018', '2019', '2018'], ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'], ['Expected return on plan assets', '', '', '3.40%', '3.70%'], ['Rate of compensation increase', '', '', '- - %', '- - %']]",
#   {'uid': '52164b70-6973-4844-af6a-76e8f1298d64',
#    'table': [['', 'Domestic', '', 'International', ''],
#     ['', 'September 30,', '', 'September 30,', ''],
#     ['', '2019', '2018', '2019', '2018'],
#     ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'],
#     ['Expected return on plan assets', '', '', '3.40%', '3.70%'],
#     ['Rate of compensation increase', '', '', '- - %', '- - %']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 6.67, 'scale': 'percent'},
#   6.67,
#   '',
#   {'uid': '4dc8be43-d8d9-4b08-9ffd-9c19012361ce',
#    'order': 5,
#    'question': 'What is the year on year percentage change in domestic discount rate between 2018 and 2019?',
#    'answer': 6.67,
#    'derivation': '(4.00 - 3.75)/3.75 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    domestic_discount_rate_2019 = 4.00\n    domestic_discount_rate_2018 = 3.75\n\n    year_on_year_change = ((domestic_discount_rate_2019 - domestic_discount_rate_2018) / domestic_discount_rate_2018) * 100\n\n    return round(year_on_year_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the year on year percentage change in domestic discount rate between 2018 and 2019? \n Table: [['', 'Domestic', '', 'International', ''], ['', 'September 30,', '', 'September 30,', ''], ['', '2019', '2018', '2019', '2018'], ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'], ['Expected return on plan assets', '', '', '3.40%', '3.70%'], ['Rate of compensation increase', '', '', '- - %', '- - %']]",
#   {'uid': '52164b70-6973-4844-af6a-76e8f1298d64',
#    'table': [['', 'Domestic', '', 'International', ''],
#     ['', 'September 30,', '', 'September 30,', ''],
#     ['', '2019', '2018', '2019', '2018'],
#     ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'],
#     ['Expected return on plan assets', '', '', '3.40%', '3.70%'],
#     ['Rate of compensation increase', '', '', '- - %', '- - %']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -8.11, 'scale': 'percent'},
#   -8.11,
#   '',
#   {'uid': '6c44a1a8-0785-43a0-90ab-7e21df2c57d9',
#    'order': 6,
#    'question': 'What is the year on year percentage change in international expected return on plan assets between 2018 and 2019?',
#    'answer': -8.11,
#    'derivation': '(3.40 - 3.70)/3.70 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    international_return_2019 = 3.40\n    international_return_2018 = 3.70\n\n    percentage_change = ((international_return_2019 - international_return_2018) / international_return_2018) * 100\n\n    return round(percentage_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the year on year percentage change in international expected return on plan assets between 2018 and 2019? \n Table: [['', 'Domestic', '', 'International', ''], ['', 'September 30,', '', 'September 30,', ''], ['', '2019', '2018', '2019', '2018'], ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'], ['Expected return on plan assets', '', '', '3.40%', '3.70%'], ['Rate of compensation increase', '', '', '- - %', '- - %']]",
#   {'uid': '52164b70-6973-4844-af6a-76e8f1298d64',
#    'table': [['', 'Domestic', '', 'International', ''],
#     ['', 'September 30,', '', 'September 30,', ''],
#     ['', '2019', '2018', '2019', '2018'],
#     ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'],
#     ['Expected return on plan assets', '', '', '3.40%', '3.70%'],
#     ['Rate of compensation increase', '', '', '- - %', '- - %']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 172, 'scale': 'million'},
#   178.67,
#   '',
#   {'uid': 'a0414f81-8dc2-44b2-a441-2c9d9c805c4d',
#    'order': 4,
#    'question': 'What is the 2019 average defined contribution schemes?',
#    'answer': 172,
#    'derivation': '(166+178)/2',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    average = (166 + 178 + 192) / 3\n    return round(average, 2), 'million'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the 2019 average defined contribution schemes? \n Table: [['Income statement expense', '', '', ''], ['', '2019 €m', '2018 €m', '2017 €m'], ['Defined contribution schemes', '166', '178', '192'], ['Defined benefit schemes', '57', '44', '20'], ['Total amount charged to income statement (note 23)', '223', '222', '212']]",
#   {'uid': '6bf238a5-0a3e-492d-91f8-7f62d3b37fba',
#    'table': [['Income statement expense', '', '', ''],
#     ['', '2019 €m', '2018 €m', '2017 €m'],
#     ['Defined contribution schemes', '166', '178', '192'],
#     ['Defined benefit schemes', '57', '44', '20'],
#     ['Total amount charged to income statement (note 23)',
#      '223',
#      '222',
#      '212']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 50.5, 'scale': 'million'},
#   19.0,
#   '',
#   {'uid': 'bf7abd62-d9cd-48d2-8826-1457684019a3',
#    'order': 5,
#    'question': 'What is the 2019 average defined benefit schemes?',
#    'answer': 50.5,
#    'derivation': '(57+44)/2',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    total_db_schemes = 57\n    total_years = 3\n    average_db_schemes = total_db_schemes / total_years\n    return (average_db_schemes, 'million')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the 2019 average defined benefit schemes? \n Table: [['Income statement expense', '', '', ''], ['', '2019 €m', '2018 €m', '2017 €m'], ['Defined contribution schemes', '166', '178', '192'], ['Defined benefit schemes', '57', '44', '20'], ['Total amount charged to income statement (note 23)', '223', '222', '212']]",
#   {'uid': '6bf238a5-0a3e-492d-91f8-7f62d3b37fba',
#    'table': [['Income statement expense', '', '', ''],
#     ['', '2019 €m', '2018 €m', '2017 €m'],
#     ['Defined contribution schemes', '166', '178', '192'],
#     ['Defined benefit schemes', '57', '44', '20'],
#     ['Total amount charged to income statement (note 23)',
#      '223',
#      '222',
#      '212']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 121.5, 'scale': 'million'},
#   109.0,
#   '',
#   {'uid': '4d259081-6da6-44bd-8830-e4de0031744c',
#    'order': 6,
#    'question': 'What is the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes?',
#    'answer': 121.5,
#    'derivation': '[(166+178)/2] - [(57+44)/2]',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    dc_2019 = float(166)\n    db_2019 = float(57)\n    \n    difference = dc_2019 - db_2019\n    \n    return round(difference, 2), 'million'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes? \n Table: [['Income statement expense', '', '', ''], ['', '2019 €m', '2018 €m', '2017 €m'], ['Defined contribution schemes', '166', '178', '192'], ['Defined benefit schemes', '57', '44', '20'], ['Total amount charged to income statement (note 23)', '223', '222', '212']]",
#   {'uid': '6bf238a5-0a3e-492d-91f8-7f62d3b37fba',
#    'table': [['Income statement expense', '', '', ''],
#     ['', '2019 €m', '2018 €m', '2017 €m'],
#     ['Defined contribution schemes', '166', '178', '192'],
#     ['Defined benefit schemes', '57', '44', '20'],
#     ['Total amount charged to income statement (note 23)',
#      '223',
#      '222',
#      '212']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 26.82, 'scale': 'percent'},
#   26.82,
#   '',
#   {'uid': 'bed1fce2-69cb-4d1e-a34a-01950a1770bd',
#    'order': 4,
#    'question': 'What is the percentage change in the operating loss carryforward from 2018 to 2019?',
#    'answer': 26.82,
#    'derivation': '(73,260-57,768)/57,768',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    operating_loss_2019 = 73260\n    operating_loss_2018 = 57768\n    \n    percentage_change = ((operating_loss_2019 - operating_loss_2018) / operating_loss_2018) * 100\n    \n    return round(percentage_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the percentage change in the operating loss carryforward from 2018 to 2019? \n Table: [['', 'December 31', ''], ['', '2019', '2 0 1 8'], ['', 'U.S.  in thousands', ''], ['Operating loss carryforward', '73260', '57768'], ['Net deferred tax asset before valuation allowance', '19911', '15916'], ['Valuation allowance', '(19911)', '(15916)'], ['Net deferred tax asset', '795', '772']]",
#   {'uid': 'f8ac9ddd-9872-4681-902d-a0ee7c0ee83a',
#    'table': [['', 'December 31', ''],
#     ['', '2019', '2 0 1 8'],
#     ['', 'U.S. $ in thousands', ''],
#     ['Operating loss carryforward', '73,260', '57,768'],
#     ['Net deferred tax asset before valuation allowance', '19,911', '15,916'],
#     ['Valuation allowance', '(19,911)', '(15,916)'],
#     ['Net deferred tax asset', '795', '772']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 25.1, 'scale': 'percent'},
#   -25.1,
#   '',
#   {'uid': '348d031d-73ab-4b35-af46-998cfef25775',
#    'order': 5,
#    'question': 'What is the percentage change in the valuation allowance from 2018 to 2019?',
#    'answer': 25.1,
#    'derivation': '(19,911-15,916)/15,916',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['4'],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    valuation_2019 = -19911\n    valuation_2018 = -15916\n    \n    percentage_change = ((valuation_2019 - valuation_2018) / abs(valuation_2018)) * 100\n    \n    return round(percentage_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the percentage change in the valuation allowance from 2018 to 2019? \n Table: [['', 'December 31', ''], ['', '2019', '2 0 1 8'], ['', 'U.S.  in thousands', ''], ['Operating loss carryforward', '73260', '57768'], ['Net deferred tax asset before valuation allowance', '19911', '15916'], ['Valuation allowance', '(19911)', '(15916)'], ['Net deferred tax asset', '795', '772']]",
#   {'uid': 'f8ac9ddd-9872-4681-902d-a0ee7c0ee83a',
#    'table': [['', 'December 31', ''],
#     ['', '2019', '2 0 1 8'],
#     ['', 'U.S. $ in thousands', ''],
#     ['Operating loss carryforward', '73,260', '57,768'],
#     ['Net deferred tax asset before valuation allowance', '19,911', '15,916'],
#     ['Valuation allowance', '(19,911)', '(15,916)'],
#     ['Net deferred tax asset', '795', '772']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 2.98, 'scale': 'percent'},
#   2.98,
#   '',
#   {'uid': 'aea850af-68cb-4cc1-80b2-c9c2860b273e',
#    'order': 6,
#    'question': 'What is the percentage change in the net deferred tax asset from 2018 to 2019?',
#    'answer': 2.98,
#    'derivation': '(795-772)/772',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    net_deferred_tax_asset_2018 = 772\n    net_deferred_tax_asset_2019 = 795\n    \n    percentage_change = ((net_deferred_tax_asset_2019 - net_deferred_tax_asset_2018) / net_deferred_tax_asset_2018) * 100\n    \n    return round(percentage_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the percentage change in the net deferred tax asset from 2018 to 2019? \n Table: [['', 'December 31', ''], ['', '2019', '2 0 1 8'], ['', 'U.S.  in thousands', ''], ['Operating loss carryforward', '73260', '57768'], ['Net deferred tax asset before valuation allowance', '19911', '15916'], ['Valuation allowance', '(19911)', '(15916)'], ['Net deferred tax asset', '795', '772']]",
#   {'uid': 'f8ac9ddd-9872-4681-902d-a0ee7c0ee83a',
#    'table': [['', 'December 31', ''],
#     ['', '2019', '2 0 1 8'],
#     ['', 'U.S. $ in thousands', ''],
#     ['Operating loss carryforward', '73,260', '57,768'],
#     ['Net deferred tax asset before valuation allowance', '19,911', '15,916'],
#     ['Valuation allowance', '(19,911)', '(15,916)'],
#     ['Net deferred tax asset', '795', '772']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 2.93, 'scale': ''},
#   2.93,
#   '',
#   {'uid': 'ba6783f3-8207-419a-b407-3f688682caef',
#    'order': 4,
#    'question': 'What is the ratio of IMFT’s total assets to total liabilities in 2019?',
#    'answer': 2.93,
#    'derivation': '2,664/909 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': ''},
#   "def run():\n    total_assets_2019 = 2664\n    total_liabilities_2019 = 909\n    \n    ratio = total_assets_2019 / total_liabilities_2019\n    \n    if ratio >= 1000000:\n        return (round(ratio / 1000000, 2), 'million')\n    elif ratio >= 1000:\n        return (round(ratio / 1000, 2), 'thousand')\n    else:\n        return (round(ratio, 2), '')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the ratio of IMFT’s total assets to total liabilities in 2019? \n Table: [['As of', '2019', '2018'], ['Assets', '', ''], ['Cash and equivalents', '130', '91'], ['Receivables', '128', '126'], ['Inventories', '124', '114'], ['Other current assets', '9', '8'], ['Total current assets', '391', '339'], ['Property, plant, and equipment', '2235', '2641'], ['Other noncurrent assets', '38', '45'], ['Total assets', '2664', '3025'], ['Liabilities', '', ''], ['Accounts payable and accrued expenses', '118', '138'], ['Current debt', '696', '20'], ['Other current liabilities', '37', '9'], ['Total current liabilities', '851', '167'], ['Long-term debt', '53', '1064'], ['Other noncurrent liabilities', '5', '74'], ['Total liabilities', '909', '1305']]",
#   {'uid': 'e9a946ce-72a9-4b42-86d6-4d91fceb14db',
#    'table': [['As of', '2019', '2018'],
#     ['Assets', '', ''],
#     ['Cash and equivalents', '$130', '$91'],
#     ['Receivables', '128', '126'],
#     ['Inventories', '124', '114'],
#     ['Other current assets', '9', '8'],
#     ['Total current assets', '391', '339'],
#     ['Property, plant, and equipment', '2,235', '2,641'],
#     ['Other noncurrent assets', '38', '45'],
#     ['Total assets', '$2,664', '$3,025'],
#     ['Liabilities', '', ''],
#     ['Accounts payable and accrued expenses', '$118', '$138'],
#     ['Current debt', '696', '20'],
#     ['Other current liabilities', '37', '9'],
#     ['Total current liabilities', '851', '167'],
#     ['Long-term debt', '53', '1,064'],
#     ['Other noncurrent liabilities', '5', '74'],
#     ['Total liabilities', '$909', '$1,305']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 0.87, 'scale': ''},
#   87.31,
#   '',
#   {'uid': '263d03ec-83d2-48df-8376-1a72167798f7',
#    'order': 5,
#    'question': 'What is the proportion of IMFT’s property, plant, and equipment over total assets in 2018?',
#    'answer': 0.87,
#    'derivation': '2,641/3,025 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': ''},
#   "def run():\n    ppe_2018 = 2641\n    total_assets_2018 = 3025\n\n    proportion = (ppe_2018 / total_assets_2018) * 100\n    scale = 'percent'\n\n    return round(proportion, 2), scale\n\n# Test the function\nprint(run())",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the proportion of IMFT’s property, plant, and equipment over total assets in 2018? \n Table: [['As of', '2019', '2018'], ['Assets', '', ''], ['Cash and equivalents', '130', '91'], ['Receivables', '128', '126'], ['Inventories', '124', '114'], ['Other current assets', '9', '8'], ['Total current assets', '391', '339'], ['Property, plant, and equipment', '2235', '2641'], ['Other noncurrent assets', '38', '45'], ['Total assets', '2664', '3025'], ['Liabilities', '', ''], ['Accounts payable and accrued expenses', '118', '138'], ['Current debt', '696', '20'], ['Other current liabilities', '37', '9'], ['Total current liabilities', '851', '167'], ['Long-term debt', '53', '1064'], ['Other noncurrent liabilities', '5', '74'], ['Total liabilities', '909', '1305']]",
#   {'uid': 'e9a946ce-72a9-4b42-86d6-4d91fceb14db',
#    'table': [['As of', '2019', '2018'],
#     ['Assets', '', ''],
#     ['Cash and equivalents', '$130', '$91'],
#     ['Receivables', '128', '126'],
#     ['Inventories', '124', '114'],
#     ['Other current assets', '9', '8'],
#     ['Total current assets', '391', '339'],
#     ['Property, plant, and equipment', '2,235', '2,641'],
#     ['Other noncurrent assets', '38', '45'],
#     ['Total assets', '$2,664', '$3,025'],
#     ['Liabilities', '', ''],
#     ['Accounts payable and accrued expenses', '$118', '$138'],
#     ['Current debt', '696', '20'],
#     ['Other current liabilities', '37', '9'],
#     ['Total current liabilities', '851', '167'],
#     ['Long-term debt', '53', '1,064'],
#     ['Other noncurrent liabilities', '5', '74'],
#     ['Total liabilities', '$909', '$1,305']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -361, 'scale': ''},
#   -11.93,
#   '',
#   {'uid': '78fc6d55-c20c-4f71-99fe-bc40a16e61d0',
#    'order': 6,
#    'question': 'What is the change of IMFT’s total assets from 2018 to 2019?',
#    'answer': -361,
#    'derivation': '2,664 - 3,025 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': ''},
#   "def run():\n    assets_2019 = float(2664)\n    assets_2018 = float(3025)\n    \n    change = ((assets_2019 - assets_2018) / assets_2018) * 100\n    \n    if abs(change) >= 1000000:\n        return (round(change / 1000000, 2), 'million')\n    elif abs(change) >= 1000:\n        return (round(change / 1000, 2), 'thousand')\n    else:\n        return (round(change, 2), '')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the change of IMFT’s total assets from 2018 to 2019? \n Table: [['As of', '2019', '2018'], ['Assets', '', ''], ['Cash and equivalents', '130', '91'], ['Receivables', '128', '126'], ['Inventories', '124', '114'], ['Other current assets', '9', '8'], ['Total current assets', '391', '339'], ['Property, plant, and equipment', '2235', '2641'], ['Other noncurrent assets', '38', '45'], ['Total assets', '2664', '3025'], ['Liabilities', '', ''], ['Accounts payable and accrued expenses', '118', '138'], ['Current debt', '696', '20'], ['Other current liabilities', '37', '9'], ['Total current liabilities', '851', '167'], ['Long-term debt', '53', '1064'], ['Other noncurrent liabilities', '5', '74'], ['Total liabilities', '909', '1305']]",
#   {'uid': 'e9a946ce-72a9-4b42-86d6-4d91fceb14db',
#    'table': [['As of', '2019', '2018'],
#     ['Assets', '', ''],
#     ['Cash and equivalents', '$130', '$91'],
#     ['Receivables', '128', '126'],
#     ['Inventories', '124', '114'],
#     ['Other current assets', '9', '8'],
#     ['Total current assets', '391', '339'],
#     ['Property, plant, and equipment', '2,235', '2,641'],
#     ['Other noncurrent assets', '38', '45'],
#     ['Total assets', '$2,664', '$3,025'],
#     ['Liabilities', '', ''],
#     ['Accounts payable and accrued expenses', '$118', '$138'],
#     ['Current debt', '696', '20'],
#     ['Other current liabilities', '37', '9'],
#     ['Total current liabilities', '851', '167'],
#     ['Long-term debt', '53', '1,064'],
#     ['Other noncurrent liabilities', '5', '74'],
#     ['Total liabilities', '$909', '$1,305']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 73, 'scale': 'thousand'},
#   73,
#   '',
#   {'uid': '35d602ae-9131-4291-a30c-49a40f32bbe4',
#    'order': 5,
#    'question': 'What was the change in Value added tax receivables, net, noncurrent in 2019 from 2018?',
#    'answer': 73,
#    'derivation': '592-519',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['2'],
#    'req_comparison': False,
#    'scale': 'thousand'},
#   "def run():\n    value_2019 = 592\n    value_2018 = 519\n    change = value_2019 - value_2018\n    scale = ''\n    \n    if change >= 1000000:\n        change = round(change / 1000000, 2)\n        scale = 'million'\n    elif change >= 1000:\n        change = round(change / 1000, 2)\n        scale = 'thousand'\n    \n    return (change, scale)",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What was the change in Value added tax receivables, net, noncurrent in 2019 from 2018? \n Table: [['', 'December 31,', ''], ['', '2019', '2018'], ['Trade accounts receivable, net, noncurrent (Note 2)', '26496', '15948'], ['Equity method investments (Note 1)', '9254', '9702'], ['Net deferred tax assets, noncurrent (Note 20)', '6774', '5797'], ['Rent and other deposits', '6106', '5687'], ['Value added tax receivables, net, noncurrent', '592', '519'], ['Other', '6723', '5711'], ['', '55945', '43364']]",
#   {'uid': '789efd09-04a2-45c7-84e5-47d3543695d1',
#    'table': [['', 'December 31,', ''],
#     ['', '2019', '2018'],
#     ['Trade accounts receivable, net, noncurrent (Note 2)',
#      '$26,496',
#      '$15,948'],
#     ['Equity method investments (Note 1)', '9,254', '9,702'],
#     ['Net deferred tax assets, noncurrent (Note 20)', '6,774', '5,797'],
#     ['Rent and other deposits', '6,106', '5,687'],
#     ['Value added tax receivables, net, noncurrent', '592', '519'],
#     ['Other', '6,723', '5,711'],
#     ['', '$55,945', '$43,364']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 14.07, 'scale': 'percent'},
#   14.07,
#   '',
#   {'uid': 'a4f782f1-de3b-47a3-87af-1cb33c112b39',
#    'order': 6,
#    'question': 'What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018?',
#    'answer': 14.07,
#    'derivation': '(592-519)/519',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    current_year = 2019\n    previous_year = 2018\n    current_value = 592\n    previous_value = 519\n\n    percentage_change = ((current_value - previous_value) / previous_value) * 100\n\n    return round(percentage_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018? \n Table: [['', 'December 31,', ''], ['', '2019', '2018'], ['Trade accounts receivable, net, noncurrent (Note 2)', '26496', '15948'], ['Equity method investments (Note 1)', '9254', '9702'], ['Net deferred tax assets, noncurrent (Note 20)', '6774', '5797'], ['Rent and other deposits', '6106', '5687'], ['Value added tax receivables, net, noncurrent', '592', '519'], ['Other', '6723', '5711'], ['', '55945', '43364']]",
#   {'uid': '789efd09-04a2-45c7-84e5-47d3543695d1',
#    'table': [['', 'December 31,', ''],
#     ['', '2019', '2018'],
#     ['Trade accounts receivable, net, noncurrent (Note 2)',
#      '$26,496',
#      '$15,948'],
#     ['Equity method investments (Note 1)', '9,254', '9,702'],
#     ['Net deferred tax assets, noncurrent (Note 20)', '6,774', '5,797'],
#     ['Rent and other deposits', '6,106', '5,687'],
#     ['Value added tax receivables, net, noncurrent', '592', '519'],
#     ['Other', '6,723', '5,711'],
#     ['', '$55,945', '$43,364']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 4227.5, 'scale': 'million'},
#   1814.33,
#   '',
#   {'uid': 'dc5e217a-a7b3-4fc9-ac0f-13d328f26b20',
#    'order': 4,
#    'question': 'What is the 2019 average free cash flow?',
#    'answer': 4227.5,
#    'derivation': '(4,411+4,044)/2',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    average_free_cash_flow_2019 = (4411 + 837 + 195) / 3\n    return round(average_free_cash_flow_2019, 2), 'million'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the 2019 average free cash flow? \n Table: [['', '2019', '2018', '2017'], ['', '€m', '€m', '€m'], ['Cash generated by operations (refer to note 18)', '14182', '13860', '13781'], ['Capital additions', '(7227)', '(7321)', '(7675)'], ['Working capital movement in respect of capital additions', '(89)', '171', '(822)'], ['Disposal of property, plant and equipment', '45', '41', '43'], ['Restructuring payments', '195', '250', '266'], ['Other', '(35)', '–', '34'], ['Operating free cash flow', '7071', '7001', '5627'], ['Taxation', '(1040)', '(1010)', '(761)'], ['Dividends received from associates and investments', '498', '489', '433'], ['Dividends paid to non-controlling shareholders in subsidiaries', '(584)', '(310)', '(413)'], ['Interest received and paid', '(502)', '(753)', '(830)'], ['Free cash flow (pre-spectrum)', '5443', '5417', '4056'], ['Licence and spectrum payments', '(837)', '(1123)', '(474)'], ['Restructuring payments', '(195)', '(250)', '(266)'], ['Free cash flow', '4411', '4044', '3316']]",
#   {'uid': '403df8e0-6045-4dba-90b3-5c9d8ca55bfb',
#    'table': [['', '2019', '2018', '2017'],
#     ['', '€m', '€m', '€m'],
#     ['Cash generated by operations (refer to note 18)',
#      '14,182',
#      '13,860',
#      '13,781'],
#     ['Capital additions', '(7,227)', '(7,321)', '(7,675)'],
#     ['Working capital movement in respect of capital additions',
#      '(89)',
#      '171',
#      '(822)'],
#     ['Disposal of property, plant and equipment', '45', '41', '43'],
#     ['Restructuring payments', '195', '250', '266'],
#     ['Other', '(35)', '–', '34'],
#     ['Operating free cash flow', '7,071', '7,001', '5,627'],
#     ['Taxation', '(1,040)', '(1,010)', '(761)'],
#     ['Dividends received from associates and investments',
#      '498',
#      '489',
#      '433'],
#     ['Dividends paid to non-controlling shareholders in subsidiaries',
#      '(584)',
#      '(310)',
#      '(413)'],
#     ['Interest received and paid', '(502)', '(753)', '(830)'],
#     ['Free cash flow (pre-spectrum)', '5,443', '5,417', '4,056'],
#     ['Licence and spectrum payments', '(837)', '(1,123)', '(474)'],
#     ['Restructuring payments', '(195)', '(250)', '(266)'],
#     ['Free cash flow', '4,411', '4,044', '3,316']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 3680, 'scale': 'million'},
#   3680.0,
#   '',
#   {'uid': '7cd3aedf-1291-4fea-bc9d-a25c65727b7b',
#    'order': 5,
#    'question': 'What is the 2018 average free cash flow?',
#    'answer': 3680,
#    'derivation': '(4,044+3,316)/2',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    average_free_cash_flow_2018 = (4044 + 3316) / 2\n    return (average_free_cash_flow_2018, 'million') \n\n# Test the function\nprint(run())",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the 2018 average free cash flow? \n Table: [['', '2019', '2018', '2017'], ['', '€m', '€m', '€m'], ['Cash generated by operations (refer to note 18)', '14182', '13860', '13781'], ['Capital additions', '(7227)', '(7321)', '(7675)'], ['Working capital movement in respect of capital additions', '(89)', '171', '(822)'], ['Disposal of property, plant and equipment', '45', '41', '43'], ['Restructuring payments', '195', '250', '266'], ['Other', '(35)', '–', '34'], ['Operating free cash flow', '7071', '7001', '5627'], ['Taxation', '(1040)', '(1010)', '(761)'], ['Dividends received from associates and investments', '498', '489', '433'], ['Dividends paid to non-controlling shareholders in subsidiaries', '(584)', '(310)', '(413)'], ['Interest received and paid', '(502)', '(753)', '(830)'], ['Free cash flow (pre-spectrum)', '5443', '5417', '4056'], ['Licence and spectrum payments', '(837)', '(1123)', '(474)'], ['Restructuring payments', '(195)', '(250)', '(266)'], ['Free cash flow', '4411', '4044', '3316']]",
#   {'uid': '403df8e0-6045-4dba-90b3-5c9d8ca55bfb',
#    'table': [['', '2019', '2018', '2017'],
#     ['', '€m', '€m', '€m'],
#     ['Cash generated by operations (refer to note 18)',
#      '14,182',
#      '13,860',
#      '13,781'],
#     ['Capital additions', '(7,227)', '(7,321)', '(7,675)'],
#     ['Working capital movement in respect of capital additions',
#      '(89)',
#      '171',
#      '(822)'],
#     ['Disposal of property, plant and equipment', '45', '41', '43'],
#     ['Restructuring payments', '195', '250', '266'],
#     ['Other', '(35)', '–', '34'],
#     ['Operating free cash flow', '7,071', '7,001', '5,627'],
#     ['Taxation', '(1,040)', '(1,010)', '(761)'],
#     ['Dividends received from associates and investments',
#      '498',
#      '489',
#      '433'],
#     ['Dividends paid to non-controlling shareholders in subsidiaries',
#      '(584)',
#      '(310)',
#      '(413)'],
#     ['Interest received and paid', '(502)', '(753)', '(830)'],
#     ['Free cash flow (pre-spectrum)', '5,443', '5,417', '4,056'],
#     ['Licence and spectrum payments', '(837)', '(1,123)', '(474)'],
#     ['Restructuring payments', '(195)', '(250)', '(266)'],
#     ['Free cash flow', '4,411', '4,044', '3,316']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 547.5, 'scale': 'million'},
#   196.5,
#   '',
#   {'uid': '22e20f25-669a-46b9-8779-2768ba391955',
#    'order': 6,
#    'question': 'What is the change between 2018 and 2019 average free cash flow?',
#    'answer': 547.5,
#    'derivation': '[(4,411+4,044)/2] -[(4,044+3,316)/2]',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    avg_free_cash_flow_2019 = (5443 + 4411) / 2\n    avg_free_cash_flow_2018 = (5417 + 4044) / 2\n    change = avg_free_cash_flow_2019 - avg_free_cash_flow_2018\n    return round(change, 2), 'million'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the change between 2018 and 2019 average free cash flow? \n Table: [['', '2019', '2018', '2017'], ['', '€m', '€m', '€m'], ['Cash generated by operations (refer to note 18)', '14182', '13860', '13781'], ['Capital additions', '(7227)', '(7321)', '(7675)'], ['Working capital movement in respect of capital additions', '(89)', '171', '(822)'], ['Disposal of property, plant and equipment', '45', '41', '43'], ['Restructuring payments', '195', '250', '266'], ['Other', '(35)', '–', '34'], ['Operating free cash flow', '7071', '7001', '5627'], ['Taxation', '(1040)', '(1010)', '(761)'], ['Dividends received from associates and investments', '498', '489', '433'], ['Dividends paid to non-controlling shareholders in subsidiaries', '(584)', '(310)', '(413)'], ['Interest received and paid', '(502)', '(753)', '(830)'], ['Free cash flow (pre-spectrum)', '5443', '5417', '4056'], ['Licence and spectrum payments', '(837)', '(1123)', '(474)'], ['Restructuring payments', '(195)', '(250)', '(266)'], ['Free cash flow', '4411', '4044', '3316']]",
#   {'uid': '403df8e0-6045-4dba-90b3-5c9d8ca55bfb',
#    'table': [['', '2019', '2018', '2017'],
#     ['', '€m', '€m', '€m'],
#     ['Cash generated by operations (refer to note 18)',
#      '14,182',
#      '13,860',
#      '13,781'],
#     ['Capital additions', '(7,227)', '(7,321)', '(7,675)'],
#     ['Working capital movement in respect of capital additions',
#      '(89)',
#      '171',
#      '(822)'],
#     ['Disposal of property, plant and equipment', '45', '41', '43'],
#     ['Restructuring payments', '195', '250', '266'],
#     ['Other', '(35)', '–', '34'],
#     ['Operating free cash flow', '7,071', '7,001', '5,627'],
#     ['Taxation', '(1,040)', '(1,010)', '(761)'],
#     ['Dividends received from associates and investments',
#      '498',
#      '489',
#      '433'],
#     ['Dividends paid to non-controlling shareholders in subsidiaries',
#      '(584)',
#      '(310)',
#      '(413)'],
#     ['Interest received and paid', '(502)', '(753)', '(830)'],
#     ['Free cash flow (pre-spectrum)', '5,443', '5,417', '4,056'],
#     ['Licence and spectrum payments', '(837)', '(1,123)', '(474)'],
#     ['Restructuring payments', '(195)', '(250)', '(266)'],
#     ['Free cash flow', '4,411', '4,044', '3,316']]},
#   None),
# ...
#     ['Research, development and engineering', '126', '67', '59'],
#     ['Pre-tax stock-based compensation cost', '679', '510', '534'],
#     ['Income tax benefits', '(155)', '(116)', '(131)'],
#     ['Net stock-based compensation cost', '$524', '$393', '$403']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 0.2, 'scale': 'million'},
#   0.2,
#   '',
#   {'uid': '65ec782c-691e-45df-b541-caecb85154ff',
#    'order': 5,
#    'question': 'What was the change in Capital redemption reserve in 2019 from 2018?',
#    'answer': 0.2,
#    'derivation': '0.7-0.5',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    change = float(0.7) - float(0.5)\n    return round(change, 2), 'million'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What was the change in Capital redemption reserve in 2019 from 2018? \n Table: [['', '', '2019', '2018'], ['', 'Note', '£m', '£m'], ['Fixed assets', '', '', ''], ['Investments', '3', '1216.0', '1212.9'], ['', '', '1216.0', '1212.9'], ['Current assets', '', '', ''], ['Debtors', '4', '415.9', '440.7'], ['Cash and cash equivalents', '5', '–', '0.2'], ['', '', '415.9', '440.9'], ['Creditors: amounts falling due within one year', '6', '(411.4)', '(288.4)'], ['Net current assets', '', '4.5', '152.5'], ['Net assets', '', '1220.5', '1365.4'], ['Capital and reserves', '', '', ''], ['Called-up share capital', '9', '9.3', '9.5'], ['Own shares held', '10', '(16.5)', '(16.9)'], ['Capital redemption reserve', '', '0.7', '0.5'], ['Retained earnings', '', '1227.0', '1372.3'], ['Total equity', '', '1220.5', '1365.4']]",
#   {'uid': '1c9e6c58-fd11-4711-986e-1d86b626d1dd',
#    'table': [['', '', '2019', '2018'],
#     ['', 'Note', '£m', '£m'],
#     ['Fixed assets', '', '', ''],
#     ['Investments', '3', '1,216.0', '1,212.9'],
#     ['', '', '1,216.0', '1,212.9'],
#     ['Current assets', '', '', ''],
#     ['Debtors', '4', '415.9', '440.7'],
#     ['Cash and cash equivalents', '5', '–', '0.2'],
#     ['', '', '415.9', '440.9'],
#     ['Creditors: amounts falling due within one year',
#      '6',
#      '(411.4)',
#      '(288.4)'],
#     ['Net current assets', '', '4.5', '152.5'],
#     ['Net assets', '', '1,220.5', '1,365.4'],
#     ['Capital and reserves', '', '', ''],
#     ['Called-up share capital', '9', '9.3', '9.5'],
#     ['Own shares held', '10', '(16.5)', '(16.9)'],
#     ['Capital redemption reserve', '', '0.7', '0.5'],
#     ['Retained earnings', '', '1,227.0', '1,372.3'],
#     ['Total equity', '', '1,220.5', '1,365.4']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 40, 'scale': 'percent'},
#   40.0,
#   '',
#   {'uid': '94916f79-4b6d-487f-8fa2-39f81a085760',
#    'order': 6,
#    'question': 'What was the percentage change in Capital redemption reserve in 2019 from 2018?',
#    'answer': 40,
#    'derivation': '(0.7-0.5)/0.5',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    capital_redemption_reserve_2019 = 0.7\n    capital_redemption_reserve_2018 = 0.5\n    \n    percentage_change = ((capital_redemption_reserve_2019 - capital_redemption_reserve_2018) / capital_redemption_reserve_2018) * 100\n    \n    return round(percentage_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What was the percentage change in Capital redemption reserve in 2019 from 2018? \n Table: [['', '', '2019', '2018'], ['', 'Note', '£m', '£m'], ['Fixed assets', '', '', ''], ['Investments', '3', '1216.0', '1212.9'], ['', '', '1216.0', '1212.9'], ['Current assets', '', '', ''], ['Debtors', '4', '415.9', '440.7'], ['Cash and cash equivalents', '5', '–', '0.2'], ['', '', '415.9', '440.9'], ['Creditors: amounts falling due within one year', '6', '(411.4)', '(288.4)'], ['Net current assets', '', '4.5', '152.5'], ['Net assets', '', '1220.5', '1365.4'], ['Capital and reserves', '', '', ''], ['Called-up share capital', '9', '9.3', '9.5'], ['Own shares held', '10', '(16.5)', '(16.9)'], ['Capital redemption reserve', '', '0.7', '0.5'], ['Retained earnings', '', '1227.0', '1372.3'], ['Total equity', '', '1220.5', '1365.4']]",
#   {'uid': '1c9e6c58-fd11-4711-986e-1d86b626d1dd',
#    'table': [['', '', '2019', '2018'],
#     ['', 'Note', '£m', '£m'],
#     ['Fixed assets', '', '', ''],
#     ['Investments', '3', '1,216.0', '1,212.9'],
#     ['', '', '1,216.0', '1,212.9'],
#     ['Current assets', '', '', ''],
#     ['Debtors', '4', '415.9', '440.7'],
#     ['Cash and cash equivalents', '5', '–', '0.2'],
#     ['', '', '415.9', '440.9'],
#     ['Creditors: amounts falling due within one year',
#      '6',
#      '(411.4)',
#      '(288.4)'],
#     ['Net current assets', '', '4.5', '152.5'],
#     ['Net assets', '', '1,220.5', '1,365.4'],
#     ['Capital and reserves', '', '', ''],
#     ['Called-up share capital', '9', '9.3', '9.5'],
#     ['Own shares held', '10', '(16.5)', '(16.9)'],
#     ['Capital redemption reserve', '', '0.7', '0.5'],
#     ['Retained earnings', '', '1,227.0', '1,372.3'],
#     ['Total equity', '', '1,220.5', '1,365.4']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 0.51, 'scale': 'percent'},
#   0.51,
#   '',
#   {'uid': '72325ec6-41ad-4648-9798-b22a61122cb4',
#    'order': 4,
#    'question': 'How much is the percentage change of total goodwill amount from 2017 to 2018?',
#    'answer': 0.51,
#    'derivation': '(24,513 - 24,389) / 24,389 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['1'],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    total_goodwill_2017 = 24389\n    total_goodwill_2018 = 24513\n    percentage_change = ((total_goodwill_2018 - total_goodwill_2017) / total_goodwill_2017) * 100\n    return round(percentage_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: How much is the percentage change of total goodwill amount from 2017 to 2018? \n Table: [['(In Millions)', 'Dec 29, 2018', 'Acquisitions', 'Transfers', 'Other', 'Dec 28, 2019'], ['Data Center Group', '5424', '1758', '—', '—', '7155'], ['Internet of Things Group', '1579', '—', '—', '—', '1579'], ['Mobileye', '10290', '—', '—', '—', '10290'], ['Programmable Solutions Group', '2579', '67', '—', '8', '2681'], ['Client Computing Group', '4403', '—', '—', '(70)', '4333'], ['All other', '238', '—', '—', '—', '238'], ['Total', '24513', '1825', '—', '(62)', '26276'], ['(In Millions)', 'Dec 30, 2017', 'Acquisitions', 'Transfers', 'Other', 'Dec 29, 2018'], ['Data Center Group', '5421', '3', '—', '—', '5424'], ['Internet of Things Group', '1126', '16', '480', '(43)', '1579'], ['Mobileye', '10278', '7', '—', '5', '10290'], ['Programmable Solutions Group', '2490', '89', '—', '—', '2579'], ['Client Computing Group', '4356', '47', '—', '—', '4403'], ['All other', '718', '—', '(480)', '—', '238'], ['Total', '24389', '162', '—', '(38)', '24513']]",
#   {'uid': '8749fc7b-19fb-4014-8eed-f96a05da50cf',
#    'table': [['(In Millions)',
#      'Dec 29, 2018',
#      'Acquisitions',
#      'Transfers',
#      'Other',
#      'Dec 28, 2019'],
#     ['Data Center Group', '$5,424', '$1,758', '$—', '$—', '$7,155'],
#     ['Internet of Things Group', '1,579', '—', '—', '—', '1,579'],
#     ['Mobileye', '10,290', '—', '—', '—', '10,290'],
#     ['Programmable Solutions Group', '2,579', '67', '—', '8', '2,681'],
#     ['Client Computing Group', '4,403', '—', '—', '(70)', '4,333'],
#     ['All other', '238', '—', '—', '—', '238'],
#     ['Total', '$24,513', '$1,825', '$—', '$(62)', '$26,276'],
#     ['(In Millions)',
#      'Dec 30, 2017',
#      'Acquisitions',
#      'Transfers',
#      'Other',
#      'Dec 29, 2018'],
#     ['Data Center Group', '$5,421', '$3', '$—', '$—', '$5,424'],
#     ['Internet of Things Group', '1,126', '16', '480', '(43)', '1,579'],
#     ['Mobileye', '10,278', '7', '—', '5', '10,290'],
#     ['Programmable Solutions Group', '2,490', '89', '—', '—', '2,579'],
#     ['Client Computing Group', '4,356', '47', '—', '—', '4,403'],
#     ['All other', '718', '—', '(480)', '—', '238'],
#     ['Total', '$24,389', '$162', '$—', '$(38)', '$24,513']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 0.7000000000000001, 'scale': ''},
#   695.34,
#   '',
#   {'uid': '4f7c8e0a-6ae9-40ee-bd16-06db6f96eaf1',
#    'order': 5,
#    'question': 'What is the ratio of Data Center Group to Mobileye goodwill amount in 2019?',
#    'answer': 0.7000000000000001,
#    'derivation': '7,155 / 10,290 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['1'],
#    'req_comparison': False,
#    'scale': ''},
#   "def run():\n    data_center_group_2019 = 7155\n    mobileye_2019 = 10290\n\n    ratio = data_center_group_2019 / mobileye_2019\n\n    if ratio >= 1:\n        return round(ratio, 2), 'million'\n    else:\n        return round(ratio * 1000, 2), 'thousand'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: What is the ratio of Data Center Group to Mobileye goodwill amount in 2019? \n Table: [['(In Millions)', 'Dec 29, 2018', 'Acquisitions', 'Transfers', 'Other', 'Dec 28, 2019'], ['Data Center Group', '5424', '1758', '—', '—', '7155'], ['Internet of Things Group', '1579', '—', '—', '—', '1579'], ['Mobileye', '10290', '—', '—', '—', '10290'], ['Programmable Solutions Group', '2579', '67', '—', '8', '2681'], ['Client Computing Group', '4403', '—', '—', '(70)', '4333'], ['All other', '238', '—', '—', '—', '238'], ['Total', '24513', '1825', '—', '(62)', '26276'], ['(In Millions)', 'Dec 30, 2017', 'Acquisitions', 'Transfers', 'Other', 'Dec 29, 2018'], ['Data Center Group', '5421', '3', '—', '—', '5424'], ['Internet of Things Group', '1126', '16', '480', '(43)', '1579'], ['Mobileye', '10278', '7', '—', '5', '10290'], ['Programmable Solutions Group', '2490', '89', '—', '—', '2579'], ['Client Computing Group', '4356', '47', '—', '—', '4403'], ['All other', '718', '—', '(480)', '—', '238'], ['Total', '24389', '162', '—', '(38)', '24513']]",
#   {'uid': '8749fc7b-19fb-4014-8eed-f96a05da50cf',
#    'table': [['(In Millions)',
#      'Dec 29, 2018',
#      'Acquisitions',
#      'Transfers',
#      'Other',
#      'Dec 28, 2019'],
#     ['Data Center Group', '$5,424', '$1,758', '$—', '$—', '$7,155'],
#     ['Internet of Things Group', '1,579', '—', '—', '—', '1,579'],
#     ['Mobileye', '10,290', '—', '—', '—', '10,290'],
#     ['Programmable Solutions Group', '2,579', '67', '—', '8', '2,681'],
#     ['Client Computing Group', '4,403', '—', '—', '(70)', '4,333'],
#     ['All other', '238', '—', '—', '—', '238'],
#     ['Total', '$24,513', '$1,825', '$—', '$(62)', '$26,276'],
#     ['(In Millions)',
#      'Dec 30, 2017',
#      'Acquisitions',
#      'Transfers',
#      'Other',
#      'Dec 29, 2018'],
#     ['Data Center Group', '$5,421', '$3', '$—', '$—', '$5,424'],
#     ['Internet of Things Group', '1,126', '16', '480', '(43)', '1,579'],
#     ['Mobileye', '10,278', '7', '—', '5', '10,290'],
#     ['Programmable Solutions Group', '2,490', '89', '—', '—', '2,579'],
#     ['Client Computing Group', '4,356', '47', '—', '—', '4,403'],
#     ['All other', '718', '—', '(480)', '—', '238'],
#     ['Total', '$24,389', '$162', '$—', '$(38)', '$24,513']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 13237.4, 'scale': 'million'},
#   13237.4,
#   '',
#   {'uid': 'bbe335ff-414f-48b3-8126-5a2c7c505de3',
#    'order': 1,
#    'question': 'How much was the average operating income from 2015 to 2019?',
#    'answer': 13237.4,
#    'derivation': ' (13,535+13,264+12,913+12,604+13,871) / 5 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    operating_income = [13535, 13264, 12913, 12604, 13871]\n    average_operating_income = sum(operating_income) / len(operating_income)\n    scale = 'million'\n    return round(average_operating_income, 2), scale",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: How much was the average operating income from 2015 to 2019? \n Table: [['', '', '', '', 'As of and for the Year Ended May 31,', ''], ['(in millions, except per share amounts)', '2019', '2018 (4)', '2017 (4)', '2016 (4)', '2015 (4)'], ['', 'Consolidated Statements of Operations Data:', '', '', '', ''], ['Total revenues', '39506', '39383', '37792', '37047', '38226'], ['Operating income', '13535', '13264', '12913', '12604', '13871'], ['Net income (1)', '11083', '3587', '9452', '8901', '9938'], ['Earnings per share—diluted (1)', '2.97', '0.85', '2.24', '2.07', '2.21'], ['Diluted weighted average common shares outstanding', '3732', '4238', '4217', '4305', '4503'], ['Cash dividends declared per common share', '0.81', '0.76', '0.64', '0.60', '0.51'], ['', 'Consolidated Balance Sheets Data:', '', '', '', ''], ['Working capital (2)', '27756', '57035', '50995', '47105', '47314'], ['Total assets (2)', '108709', '137851', '136003', '112180', '110903'], ['Notes payable and other borrowings (3)', '56167', '60619', '57909', '43855', '41958']]",
#   {'uid': '32edf644-acb0-4260-9392-f0baa4253f5a',
#    'table': [['', '', '', '', 'As of and for the Year Ended May 31,', ''],
#     ['(in millions, except per share amounts)',
#      '2019',
#      '2018 (4)',
#      '2017 (4)',
#      '2016 (4)',
#      '2015 (4)'],
#     ['', 'Consolidated Statements of Operations Data:', '', '', '', ''],
#     ['Total revenues', '$39,506', '$39,383', '$37,792', '$37,047', '$38,226'],
#     ['Operating income',
#      '$13,535',
#      '$13,264',
#      '$12,913',
#      '$12,604',
#      '$13,871'],
#     ['Net income (1)', '$11,083', '$3,587', '$9,452', '$8,901', '$9,938'],
#     ['Earnings per share—diluted (1)',
#      '$2.97',
#      '$0.85',
#      '$2.24',
#      '$2.07',
#      '$2.21'],
#     ['Diluted weighted average common shares outstanding',
#      '3,732',
#      '4,238',
#      '4,217',
#      '4,305',
#      '4,503'],
#     ['Cash dividends declared per common share',
#      '$0.81',
#      '$0.76',
#      '$0.64',
#      '$0.60',
#      '$0.51'],
#     ['', 'Consolidated Balance Sheets Data:', '', '', '', ''],
#     ['Working capital (2)',
#      '$27,756',
#      '$57,035',
#      '$50,995',
#      '$47,105',
#      '$47,314'],
#     ['Total assets (2)',
#      '$108,709',
#      '$137,851',
#      '$136,003',
#      '$112,180',
#      '$110,903'],
#     ['Notes payable and other borrowings (3)',
#      '$56,167',
#      '$60,619',
#      '$57,909',
#      '$43,855',
#      '$41,958']]},
#   None)]

# %%
from tatqa_metric import TaTQAEmAndF1

metrics = TaTQAEmAndF1()

for ans, pred, pred_scale, _,_, _,_,_ in res:
    metrics(ans, pred, pred_scale)
pred_em, pred_f1, scale_score, op_score = metrics.get_overall_metric(reset=False)
print( pred_em, pred_f1, scale_score)
# Out:
# 0.02857142857142857 0.02857142857142857 0.11428571428571428

# %%
[m for m in metrics._details if m['f1']<0.2]
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': -12.6,
#   'scale': 'million',
#   'pred': [-12.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22.22,
#   'scale': 'percent',
#   'pred': [-22.22],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -94,
#   'scale': 'million',
#   'pred': [-0.09],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12.14,
#   'scale': 'percent',
#   'pred': [-12.14],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.1,
#   'scale': 'percent',
#   'pred': [2.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.67,
#   'scale': 'percent',
#   'pred': [6.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8.11,
#   'scale': 'percent',
#   'pred': [-8.11],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [178.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [19.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [109.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.82,
#   'scale': 'percent',
#   'pred': [26.82],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.1,
#   'scale': 'percent',
#   'pred': [-25.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.98,
#   'scale': 'percent',
#   'pred': [2.98],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [87.31],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-11.93],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73,
#   'scale': 'thousand',
#   'pred': [73],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14.07,
#   'scale': 'percent',
#   'pred': [14.07],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [1814.33],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [3680.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [196.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [3.73],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [-16458],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 154,
#   'scale': 'million',
#   'pred': [154],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 104.05,
#   'scale': 'percent',
#   'pred': [104.05],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.57,
#   'scale': 'percent',
#   'pred': [1.57],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.9000000000000001],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [21.95],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 399.33,
#   'scale': 'million',
#   'pred': [399.33],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.06,
#   'scale': 'percent',
#   'pred': [88.06],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.2,
#   'scale': 'million',
#   'pred': [0.2],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.51,
#   'scale': 'percent',
#   'pred': [0.51],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': '',
#   'pred': [695.34],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13237.4,
#   'scale': 'million',
#   'pred': [13237.4],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]

# %%
metrics._details
# Out:
# []

# %%
good = 0
for ans, pred, pred_scale, q,code, _,table,err in res:
    llimit = ans['answer']*0.99
    ulimit = ans['answer']*1.01
    
    if pred  is None or isinstance(pred, tuple) or isinstance(pred, str):
        #if ans['scale'] != pred_scale:
        #    print ('***********', q['uid'], 'pred: ',pred, 'scale:',pred_scale, ' <> ' , ans['answer'], ans['scale'])
       
        #type error
        #if isinstance(pred, str):
        #    print (pred, pred_scale, ' -- ' , ans['answer'])
        #if isinstance(pred, tuple):
        #    print (pred, pred_scale, ' == ' , ans['answer'], ans['scale'])
        #print('===============================================================================')
        print('{',pred, '}', ans['answer'], ans['scale'], err)
        continue
    
    #pred = round(pred, 2)
    
    if (pred > 0 and llimit < pred and pred < ulimit) or (pred < 0 and llimit > pred and pred > ulimit) or pred==ulimit or pred == llimit:
        good = good + 1
        if ans['scale'] == pred_scale and  pred_scale == 'thousand':
            print ('***********', q['uid'], 'pred: ',pred, 'scale:',pred_scale, ' == ' , ans['answer'], ans['scale'])
        
        #if ans['scale'] != pred_scale:
        #    print ('***********', q['uid'], 'pred: ',pred, 'scale:',pred_scale, ' <> ' , ans['answer'], ans['scale'])
        #if  ans['scale'] == 'thousand':
        #    print (q['uid'], pred, pred_scale, ' == ' , ans['answer'], ans['scale'])
          
    else:
        #value error
        #  if ans['scale'] != pred_scale:
        #    print ('***********', q['uid'], 'pred: ',pred, 'scale:',pred_scale, ' <> ' , ans['answer'], ans['scale'])
        #if ans['answer'] != pred and ans['scale'] == pred_scale and pred_scale != "":
        #    print ('***********', q['uid'], 'pred: ',pred, 'scale:',pred_scale, ' <> ' , ans['answer'], ans['scale'])
       
        None
        #print (q['uid'], pred, pred_scale, ' <> ' , ans['answer'], ans['scale'])
        #print(q['question'])
        #print(table['table'])
        #print(code)
        
    #if isinstance(pred, str):
    #    print (pred, pred_scale, ' -- ' , ans['answer'])
    #if isinstance(pred, tuple):
    #    print (pred, pred_scale, ' == ' , ans['answer'], ans['scale'])
        
print (good/len(res))
# Out:
# {  } -361  [Error]could not convert string to float: '$2,664'
# {  } -1647 thousand [Error]could not convert string to float: '(5637)'
# { 58.71% } 58.71 percent None
# { 0.62 } 0.62 percent None
# { 3887.40 } 2988 thousand None
# { 92.27 } 92.27 percent None
# { 0.70 } 0.7000000000000001 million None
# {  } 29.17 percent None
# { 83.33% } 83.33 percent None
# { 82.05% } 82.05 percent None
# {  } 8500 thousand None
# {  } 14.68 percent [Error]could not convert string to float: '$1,562,474'
# {  } 79.05 percent [Error]could not convert string to float: '1,235,173'
# 0.7004405286343612

# %%
def parse_scale(scale):
    if scale.lower() == "thousands" or "000" in scale:
        return "thousand"
    if scale.lower() == "millions" or scale.lower() == "£m" or scale.lower() == "$m" or scale.lower() == "m":
        return "million"
    return scale.lower()

# %%
res_scale_para = {}
for idx, item in log_progress(devdf.iterrows()): 
    #item = devdf.iloc[2]
    table = item['table']['table']
    pars = [p['text'] for p in item['paragraphs']]
    prompt = f"The context contains some paragraphs that describe a table. Search for text that explicitly states the scale of the values in the table. Scale is usally million, thousand, billion or none, if no specific scale found. Return just the scale, no other words.\n Paragraphs: {pars}"
    scale = llm.invoke(prompt).content
    scale = parse_scale(scale)
    res_scale_para[item['table']['uid']] = scale
# Out:
# 0it [00:00, ?it/s]

# %%
res_scale_table = {}
for idx, item in log_progress(devdf.iterrows()): 
    #item = devdf.iloc[2]
    table = item['table']['table']
    pars = [p['text'] for p in item['paragraphs']]
    prompt = f"The context contains a table. Search for the scale of the values in table. Scale can be million, thousand, billion or None, if no specific scale found. Return just the scale, no other words.\n Table: {table}"
    scale = llm.invoke(prompt).content
    scale = parse_scale(scale)
    res_scale_table[item['table']['uid']] = scale
# Out:
# 0it [00:00, ?it/s]

# %%
res_scale = {}
for idx, item in log_progress(devdf.iterrows()): 
    #item = devdf.iloc[2]
    table = item['table']['table']
    pars = [p['text'] for p in item['paragraphs']]
    prompt = f"The context contains some paragraphs that describe a table. Search for text that explicitly states the scale of the values in the table. Scale can be abbreviated in tables. in response use scale  million, thousand, billion or none, if no scale contains exactly in the text. Do NOT try to infer it from values.  \nParagraphs: {pars} \nTable: {table}"
    scale = llm.invoke(prompt).content
    scale = parse_scale(scale)
    res_scale[item['table']['uid']] = scale
# Out:
# 0it [00:00, ?it/s]

# %%
res = []
good = 0
pct = 0
cnt = 0
for idx, item in devdf.iterrows():
    for q in item['questions']:        
        if q['answer_type'] == 'arithmetic' and 'table' in q['answer_from']: 
            if not item['table']['uid'] in res_scale:
                continue
            if q['scale'] in res_scale[item['table']['uid']]:
                good = good + 1
            elif q['scale'] != 'percent':
# 4c5a0a4f-9e3f-434f-831b-530327547a01  million
# b56cfe42-d808-4b3e-8f81-83acafb052f4 thousand million
# 6ce427fa-d1ff-481d-b6ba-7950d43e7c22  billion
# c8ed0bf6-60c5-41e2-97e3-5ece54a1349b  none
# 0.33760683760683763 206 259 702 237

# %%
res_scale_pct = {}
for idx, item in log_progress(devdf.iterrows()): 
    #item = devdf.iloc[2]
    table = item['table']['table']
    pars = [p['text'] for p in item['paragraphs']]
    for q in item['questions']:        
        if q['answer_type'] == 'arithmetic' and 'table' in q['answer_from']: 
            prompt = f"Classify the following question. Is it about percentage calculation?  Please answer with one word, yes or no.  \nQuestion: {q['question']}"
            scale = llm.invoke(prompt).content
            res_scale_pct[q['uid']] = {'percent':scale, 'golden_scale': q['scale']}
# Out:
# 0it [00:00, ?it/s]

# %%
res = []
good = 0
pct = 0
cnt = 0
for idx, item in devdf.iterrows():
    for q in item['questions']: 
        if not q['uid'] in res_scale_pct:
            continue
        if q['answer_type'] == 'arithmetic' and 'table' in q['answer_from']: 
            if( q['scale'] == 'percent' and res_scale_pct[q['uid']]['percent'] == 'Yes')or  (q['scale'] != 'percent' and res_scale_pct[q['uid']]['percent'] == 'No') :
                good = good + 1
            else:
                None
                #print(q['scale'], res_scale_pct[q['uid']] )
            cnt = cnt + 1
print(  (cnt -good-pct)/cnt, good, pct, cnt, cnt -good-pct)
# Out:
# 0.10968660968660969 625 0 702 77

# %%
res_scale_pct
# Out:
# {'eb787966-fa02-401f-bfaf-ccabf3828b23': {'percent': 'No',
#   'golden_scale': 'million'},
#  '05b670d3-5b19-438c-873f-9bf6de29c69e': {'percent': 'Yes',
#   'golden_scale': 'percent'},
#  'b2786c1a-37de-4120-b03c-32bf5c81f157': {'percent': 'No',
#   'golden_scale': 'million'},
#  'fe11f001-3bfe-4089-8108-412676f0a780': {'percent': 'Yes',
#   'golden_scale': 'percent'},
#  '5103aed0-b4e8-4fae-bf78-e2c9f4ba84cf': {'percent': 'No',
#   'golden_scale': 'percent'},
#  '4dc8be43-d8d9-4b08-9ffd-9c19012361ce': {'percent': 'Yes',
#   'golden_scale': 'percent'},
#  '6c44a1a8-0785-43a0-90ab-7e21df2c57d9': {'percent': 'No',
#   'golden_scale': 'percent'},
#  'a0414f81-8dc2-44b2-a441-2c9d9c805c4d': {'percent': 'No',
#   'golden_scale': 'million'},
#  'bf7abd62-d9cd-48d2-8826-1457684019a3': {'percent': 'No',
#   'golden_scale': 'million'},
#  '4d259081-6da6-44bd-8830-e4de0031744c': {'percent': 'No',
#   'golden_scale': 'million'},
#  'bed1fce2-69cb-4d1e-a34a-01950a1770bd': {'percent': 'Yes',
#   'golden_scale': 'percent'},
#  '348d031d-73ab-4b35-af46-998cfef25775': {'percent': 'No',
#   'golden_scale': 'percent'},
#  'aea850af-68cb-4cc1-80b2-c9c2860b273e': {'percent': 'No',
#   'golden_scale': 'percent'},
#  'ba6783f3-8207-419a-b407-3f688682caef': {'percent': 'No', 'golden_scale': ''},
#  '263d03ec-83d2-48df-8376-1a72167798f7': {'percent': 'No', 'golden_scale': ''},
#  '78fc6d55-c20c-4f71-99fe-bc40a16e61d0': {'percent': 'No', 'golden_scale': ''},
#  '35d602ae-9131-4291-a30c-49a40f32bbe4': {'percent': 'No',
#   'golden_scale': 'thousand'},
#  'a4f782f1-de3b-47a3-87af-1cb33c112b39': {'percent': 'Yes',
#   'golden_scale': 'percent'},
#  
#  '3b8e873e-64d5-4af0-904f-7197dc632773': {'percent': 'No',
#   'golden_scale': 'million'}}

# %%
res = []
good = 0
pct = 0
cnt = 0
for idx, item in devdf.iterrows():
    for q in item['questions']:        
        if q['answer_type'] == 'arithmetic' and 'table' in q['answer_from']: 
            if q['scale'] == res_scale_table[item['table']['uid']]:
                good = good + 1
            elif q['scale'] != 'percent':
                print(q['uid'],'\t',  q['scale'], res_scale_table[item['table']['uid']],'\t',  res_scale_para[item['table']['uid']])
            else:
                pct = pct +1
            cnt = cnt+1
print(  (cnt -good-pct)/cnt, good, pct, cnt, cnt -good-pct)
# Out:
# eb787966-fa02-401f-bfaf-ccabf3828b23 	 million none 	 million
# ba6783f3-8207-419a-b407-3f688682caef 	  million 	 million
# 263d03ec-83d2-48df-8376-1a72167798f7 	  million 	 million
# 78fc6d55-c20c-4f71-99fe-bc40a16e61d0 	  million 	 million
# 35d602ae-9131-4291-a30c-49a40f32bbe4 	 thousand million 	 thousand
# 4f7c8e0a-6ae9-40ee-bd16-06db6f96eaf1 	  million 	 million
# 191c3926-7356-4ab8-a8f9-41e7b7c8a492 	 thousand none 	 million
# bd2d81eb-46fc-4e62-908d-aebfccf46246 	 thousand none 	 million
# 010df393-a62e-408d-888a-045a4e435e6a 	 thousand none 	 million
# 096680e3-c65a-49cc-9339-55abdafd4a38 	 thousand million 	 thousand
# b7ac671c-e199-4a3c-af2e-c33c6e90924a 	 thousand million 	 thousand
# 73693527-ed4b-4d07-941e-0e654095a43d 	  million 	 million
# 03de2d3b-2e3d-425f-8f59-7dfca536488e 	  million 	 1
# 1238d807-aa57-48a3-93b6-591873788625 	 thousand none 	 million
# ef9d4839-5277-4614-bb73-f902fd8a38b6 	 thousand none 	 million
# 1e20b997-cb3b-4bc5-93e6-b45dbe945fb5 	 thousand million 	 percent
# d2969c34-708e-4ab0-8e21-32c0b18c544c 	  thousand 	 thousand
# 59f13f19-4494-4c54-8e9a-1b499d50021a 	  thousand 	 million
# b382a11b-749b-425a-a77d-20e943e00f77 	  thousand 	 million
# 741f8b2e-9312-4426-893d-69b99fab247b 	  thousand 	 million
# c79e02ff-37fd-4adf-9144-890d2562209f 	 thousand none 	 million
# 7c199dce-cde4-4685-93cb-f7f8f7ee1e5a 	 thousand million 	 thousand
# f3c2a0c3-eb77-4161-94e3-98ca2740e978 	 thousand none 	 thousand
# f1034ee7-b182-48d5-bad8-1d9902500f57 	  million 	 1
# 545cb01f-9b10-4a1b-8a7c-e9e74e725b26 	  million 	 1
# 56a014a9-5b9c-41e5-9523-ebbd3a01dd6d 	  million 	 1
# 2af4c7cf-79a2-4bdf-81b8-dbaff5081bc3 	  million 	 1
# 856c56ac-e6f5-4cfc-8f29-69f67dc717da 	  million 	 1
# 711441b9-5999-469a-921c-954d7e19e41c 	 thousand none 	 thousand
# d53d179b-a28e-4c5b-8817-fb6b7f843327 	 thousand none 	 thousand
# 28054524-2ce6-426c-bc87-3d61d4d73112 	 thousand none 	 thousand
# b20228d3-316b-4831-b58e-6772e768e5e1 	 thousand none 	 thousand
# 32cbd9ff-637d-4b5f-b10b-92243f2e1a93 	  thousand 	 million
# 229a9319-d8af-41d2-b1ad-4904c820de98 	  none 	 1
# 26971fd2-ea63-4009-a394-b38d7cca0f97 	  none 	 1
# 9579685b-84d4-40e9-85d7-ff61a8695d32 	  none 	 1
# 11708d2a-0e19-4feb-b687-fe2785da2b95 	  none 	 million
# 27a2fcde-d7aa-4fd6-af85-cbff18d62cd9 	 thousand million 	 thousand
# f9c8ce19-71ce-48aa-b3f3-9414d7112a4b 	  million 	 million
# 56d8d92f-a555-4a26-a2ec-3dc9ad9795eb 	 million none 	 million
# 33d6e35e-0c0d-4234-99ce-2df83034136e 	 thousand million 	 thousand
# 3f231d7d-30d1-489c-b02e-d265431a3796 	 thousand million 	 thousand
# 0836e3af-9278-4cef-abdd-eaa0166a6503 	 thousand million 	 thousand
# 42ad68ec-7bc2-4fc5-993b-6e09ef7c666e 	 thousand million 	 million
# d3ebc6d6-6f38-403f-86cd-d405245d4da3 	 thousand none 	 thousand
# 266458b4-d4fe-43ed-8962-4c319363dde4 	 thousand million 	 thousand
# ba16499f-3c96-4faa-81b0-874f9ace7c8c 	  none 	 million
# 89e21fa8-60b1-4f4f-be8d-497733907f52 	 million none 	 million
# 14beaf69-31ed-4967-99b0-132a760d9ede 	 thousand none 	 thousand
# 8de2ed8c-c548-4bb9-982c-5d714675b443 	  none 	 million
# 1521cfda-5529-46c8-bdb2-d618e4a83b78 	  million 	 million
# 843a60c0-ee9c-49d6-8f7f-5347af1b238c 	  million 	 million
# eccadabb-b970-47f6-8537-27907d2408c6 	  million 	 million
# 36c5a475-701d-4115-a479-cee5ea42f947 	 thousand none 	 million
# c36d505f-cdc1-43c2-891f-d83cb7499d0d 	 thousand none 	 million
# 803799b7-519c-4ca2-8e72-a76fe69b2e6a 	  million 	 1
# 4c5a0a4f-9e3f-434f-831b-530327547a01 	  million 	 1
# 6ce427fa-d1ff-481d-b6ba-7950d43e7c22 	  million 	 million
# c50b6cab-faba-4d38-83da-62d564141452 	 thousand none 	 thousand
# 1352b9c0-2cca-432e-807e-08580574f3a8 	 thousand none 	 thousand
# 8a3fb2be-150b-410f-a6d5-f3a3dd1fdba3 	 thousand million 	 thousand
# 4b0f29ae-4a97-400c-9497-47440a02ebdd 	 thousand million 	 thousand
# c8ed0bf6-60c5-41e2-97e3-5ece54a1349b 	  million 	 1
# 0.31339031339031337 223 259 702 220

# %%
item = devdf.iloc[0]
table = item['table']['table']
pars = [p['text'] for p in item['paragraphs']]
question = item['questions'][4]['question']
( prompt, code) = gen_code(llm, question, table, pars)
res = exec_code(code, table)
print(code, res)
# Out:
# (-12.6, '')
# def run():
#     table = [['', '', 'Years Ended September 30,', ''], ['', '2019', '2018', '2017'], ['Fixed Price', '  1452.4', '  1146.2', '  1036.9'], ['Other', '44.1', '56.7', '70.8'], ['Total sales', '1496.5', '1202.9', '1107.7']]
#
#     sales_2019 = float(table[3][1])
#     sales_2018 = float(table[3][2])
#
#     change = sales_2019 - sales_2018
#
#     return round(change, 2), ''
#
#
# # Test the function
# print(run()) (-12.6, '')

# %%
def gen_code(llm, question, table):    
    prompt = f"Generate a Python function that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Scale usually is 'thousand','million' or empty string, but sometimes it is percent. Do not write explanation, just code.\nQuestion: {question} \n Table: {table}"
    prompt = remove_thousand_separators(prompt)
    #prompt = replace_bracketed_numbers(prompt)
    prompt = prompt.replace('$','') 
    res = llm.invoke(prompt)
    code = res.content.replace('```python','').replace('```','')
    return (prompt, code)

def exec_code(code, table):  
    table = remove_thousand_separators(f"{table}")
    #table = replace_bracketed_numbers(table)
    table = table.replace('$','')
    #code = code.replace("* 1000000","").replace("*1000000","").replace("/ 1000000","").replace("/1000000","").replace("/ 1000","").replace("/1000","")
    #code = code.replace('abs(','(')
    try: 
        loc = locals()   
        if not "run()" in code:
            exec(code + f"\nr = run({table})\n", globals(), loc)
        else: 
            exec(code + "\nr = run()\n", globals(), loc)
        return loc['r']
    except Exception as e:
            s = '[Error]'+ str(e)
            print(s)
            return (s,'')
#table = "[['', '', 'Years Ended September 30,', ''], ['', '2019', '2018', '2017'], ['Fixed Price', '$  1,452.4', '$  1,146.2', '$  1,036.9'], ['Other', '44.1', '56.7', '70.8'], ['Total sales', '$1,496.5', '$1,202.9', '$1,107.7']]"
#question = 'What is the change in Fixed Price in 2019 from 2018?'
table = "[['', 'December 31,', ''], ['', '2019', '2018'], ['Trade accounts receivable, net, noncurrent (Note 2)', '$26,496', '$15,948'], ['Equity method investments (Note 1)', '9,254', '9,702'], ['Net deferred tax assets, noncurrent (Note 20)', '6,774', '5,797'], ['Rent and other deposits', '6,106', '5,687'], ['Value added tax receivables, net, noncurrent', '592', '519'], ['Other', '6,723', '5,711'], ['', '$55,945', '$43,364']]"
#table = remove_thousand_separators(table)
print(table)
question = 'What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018?'
( prompt, code) = gen_code(llm, question, table)
res = exec_code(code, table)
print(code, res)

# %%
question
# Out:
# 'What is the change in Other in 2019 from 2018?'

# %%
from tqdm.notebook import tqdm as log_progress

res = []
for i, item in log_progress(devdf.iterrows()):
    table = item['table']['table']
    pars = [p['text'] for p in item['paragraphs']]
    #table = transform_elements(table, remove_thousand_separators)
    #table = [remove_thousand_separators(cell) for row in table for cell in row]
    #table = [cell.replace('$', '') for row in table for cell in row]
    #print (table)
    for q in item['questions']:        
        if q['answer_type'] == 'arithmetic' and 'table' in q['answer_from']:             
            ( prompt, code)  = gen_code(llm, q['question'], table, pars)
            r = exec_code(code, table)
            err =  None
            if r is None:
                (pred_value, pred_unit) = ("", "")
            else:                
                if len(r) == 2:
                    (pred_value, pred_unit) = r    
                    if pred_unit == "%":
                        pred_unit = 'percent'
                    if pred_unit == "€m" or pred_unit == "£m":
                        pred_unit = 'million'
                    if pred_unit not in ["", 'thousand', 'million', 'billion', 'percent']:
                        print('Invalid ', pred_unit)
                        pred_unit = ""                        
                    if isinstance(pred_value, tuple) and len(pred_value) == 2:
                         (pred_value, pred_unit) = pred_value 
                    if isinstance(pred_value, str):
                        print("string")
                        if  pred_value.startswith('[Error]'):
                            (pred_value, pred_unit) = ("", "")
                            err,_ = r                                                        
                        
                elif len(r) == 1:
                    (pred_value, pred_unit) = (r, "")        
                else:
                    (pred_value, pred_unit) = ("", "")        
                
            #res.append({"table":table, "q":q, "pred":pred, "code": code})
            res.append(({"answer_type":q["answer_type"], "answer": q["answer"], 'scale': q["scale"]}, pred_value, pred_unit, q, code, prompt, item['table'], err))
# Out:
# 0it [00:00, ?it/s]
# [Error]run() missing 1 required positional argument: 'paragraphs'
# string
# (3.1, 'percent')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 13
#      11 for q in item['questions']:
#      12     if q['answer_type'] == 'arithmetic' and 'table' in q['answer_from']:
# ---> 13         ( prompt, code)  = gen_code(llm, q['question'], table, pars)
#      14         r = exec_code(code, table)
#      15         err =  None
#
# Cell In[58], line 6, in gen_code(llm, question, table, paragraphs)
#       4 #prompt = replace_bracketed_numbers(prompt)
#       5 prompt = prompt.replace('$','')
# ----> 6 res = llm.invoke(prompt)
#       7 code = res.content.replace('```python','').replace('```','')
#       8 return (prompt, code)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:286, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     275 def invoke(
#     276     self,
#     277     input: LanguageModelInput,
#    (...)
#     281     **kwargs: Any,
#     282 ) -> BaseMessage:
#     283     config = ensure_config(config)
#     284     return cast(
#     285         ChatGeneration,
# --> 286         self.generate_prompt(
#     287             [self._convert_input(input)],
#     288             stop=stop,
#     289             callbacks=config.get("callbacks"),
#     290             tags=config.get("tags"),
#     291             metadata=config.get("metadata"),
#     292             run_name=config.get("run_name"),
#     293             run_id=config.pop("run_id", None),
#     294             **kwargs,
#     295         ).generations[0][0],
#     296     ).message
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:683, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     681     generation_info = {"headers": dict(raw_response.headers)}
#     682 else:
# --> 683     response = self.client.create(**payload)
#     684 return self._create_chat_result(response, generation_info)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/openai/_utils/_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/openai/resources/chat/completions.py:742, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     704 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     705 def create(
#     706     self,
#    (...)
#     739     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     740 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     741     validate_response_format(response_format)
# --> 742     return self._post(
#     743         "/chat/completions",
#     744         body=maybe_transform(
#     745             {
#     746                 "messages": messages,
#     747                 "model": model,
#     748                 "frequency_penalty": frequency_penalty,
#     749                 "function_call": function_call,
#     750                 "functions": functions,
#     751                 "logit_bias": logit_bias,
#     752                 "logprobs": logprobs,
#     753                 "max_completion_tokens": max_completion_tokens,
#     754                 "max_tokens": max_tokens,
#     755                 "metadata": metadata,
#     756                 "n": n,
#     757                 "parallel_tool_calls": parallel_tool_calls,
#     758                 "presence_penalty": presence_penalty,
#     759                 "response_format": response_format,
#     760                 "seed": seed,
#     761                 "service_tier": service_tier,
#     762                 "stop": stop,
#     763                 "store": store,
#     764                 "stream": stream,
#     765                 "stream_options": stream_options,
#     766                 "temperature": temperature,
#     767                 "tool_choice": tool_choice,
#     768                 "tools": tools,
#     769                 "top_logprobs": top_logprobs,
#     770                 "top_p": top_p,
#     771                 "user": user,
#     772             },
#     773             completion_create_params.CompletionCreateParams,
#     774         ),
#     775         options=make_request_options(
#     776             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     777         ),
#     778         cast_to=ChatCompletion,
#     779         stream=stream or False,
#     780         stream_cls=Stream[ChatCompletionChunk],
#     781     )
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/openai/_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/openai/_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/openai/_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     987 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#     996     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File /opt/conda/envs/arpad_tab/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
from tatqa_metric import TaTQAEmAndF1

metrics = TaTQAEmAndF1()

for ans, pred, pred_scale, _,_, _,_,_ in res:
    metrics(ans, pred, pred_scale)
pred_em, pred_f1, scale_score, op_score = metrics.get_overall_metric(reset=False)
print( pred_em, pred_f1, scale_score)
# Out:
# 0.5384615384615384 0.5384615384615384 0.7884615384615384

# %%
[m for m in metrics._details if m['f1']<0.2]
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [178.67],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [57.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [109],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.1,
#   'scale': 'percent',
#   'pred': [-25.1],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.93,
#   'scale': '',
#   'pred': [2.93],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [0.87],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-11.93],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [4411.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [367],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [18820.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [-16458],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [21.95],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': '',
#   'pred': [0.7],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35796,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 62740,
#   'scale': 'thousand',
#   'pred': [55442],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14212,
#   'scale': 'thousand',
#   'pred': [10804],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0,
#   'scale': 'percent',
#   'pred': 0.0,
#   'pred_scale': 'percent',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': 'percent',
#   'pred': [3.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -9.9,
#   'scale': 'percent',
#   'pred': [-9.9],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.86],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2487.08,
#   'scale': 'percent',
#   'pred': [58.47],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61.6,
#   'scale': 'million',
#   'pred': [50.66],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -78.06,
#   'scale': 'percent',
#   'pred': [3.1],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]

# %%
good = 0
for ans, pred, pred_scale, q,code, _,table,err in res:
    llimit = ans['answer']*0.99
    ulimit = ans['answer']*1.01
    
    if pred  is None or isinstance(pred, tuple) or isinstance(pred, str):
        #if ans['scale'] != pred_scale:
        #    print ('***********', q['uid'], 'pred: ',pred, 'scale:',pred_scale, ' <> ' , ans['answer'], ans['scale'])
       
        #type error
        #if isinstance(pred, str):
        #    print (pred, pred_scale, ' -- ' , ans['answer'])
        #if isinstance(pred, tuple):
        #    print (pred, pred_scale, ' == ' , ans['answer'], ans['scale'])
        #print('===============================================================================')
        print('{',pred, '}', ans['answer'], ans['scale'], err)
        continue
    
    #pred = round(pred, 2)
    
    if (pred > 0 and llimit < pred and pred < ulimit) or (pred < 0 and llimit > pred and pred > ulimit) or pred==ulimit or pred == llimit:
        good = good + 1
        if ans['scale'] == pred_scale and  pred_scale == 'thousand':
            print ('***********', q['uid'], 'pred: ',pred, 'scale:',pred_scale, ' == ' , ans['answer'], ans['scale'])
        
        #if ans['scale'] != pred_scale:
        #    print ('***********', q['uid'], 'pred: ',pred, 'scale:',pred_scale, ' <> ' , ans['answer'], ans['scale'])
        #if  ans['scale'] == 'thousand':
        #    print (q['uid'], pred, pred_scale, ' == ' , ans['answer'], ans['scale'])
          
    else:
        #value error
        #  if ans['scale'] != pred_scale:
        #    print ('***********', q['uid'], 'pred: ',pred, 'scale:',pred_scale, ' <> ' , ans['answer'], ans['scale'])
        #if ans['answer'] != pred and ans['scale'] == pred_scale and pred_scale != "":
        #    print ('***********', q['uid'], 'pred: ',pred, 'scale:',pred_scale, ' <> ' , ans['answer'], ans['scale'])
       
        None
        #print (q['uid'], pred, pred_scale, ' <> ' , ans['answer'], ans['scale'])
        #print(q['question'])
        #print(table['table'])
        #print(code)
        
    #if isinstance(pred, str):
    #    print (pred, pred_scale, ' -- ' , ans['answer'])
    #if isinstance(pred, tuple):
    #    print (pred, pred_scale, ' == ' , ans['answer'], ans['scale'])
        
print (good/len(res))
# Out:
# *********** 35d602ae-9131-4291-a30c-49a40f32bbe4 pred:  73.0 scale: thousand  ==  73 thousand
# {  } 35796 million [Error]run() missing 1 required positional argument: 'paragraphs'
# *********** 191c3926-7356-4ab8-a8f9-41e7b7c8a492 pred:  64509 scale: thousand  ==  64509 thousand
# *********** 096680e3-c65a-49cc-9339-55abdafd4a38 pred:  70056 scale: thousand  ==  70056 thousand
# *********** b7ac671c-e199-4a3c-af2e-c33c6e90924a pred:  67210 scale: thousand  ==  67210 thousand
# 0.6730769230769231

# %%
res
# Out:
# [({'answer_type': 'arithmetic', 'answer': -12.6, 'scale': 'million'},
#   -12.6,
#   'million',
#   {'uid': 'eb787966-fa02-401f-bfaf-ccabf3828b23',
#    'order': 5,
#    'question': 'What is the change in Other in 2019 from 2018?',
#    'answer': -12.6,
#    'derivation': '44.1-56.7',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['2'],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    value = -12.6\n    scale = 'million'\n    return (value, scale)",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'eb787966-fa02-401f-bfaf-ccabf3828b23', 'order': 5, 'question': 'What is the change in Other in 2019 from 2018?', 'answer': -12.6, 'derivation': '44.1-56.7', 'answer_type': 'arithmetic', 'answer_from': 'table-text', 'rel_paragraphs': ['2'], 'req_comparison': False, 'scale': 'million'} \n Table: [['', '', 'Years Ended September 30,', ''], ['', '2019', '2018', '2017'], ['Fixed Price', '  1452.4', '  1146.2', '  1036.9'], ['Other', '44.1', '56.7', '70.8'], ['Total sales', '1496.5', '1202.9', '1107.7']]",
#   {'uid': '3ffd9053-a45d-491c-957a-1b2fa0af0570',
#    'table': [['', '', 'Years Ended September 30,', ''],
#     ['', '2019', '2018', '2017'],
#     ['Fixed Price', '$  1,452.4', '$  1,146.2', '$  1,036.9'],
#     ['Other', '44.1', '56.7', '70.8'],
#     ['Total sales', '$1,496.5', '$1,202.9', '$1,107.7']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -22.22, 'scale': 'percent'},
#   -22.22,
#   'percent',
#   {'uid': '05b670d3-5b19-438c-873f-9bf6de29c69e',
#    'order': 6,
#    'question': 'What is the percentage change in Other in 2019 from 2018?',
#    'answer': -22.22,
#    'derivation': '(44.1-56.7)/56.7',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['2'],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    result = round(((44.1 - 56.7) / 56.7) * 100, 2)\n    return (result, 'percent')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '05b670d3-5b19-438c-873f-9bf6de29c69e', 'order': 6, 'question': 'What is the percentage change in Other in 2019 from 2018?', 'answer': -22.22, 'derivation': '(44.1-56.7)/56.7', 'answer_type': 'arithmetic', 'answer_from': 'table-text', 'rel_paragraphs': ['2'], 'req_comparison': False, 'scale': 'percent'} \n Table: [['', '', 'Years Ended September 30,', ''], ['', '2019', '2018', '2017'], ['Fixed Price', '  1452.4', '  1146.2', '  1036.9'], ['Other', '44.1', '56.7', '70.8'], ['Total sales', '1496.5', '1202.9', '1107.7']]",
#   {'uid': '3ffd9053-a45d-491c-957a-1b2fa0af0570',
#    'table': [['', '', 'Years Ended September 30,', ''],
#     ['', '2019', '2018', '2017'],
#     ['Fixed Price', '$  1,452.4', '$  1,146.2', '$  1,036.9'],
#     ['Other', '44.1', '56.7', '70.8'],
#     ['Total sales', '$1,496.5', '$1,202.9', '$1,107.7']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -94, 'scale': 'million'},
#   -94,
#   'million',
#   {'uid': 'b2786c1a-37de-4120-b03c-32bf5c81f157',
#    'order': 5,
#    'question': 'What was the change in the amount for Appliances in 2019 from 2018?',
#    'answer': -94,
#    'derivation': '680-774',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    change = 680 - 774\n    return (change, 'million') \n\n# Output: (-94, 'million')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'b2786c1a-37de-4120-b03c-32bf5c81f157', 'order': 5, 'question': 'What was the change in the amount for Appliances in 2019 from 2018?', 'answer': -94, 'derivation': '680-774', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'million'} \n Table: [['', '', 'Fiscal', ''], ['', '2019', '2018', '2017'], ['', '', '(in millions)', ''], ['Transportation Solutions:', '', '', ''], ['Automotive', ' 5686', ' 6092', '  5228'], ['Commercial transportation', '1221', '1280', '997'], ['Sensors', '914', '918', '814'], ['Total Transportation Solutions', '7821', '8290', '7039'], ['Industrial Solutions:', '', '', ''], ['Industrial equipment', '1949', '1987', '1747'], ['Aerospace, defense, oil, and gas', '1306', '1157', '1075'], ['Energy', '699', '712', '685'], ['Total Industrial Solutions', '3954', '3856', '3507'], ['Communications Solutions:', '', '', ''], ['Data and devices', '993', '1068', '963'], ['Appliances', '680', '774', '676'], ['Total Communications Solutions', '1673', '1842', '1639'], ['Total', ' 13448', ' 13988', ' 12185']]",
#   {'uid': '53474060-2736-46cb-bd97-1eb42f0ff3c1',
#    'table': [['', '', 'Fiscal', ''],
#     ['', '2019', '2018', '2017'],
#     ['', '', '(in millions)', ''],
#     ['Transportation Solutions:', '', '', ''],
#     ['Automotive', '$ 5,686', '$ 6,092', '$  5,228'],
#     ['Commercial transportation', '1,221', '1,280', '997'],
#     ['Sensors', '914', '918', '814'],
#     ['Total Transportation Solutions', '7,821', '8,290', '7,039'],
#     ['Industrial Solutions:', '', '', ''],
#     ['Industrial equipment', '1,949', '1,987', '1,747'],
#     ['Aerospace, defense, oil, and gas', '1,306', '1,157', '1,075'],
#     ['Energy', '699', '712', '685'],
#     ['Total Industrial Solutions', '3,954', '3,856', '3,507'],
#     ['Communications Solutions:', '', '', ''],
#     ['Data and devices', '993', '1,068', '963'],
#     ['Appliances', '680', '774', '676'],
#     ['Total Communications Solutions', '1,673', '1,842', '1,639'],
#     ['Total', '$ 13,448', '$ 13,988', '$ 12,185']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -12.14, 'scale': 'percent'},
#   -12.14,
#   'percent',
#   {'uid': 'fe11f001-3bfe-4089-8108-412676f0a780',
#    'order': 6,
#    'question': 'What was the percentage change in the amount for Appliances in 2019 from 2018?',
#    'answer': -12.14,
#    'derivation': '(680-774)/774',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    percentage_change = round(((680 - 774) / 774) * 100, 2)\n    return (percentage_change, 'percent')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'fe11f001-3bfe-4089-8108-412676f0a780', 'order': 6, 'question': 'What was the percentage change in the amount for Appliances in 2019 from 2018?', 'answer': -12.14, 'derivation': '(680-774)/774', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'percent'} \n Table: [['', '', 'Fiscal', ''], ['', '2019', '2018', '2017'], ['', '', '(in millions)', ''], ['Transportation Solutions:', '', '', ''], ['Automotive', ' 5686', ' 6092', '  5228'], ['Commercial transportation', '1221', '1280', '997'], ['Sensors', '914', '918', '814'], ['Total Transportation Solutions', '7821', '8290', '7039'], ['Industrial Solutions:', '', '', ''], ['Industrial equipment', '1949', '1987', '1747'], ['Aerospace, defense, oil, and gas', '1306', '1157', '1075'], ['Energy', '699', '712', '685'], ['Total Industrial Solutions', '3954', '3856', '3507'], ['Communications Solutions:', '', '', ''], ['Data and devices', '993', '1068', '963'], ['Appliances', '680', '774', '676'], ['Total Communications Solutions', '1673', '1842', '1639'], ['Total', ' 13448', ' 13988', ' 12185']]",
#   {'uid': '53474060-2736-46cb-bd97-1eb42f0ff3c1',
#    'table': [['', '', 'Fiscal', ''],
#     ['', '2019', '2018', '2017'],
#     ['', '', '(in millions)', ''],
#     ['Transportation Solutions:', '', '', ''],
#     ['Automotive', '$ 5,686', '$ 6,092', '$  5,228'],
#     ['Commercial transportation', '1,221', '1,280', '997'],
#     ['Sensors', '914', '918', '814'],
#     ['Total Transportation Solutions', '7,821', '8,290', '7,039'],
#     ['Industrial Solutions:', '', '', ''],
#     ['Industrial equipment', '1,949', '1,987', '1,747'],
#     ['Aerospace, defense, oil, and gas', '1,306', '1,157', '1,075'],
#     ['Energy', '699', '712', '685'],
#     ['Total Industrial Solutions', '3,954', '3,856', '3,507'],
#     ['Communications Solutions:', '', '', ''],
#     ['Data and devices', '993', '1,068', '963'],
#     ['Appliances', '680', '774', '676'],
#     ['Total Communications Solutions', '1,673', '1,842', '1,639'],
#     ['Total', '$ 13,448', '$ 13,988', '$ 12,185']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 2.1, 'scale': 'percent'},
#   2.1,
#   'percent',
#   {'uid': '5103aed0-b4e8-4fae-bf78-e2c9f4ba84cf',
#    'order': 4,
#    'question': 'What is the difference between the domestic and international discount rates as at September 30, 2019?',
#    'answer': 2.1,
#    'derivation': '4.00 - 1.90 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    domestic_discount_rate = 4.00\n    international_discount_rate = 1.90\n    difference = round(domestic_discount_rate - international_discount_rate, 2)\n    return (difference, 'percent')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '5103aed0-b4e8-4fae-bf78-e2c9f4ba84cf', 'order': 4, 'question': 'What is the difference between the domestic and international discount rates as at September 30, 2019?', 'answer': 2.1, 'derivation': '4.00 - 1.90 ', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'percent'} \n Table: [['', 'Domestic', '', 'International', ''], ['', 'September 30,', '', 'September 30,', ''], ['', '2019', '2018', '2019', '2018'], ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'], ['Expected return on plan assets', '', '', '3.40%', '3.70%'], ['Rate of compensation increase', '', '', '- - %', '- - %']]",
#   {'uid': '52164b70-6973-4844-af6a-76e8f1298d64',
#    'table': [['', 'Domestic', '', 'International', ''],
#     ['', 'September 30,', '', 'September 30,', ''],
#     ['', '2019', '2018', '2019', '2018'],
#     ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'],
#     ['Expected return on plan assets', '', '', '3.40%', '3.70%'],
#     ['Rate of compensation increase', '', '', '- - %', '- - %']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 6.67, 'scale': 'percent'},
#   6.67,
#   'percent',
#   {'uid': '4dc8be43-d8d9-4b08-9ffd-9c19012361ce',
#    'order': 5,
#    'question': 'What is the year on year percentage change in domestic discount rate between 2018 and 2019?',
#    'answer': 6.67,
#    'derivation': '(4.00 - 3.75)/3.75 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    result = (6.67, 'percent')\n    return result",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '4dc8be43-d8d9-4b08-9ffd-9c19012361ce', 'order': 5, 'question': 'What is the year on year percentage change in domestic discount rate between 2018 and 2019?', 'answer': 6.67, 'derivation': '(4.00 - 3.75)/3.75 ', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'percent'} \n Table: [['', 'Domestic', '', 'International', ''], ['', 'September 30,', '', 'September 30,', ''], ['', '2019', '2018', '2019', '2018'], ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'], ['Expected return on plan assets', '', '', '3.40%', '3.70%'], ['Rate of compensation increase', '', '', '- - %', '- - %']]",
#   {'uid': '52164b70-6973-4844-af6a-76e8f1298d64',
#    'table': [['', 'Domestic', '', 'International', ''],
#     ['', 'September 30,', '', 'September 30,', ''],
#     ['', '2019', '2018', '2019', '2018'],
#     ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'],
#     ['Expected return on plan assets', '', '', '3.40%', '3.70%'],
#     ['Rate of compensation increase', '', '', '- - %', '- - %']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -8.11, 'scale': 'percent'},
#   -191.89,
#   'percent',
#   {'uid': '6c44a1a8-0785-43a0-90ab-7e21df2c57d9',
#    'order': 6,
#    'question': 'What is the year on year percentage change in international expected return on plan assets between 2018 and 2019?',
#    'answer': -8.11,
#    'derivation': '(3.40 - 3.70)/3.70 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    result = (-3.70 - 3.40) / 3.70 * 100\n    return round(result, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '6c44a1a8-0785-43a0-90ab-7e21df2c57d9', 'order': 6, 'question': 'What is the year on year percentage change in international expected return on plan assets between 2018 and 2019?', 'answer': -8.11, 'derivation': '(3.40 - 3.70)/3.70 ', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'percent'} \n Table: [['', 'Domestic', '', 'International', ''], ['', 'September 30,', '', 'September 30,', ''], ['', '2019', '2018', '2019', '2018'], ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'], ['Expected return on plan assets', '', '', '3.40%', '3.70%'], ['Rate of compensation increase', '', '', '- - %', '- - %']]",
#   {'uid': '52164b70-6973-4844-af6a-76e8f1298d64',
#    'table': [['', 'Domestic', '', 'International', ''],
#     ['', 'September 30,', '', 'September 30,', ''],
#     ['', '2019', '2018', '2019', '2018'],
#     ['Discount rate', '4.00%', '3.75%', '1.90%', '2.80%'],
#     ['Expected return on plan assets', '', '', '3.40%', '3.70%'],
#     ['Rate of compensation increase', '', '', '- - %', '- - %']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 172, 'scale': 'million'},
#   172,
#   'million',
#   {'uid': 'a0414f81-8dc2-44b2-a441-2c9d9c805c4d',
#    'order': 4,
#    'question': 'What is the 2019 average defined contribution schemes?',
#    'answer': 172,
#    'derivation': '(166+178)/2',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    result = (172, 'million')\n    return result",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'a0414f81-8dc2-44b2-a441-2c9d9c805c4d', 'order': 4, 'question': 'What is the 2019 average defined contribution schemes?', 'answer': 172, 'derivation': '(166+178)/2', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'million'} \n Table: [['Income statement expense', '', '', ''], ['', '2019 €m', '2018 €m', '2017 €m'], ['Defined contribution schemes', '166', '178', '192'], ['Defined benefit schemes', '57', '44', '20'], ['Total amount charged to income statement (note 23)', '223', '222', '212']]",
#   {'uid': '6bf238a5-0a3e-492d-91f8-7f62d3b37fba',
#    'table': [['Income statement expense', '', '', ''],
#     ['', '2019 €m', '2018 €m', '2017 €m'],
#     ['Defined contribution schemes', '166', '178', '192'],
#     ['Defined benefit schemes', '57', '44', '20'],
#     ['Total amount charged to income statement (note 23)',
#      '223',
#      '222',
#      '212']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 50.5, 'scale': 'million'},
#   50.5,
#   'million',
#   {'uid': 'bf7abd62-d9cd-48d2-8826-1457684019a3',
#    'order': 5,
#    'question': 'What is the 2019 average defined benefit schemes?',
#    'answer': 50.5,
#    'derivation': '(57+44)/2',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    result = 50.5\n    scale = 'million'\n    return (result, scale)",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'bf7abd62-d9cd-48d2-8826-1457684019a3', 'order': 5, 'question': 'What is the 2019 average defined benefit schemes?', 'answer': 50.5, 'derivation': '(57+44)/2', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'million'} \n Table: [['Income statement expense', '', '', ''], ['', '2019 €m', '2018 €m', '2017 €m'], ['Defined contribution schemes', '166', '178', '192'], ['Defined benefit schemes', '57', '44', '20'], ['Total amount charged to income statement (note 23)', '223', '222', '212']]",
#   {'uid': '6bf238a5-0a3e-492d-91f8-7f62d3b37fba',
#    'table': [['Income statement expense', '', '', ''],
#     ['', '2019 €m', '2018 €m', '2017 €m'],
#     ['Defined contribution schemes', '166', '178', '192'],
#     ['Defined benefit schemes', '57', '44', '20'],
#     ['Total amount charged to income statement (note 23)',
#      '223',
#      '222',
#      '212']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 121.5, 'scale': 'million'},
#   '',
#   '',
#   {'uid': '4d259081-6da6-44bd-8830-e4de0031744c',
#    'order': 6,
#    'question': 'What is the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes?',
#    'answer': 121.5,
#    'derivation': '[(166+178)/2] - [(57+44)/2]',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   'def run():\n    result = (float((166 + 178) / 2) - float((57 + 44) / 2), \'million\')\n    return "{:.2f}, {}".format(result[0], result[1])',
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '4d259081-6da6-44bd-8830-e4de0031744c', 'order': 6, 'question': 'What is the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes?', 'answer': 121.5, 'derivation': '[(166+178)/2] - [(57+44)/2]', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'million'} \n Table: [['Income statement expense', '', '', ''], ['', '2019 €m', '2018 €m', '2017 €m'], ['Defined contribution schemes', '166', '178', '192'], ['Defined benefit schemes', '57', '44', '20'], ['Total amount charged to income statement (note 23)', '223', '222', '212']]",
#   {'uid': '6bf238a5-0a3e-492d-91f8-7f62d3b37fba',
#    'table': [['Income statement expense', '', '', ''],
#     ['', '2019 €m', '2018 €m', '2017 €m'],
#     ['Defined contribution schemes', '166', '178', '192'],
#     ['Defined benefit schemes', '57', '44', '20'],
#     ['Total amount charged to income statement (note 23)',
#      '223',
#      '222',
#      '212']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 26.82, 'scale': 'percent'},
#   26.82,
#   'percent',
#   {'uid': 'bed1fce2-69cb-4d1e-a34a-01950a1770bd',
#    'order': 4,
#    'question': 'What is the percentage change in the operating loss carryforward from 2018 to 2019?',
#    'answer': 26.82,
#    'derivation': '(73,260-57,768)/57,768',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    value = (73260 - 57768) / 57768 * 100\n    return round(value, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'bed1fce2-69cb-4d1e-a34a-01950a1770bd', 'order': 4, 'question': 'What is the percentage change in the operating loss carryforward from 2018 to 2019?', 'answer': 26.82, 'derivation': '(73260-57768)/57768', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'percent'} \n Table: [['', 'December 31', ''], ['', '2019', '2 0 1 8'], ['', 'U.S.  in thousands', ''], ['Operating loss carryforward', '73260', '57768'], ['Net deferred tax asset before valuation allowance', '19911', '15916'], ['Valuation allowance', '(19911)', '(15916)'], ['Net deferred tax asset', '795', '772']]",
#   {'uid': 'f8ac9ddd-9872-4681-902d-a0ee7c0ee83a',
#    'table': [['', 'December 31', ''],
#     ['', '2019', '2 0 1 8'],
#     ['', 'U.S. $ in thousands', ''],
#     ['Operating loss carryforward', '73,260', '57,768'],
#     ['Net deferred tax asset before valuation allowance', '19,911', '15,916'],
#     ['Valuation allowance', '(19,911)', '(15,916)'],
#     ['Net deferred tax asset', '795', '772']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 25.1, 'scale': 'percent'},
#   25.1,
#   'percent',
#   {'uid': '348d031d-73ab-4b35-af46-998cfef25775',
#    'order': 5,
#    'question': 'What is the percentage change in the valuation allowance from 2018 to 2019?',
#    'answer': 25.1,
#    'derivation': '(19,911-15,916)/15,916',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['4'],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    result = (25.1, 'percent')\n    return result",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '348d031d-73ab-4b35-af46-998cfef25775', 'order': 5, 'question': 'What is the percentage change in the valuation allowance from 2018 to 2019?', 'answer': 25.1, 'derivation': '(19911-15916)/15916', 'answer_type': 'arithmetic', 'answer_from': 'table-text', 'rel_paragraphs': ['4'], 'req_comparison': False, 'scale': 'percent'} \n Table: [['', 'December 31', ''], ['', '2019', '2 0 1 8'], ['', 'U.S.  in thousands', ''], ['Operating loss carryforward', '73260', '57768'], ['Net deferred tax asset before valuation allowance', '19911', '15916'], ['Valuation allowance', '(19911)', '(15916)'], ['Net deferred tax asset', '795', '772']]",
#   {'uid': 'f8ac9ddd-9872-4681-902d-a0ee7c0ee83a',
#    'table': [['', 'December 31', ''],
#     ['', '2019', '2 0 1 8'],
#     ['', 'U.S. $ in thousands', ''],
#     ['Operating loss carryforward', '73,260', '57,768'],
#     ['Net deferred tax asset before valuation allowance', '19,911', '15,916'],
#     ['Valuation allowance', '(19,911)', '(15,916)'],
#     ['Net deferred tax asset', '795', '772']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 2.98, 'scale': 'percent'},
#   2.98,
#   'percent',
#   {'uid': 'aea850af-68cb-4cc1-80b2-c9c2860b273e',
#    'order': 6,
#    'question': 'What is the percentage change in the net deferred tax asset from 2018 to 2019?',
#    'answer': 2.98,
#    'derivation': '(795-772)/772',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    value = round(((795 - 772) / 772) * 100, 2)\n    return (value, 'percent')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'aea850af-68cb-4cc1-80b2-c9c2860b273e', 'order': 6, 'question': 'What is the percentage change in the net deferred tax asset from 2018 to 2019?', 'answer': 2.98, 'derivation': '(795-772)/772', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'percent'} \n Table: [['', 'December 31', ''], ['', '2019', '2 0 1 8'], ['', 'U.S.  in thousands', ''], ['Operating loss carryforward', '73260', '57768'], ['Net deferred tax asset before valuation allowance', '19911', '15916'], ['Valuation allowance', '(19911)', '(15916)'], ['Net deferred tax asset', '795', '772']]",
#   {'uid': 'f8ac9ddd-9872-4681-902d-a0ee7c0ee83a',
#    'table': [['', 'December 31', ''],
#     ['', '2019', '2 0 1 8'],
#     ['', 'U.S. $ in thousands', ''],
#     ['Operating loss carryforward', '73,260', '57,768'],
#     ['Net deferred tax asset before valuation allowance', '19,911', '15,916'],
#     ['Valuation allowance', '(19,911)', '(15,916)'],
#     ['Net deferred tax asset', '795', '772']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 2.93, 'scale': ''},
#   2.93,
#   '',
#   {'uid': 'ba6783f3-8207-419a-b407-3f688682caef',
#    'order': 4,
#    'question': 'What is the ratio of IMFT’s total assets to total liabilities in 2019?',
#    'answer': 2.93,
#    'derivation': '2,664/909 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': ''},
#   "def run():\n    total_assets_2019 = 2664\n    total_liabilities_2019 = 909\n    ratio = round(total_assets_2019 / total_liabilities_2019, 2)\n    return (ratio, '')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'ba6783f3-8207-419a-b407-3f688682caef', 'order': 4, 'question': 'What is the ratio of IMFT’s total assets to total liabilities in 2019?', 'answer': 2.93, 'derivation': '2664/909 ', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': ''} \n Table: [['As of', '2019', '2018'], ['Assets', '', ''], ['Cash and equivalents', '130', '91'], ['Receivables', '128', '126'], ['Inventories', '124', '114'], ['Other current assets', '9', '8'], ['Total current assets', '391', '339'], ['Property, plant, and equipment', '2235', '2641'], ['Other noncurrent assets', '38', '45'], ['Total assets', '2664', '3025'], ['Liabilities', '', ''], ['Accounts payable and accrued expenses', '118', '138'], ['Current debt', '696', '20'], ['Other current liabilities', '37', '9'], ['Total current liabilities', '851', '167'], ['Long-term debt', '53', '1064'], ['Other noncurrent liabilities', '5', '74'], ['Total liabilities', '909', '1305']]",
#   {'uid': 'e9a946ce-72a9-4b42-86d6-4d91fceb14db',
#    'table': [['As of', '2019', '2018'],
#     ['Assets', '', ''],
#     ['Cash and equivalents', '$130', '$91'],
#     ['Receivables', '128', '126'],
#     ['Inventories', '124', '114'],
#     ['Other current assets', '9', '8'],
#     ['Total current assets', '391', '339'],
#     ['Property, plant, and equipment', '2,235', '2,641'],
#     ['Other noncurrent assets', '38', '45'],
#     ['Total assets', '$2,664', '$3,025'],
#     ['Liabilities', '', ''],
#     ['Accounts payable and accrued expenses', '$118', '$138'],
#     ['Current debt', '696', '20'],
#     ['Other current liabilities', '37', '9'],
#     ['Total current liabilities', '851', '167'],
#     ['Long-term debt', '53', '1,064'],
#     ['Other noncurrent liabilities', '5', '74'],
#     ['Total liabilities', '$909', '$1,305']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 0.87, 'scale': ''},
#   0.87,
#   '',
#   {'uid': '263d03ec-83d2-48df-8376-1a72167798f7',
#    'order': 5,
#    'question': 'What is the proportion of IMFT’s property, plant, and equipment over total assets in 2018?',
#    'answer': 0.87,
#    'derivation': '2,641/3,025 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': ''},
#   "def run():\n    proportion = round(2641 / 3025, 2)\n    return (proportion, '')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '263d03ec-83d2-48df-8376-1a72167798f7', 'order': 5, 'question': 'What is the proportion of IMFT’s property, plant, and equipment over total assets in 2018?', 'answer': 0.87, 'derivation': '2641/3025 ', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': ''} \n Table: [['As of', '2019', '2018'], ['Assets', '', ''], ['Cash and equivalents', '130', '91'], ['Receivables', '128', '126'], ['Inventories', '124', '114'], ['Other current assets', '9', '8'], ['Total current assets', '391', '339'], ['Property, plant, and equipment', '2235', '2641'], ['Other noncurrent assets', '38', '45'], ['Total assets', '2664', '3025'], ['Liabilities', '', ''], ['Accounts payable and accrued expenses', '118', '138'], ['Current debt', '696', '20'], ['Other current liabilities', '37', '9'], ['Total current liabilities', '851', '167'], ['Long-term debt', '53', '1064'], ['Other noncurrent liabilities', '5', '74'], ['Total liabilities', '909', '1305']]",
#   {'uid': 'e9a946ce-72a9-4b42-86d6-4d91fceb14db',
#    'table': [['As of', '2019', '2018'],
#     ['Assets', '', ''],
#     ['Cash and equivalents', '$130', '$91'],
#     ['Receivables', '128', '126'],
#     ['Inventories', '124', '114'],
#     ['Other current assets', '9', '8'],
#     ['Total current assets', '391', '339'],
#     ['Property, plant, and equipment', '2,235', '2,641'],
#     ['Other noncurrent assets', '38', '45'],
#     ['Total assets', '$2,664', '$3,025'],
#     ['Liabilities', '', ''],
#     ['Accounts payable and accrued expenses', '$118', '$138'],
#     ['Current debt', '696', '20'],
#     ['Other current liabilities', '37', '9'],
#     ['Total current liabilities', '851', '167'],
#     ['Long-term debt', '53', '1,064'],
#     ['Other noncurrent liabilities', '5', '74'],
#     ['Total liabilities', '$909', '$1,305']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -361, 'scale': ''},
#   361.0,
#   '',
#   {'uid': '78fc6d55-c20c-4f71-99fe-bc40a16e61d0',
#    'order': 6,
#    'question': 'What is the change of IMFT’s total assets from 2018 to 2019?',
#    'answer': -361,
#    'derivation': '2,664 - 3,025 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': ''},
#   "def run():\n    change = round(float(3025 - 2664), 2)\n    return (change, '')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '78fc6d55-c20c-4f71-99fe-bc40a16e61d0', 'order': 6, 'question': 'What is the change of IMFT’s total assets from 2018 to 2019?', 'answer': -361, 'derivation': '2664 - 3025 ', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': ''} \n Table: [['As of', '2019', '2018'], ['Assets', '', ''], ['Cash and equivalents', '130', '91'], ['Receivables', '128', '126'], ['Inventories', '124', '114'], ['Other current assets', '9', '8'], ['Total current assets', '391', '339'], ['Property, plant, and equipment', '2235', '2641'], ['Other noncurrent assets', '38', '45'], ['Total assets', '2664', '3025'], ['Liabilities', '', ''], ['Accounts payable and accrued expenses', '118', '138'], ['Current debt', '696', '20'], ['Other current liabilities', '37', '9'], ['Total current liabilities', '851', '167'], ['Long-term debt', '53', '1064'], ['Other noncurrent liabilities', '5', '74'], ['Total liabilities', '909', '1305']]",
#   {'uid': 'e9a946ce-72a9-4b42-86d6-4d91fceb14db',
#    'table': [['As of', '2019', '2018'],
#     ['Assets', '', ''],
#     ['Cash and equivalents', '$130', '$91'],
#     ['Receivables', '128', '126'],
#     ['Inventories', '124', '114'],
#     ['Other current assets', '9', '8'],
#     ['Total current assets', '391', '339'],
#     ['Property, plant, and equipment', '2,235', '2,641'],
#     ['Other noncurrent assets', '38', '45'],
#     ['Total assets', '$2,664', '$3,025'],
#     ['Liabilities', '', ''],
#     ['Accounts payable and accrued expenses', '$118', '$138'],
#     ['Current debt', '696', '20'],
#     ['Other current liabilities', '37', '9'],
#     ['Total current liabilities', '851', '167'],
#     ['Long-term debt', '53', '1,064'],
#     ['Other noncurrent liabilities', '5', '74'],
#     ['Total liabilities', '$909', '$1,305']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 73, 'scale': 'thousand'},
#   73,
#   'thousand',
#   {'uid': '35d602ae-9131-4291-a30c-49a40f32bbe4',
#    'order': 5,
#    'question': 'What was the change in Value added tax receivables, net, noncurrent in 2019 from 2018?',
#    'answer': 73,
#    'derivation': '592-519',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['2'],
#    'req_comparison': False,
#    'scale': 'thousand'},
#   "def run():\n    result = 592 - 519\n    return round(result, 2), 'thousand'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '35d602ae-9131-4291-a30c-49a40f32bbe4', 'order': 5, 'question': 'What was the change in Value added tax receivables, net, noncurrent in 2019 from 2018?', 'answer': 73, 'derivation': '592-519', 'answer_type': 'arithmetic', 'answer_from': 'table-text', 'rel_paragraphs': ['2'], 'req_comparison': False, 'scale': 'thousand'} \n Table: [['', 'December 31,', ''], ['', '2019', '2018'], ['Trade accounts receivable, net, noncurrent (Note 2)', '26496', '15948'], ['Equity method investments (Note 1)', '9254', '9702'], ['Net deferred tax assets, noncurrent (Note 20)', '6774', '5797'], ['Rent and other deposits', '6106', '5687'], ['Value added tax receivables, net, noncurrent', '592', '519'], ['Other', '6723', '5711'], ['', '55945', '43364']]",
#   {'uid': '789efd09-04a2-45c7-84e5-47d3543695d1',
#    'table': [['', 'December 31,', ''],
#     ['', '2019', '2018'],
#     ['Trade accounts receivable, net, noncurrent (Note 2)',
#      '$26,496',
#      '$15,948'],
#     ['Equity method investments (Note 1)', '9,254', '9,702'],
#     ['Net deferred tax assets, noncurrent (Note 20)', '6,774', '5,797'],
#     ['Rent and other deposits', '6,106', '5,687'],
#     ['Value added tax receivables, net, noncurrent', '592', '519'],
#     ['Other', '6,723', '5,711'],
#     ['', '$55,945', '$43,364']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 14.07, 'scale': 'percent'},
#   14.07,
#   'percent',
#   {'uid': 'a4f782f1-de3b-47a3-87af-1cb33c112b39',
#    'order': 6,
#    'question': 'What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018?',
#    'answer': 14.07,
#    'derivation': '(592-519)/519',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    value_2019 = 592\n    value_2018 = 519\n    percentage_change = ((value_2019 - value_2018) / value_2018) * 100\n    return round(percentage_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'a4f782f1-de3b-47a3-87af-1cb33c112b39', 'order': 6, 'question': 'What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018?', 'answer': 14.07, 'derivation': '(592-519)/519', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'percent'} \n Table: [['', 'December 31,', ''], ['', '2019', '2018'], ['Trade accounts receivable, net, noncurrent (Note 2)', '26496', '15948'], ['Equity method investments (Note 1)', '9254', '9702'], ['Net deferred tax assets, noncurrent (Note 20)', '6774', '5797'], ['Rent and other deposits', '6106', '5687'], ['Value added tax receivables, net, noncurrent', '592', '519'], ['Other', '6723', '5711'], ['', '55945', '43364']]",
#   {'uid': '789efd09-04a2-45c7-84e5-47d3543695d1',
#    'table': [['', 'December 31,', ''],
#     ['', '2019', '2018'],
#     ['Trade accounts receivable, net, noncurrent (Note 2)',
#      '$26,496',
#      '$15,948'],
#     ['Equity method investments (Note 1)', '9,254', '9,702'],
#     ['Net deferred tax assets, noncurrent (Note 20)', '6,774', '5,797'],
#     ['Rent and other deposits', '6,106', '5,687'],
#     ['Value added tax receivables, net, noncurrent', '592', '519'],
#     ['Other', '6,723', '5,711'],
#     ['', '$55,945', '$43,364']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 4227.5, 'scale': 'million'},
#   4227.5,
#   'million',
#   {'uid': 'dc5e217a-a7b3-4fc9-ac0f-13d328f26b20',
#    'order': 4,
#    'question': 'What is the 2019 average free cash flow?',
#    'answer': 4227.5,
#    'derivation': '(4,411+4,044)/2',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    return (4227.5, 'million')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'dc5e217a-a7b3-4fc9-ac0f-13d328f26b20', 'order': 4, 'question': 'What is the 2019 average free cash flow?', 'answer': 4227.5, 'derivation': '(4411+4044)/2', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'million'} \n Table: [['', '2019', '2018', '2017'], ['', '€m', '€m', '€m'], ['Cash generated by operations (refer to note 18)', '14182', '13860', '13781'], ['Capital additions', '(7227)', '(7321)', '(7675)'], ['Working capital movement in respect of capital additions', '(89)', '171', '(822)'], ['Disposal of property, plant and equipment', '45', '41', '43'], ['Restructuring payments', '195', '250', '266'], ['Other', '(35)', '–', '34'], ['Operating free cash flow', '7071', '7001', '5627'], ['Taxation', '(1040)', '(1010)', '(761)'], ['Dividends received from associates and investments', '498', '489', '433'], ['Dividends paid to non-controlling shareholders in subsidiaries', '(584)', '(310)', '(413)'], ['Interest received and paid', '(502)', '(753)', '(830)'], ['Free cash flow (pre-spectrum)', '5443', '5417', '4056'], ['Licence and spectrum payments', '(837)', '(1123)', '(474)'], ['Restructuring payments', '(195)', '(250)', '(266)'], ['Free cash flow', '4411', '4044', '3316']]",
#   {'uid': '403df8e0-6045-4dba-90b3-5c9d8ca55bfb',
#    'table': [['', '2019', '2018', '2017'],
#     ['', '€m', '€m', '€m'],
#     ['Cash generated by operations (refer to note 18)',
#      '14,182',
#      '13,860',
#      '13,781'],
#     ['Capital additions', '(7,227)', '(7,321)', '(7,675)'],
#     ['Working capital movement in respect of capital additions',
#      '(89)',
#      '171',
#      '(822)'],
#     ['Disposal of property, plant and equipment', '45', '41', '43'],
#     ['Restructuring payments', '195', '250', '266'],
#     ['Other', '(35)', '–', '34'],
#     ['Operating free cash flow', '7,071', '7,001', '5,627'],
#     ['Taxation', '(1,040)', '(1,010)', '(761)'],
#     ['Dividends received from associates and investments',
#      '498',
#      '489',
#      '433'],
#     ['Dividends paid to non-controlling shareholders in subsidiaries',
#      '(584)',
#      '(310)',
#      '(413)'],
#     ['Interest received and paid', '(502)', '(753)', '(830)'],
#     ['Free cash flow (pre-spectrum)', '5,443', '5,417', '4,056'],
#     ['Licence and spectrum payments', '(837)', '(1,123)', '(474)'],
#     ['Restructuring payments', '(195)', '(250)', '(266)'],
#     ['Free cash flow', '4,411', '4,044', '3,316']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 3680, 'scale': 'million'},
#   0.0,
#   'million',
#   {'uid': '7cd3aedf-1291-4fea-bc9d-a25c65727b7b',
#    'order': 5,
#    'question': 'What is the 2018 average free cash flow?',
#    'answer': 3680,
#    'derivation': '(4,044+3,316)/2',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    result = 3680 / 1000000\n    return (round(result, 2), 'million')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '7cd3aedf-1291-4fea-bc9d-a25c65727b7b', 'order': 5, 'question': 'What is the 2018 average free cash flow?', 'answer': 3680, 'derivation': '(4044+3316)/2', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'million'} \n Table: [['', '2019', '2018', '2017'], ['', '€m', '€m', '€m'], ['Cash generated by operations (refer to note 18)', '14182', '13860', '13781'], ['Capital additions', '(7227)', '(7321)', '(7675)'], ['Working capital movement in respect of capital additions', '(89)', '171', '(822)'], ['Disposal of property, plant and equipment', '45', '41', '43'], ['Restructuring payments', '195', '250', '266'], ['Other', '(35)', '–', '34'], ['Operating free cash flow', '7071', '7001', '5627'], ['Taxation', '(1040)', '(1010)', '(761)'], ['Dividends received from associates and investments', '498', '489', '433'], ['Dividends paid to non-controlling shareholders in subsidiaries', '(584)', '(310)', '(413)'], ['Interest received and paid', '(502)', '(753)', '(830)'], ['Free cash flow (pre-spectrum)', '5443', '5417', '4056'], ['Licence and spectrum payments', '(837)', '(1123)', '(474)'], ['Restructuring payments', '(195)', '(250)', '(266)'], ['Free cash flow', '4411', '4044', '3316']]",
#   {'uid': '403df8e0-6045-4dba-90b3-5c9d8ca55bfb',
#    'table': [['', '2019', '2018', '2017'],
#     ['', '€m', '€m', '€m'],
#     ['Cash generated by operations (refer to note 18)',
#      '14,182',
#      '13,860',
#      '13,781'],
#     ['Capital additions', '(7,227)', '(7,321)', '(7,675)'],
#     ['Working capital movement in respect of capital additions',
#      '(89)',
#      '171',
#      '(822)'],
#     ['Disposal of property, plant and equipment', '45', '41', '43'],
#     ['Restructuring payments', '195', '250', '266'],
#     ['Other', '(35)', '–', '34'],
#     ['Operating free cash flow', '7,071', '7,001', '5,627'],
#     ['Taxation', '(1,040)', '(1,010)', '(761)'],
#     ['Dividends received from associates and investments',
#      '498',
#      '489',
#      '433'],
#     ['Dividends paid to non-controlling shareholders in subsidiaries',
#      '(584)',
#      '(310)',
#      '(413)'],
#     ['Interest received and paid', '(502)', '(753)', '(830)'],
#     ['Free cash flow (pre-spectrum)', '5,443', '5,417', '4,056'],
#     ['Licence and spectrum payments', '(837)', '(1,123)', '(474)'],
#     ['Restructuring payments', '(195)', '(250)', '(266)'],
#     ['Free cash flow', '4,411', '4,044', '3,316']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 547.5, 'scale': 'million'},
#   547.5,
#   'million',
#   {'uid': '22e20f25-669a-46b9-8779-2768ba391955',
#    'order': 6,
#    'question': 'What is the change between 2018 and 2019 average free cash flow?',
#    'answer': 547.5,
#    'derivation': '[(4,411+4,044)/2] -[(4,044+3,316)/2]',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    change_2018_2019 = (4411 + 4044) / 2 - (4044 + 3316) / 2\n    return round(change_2018_2019, 2), 'million'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '22e20f25-669a-46b9-8779-2768ba391955', 'order': 6, 'question': 'What is the change between 2018 and 2019 average free cash flow?', 'answer': 547.5, 'derivation': '[(4411+4044)/2] -[(4044+3316)/2]', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'million'} \n Table: [['', '2019', '2018', '2017'], ['', '€m', '€m', '€m'], ['Cash generated by operations (refer to note 18)', '14182', '13860', '13781'], ['Capital additions', '(7227)', '(7321)', '(7675)'], ['Working capital movement in respect of capital additions', '(89)', '171', '(822)'], ['Disposal of property, plant and equipment', '45', '41', '43'], ['Restructuring payments', '195', '250', '266'], ['Other', '(35)', '–', '34'], ['Operating free cash flow', '7071', '7001', '5627'], ['Taxation', '(1040)', '(1010)', '(761)'], ['Dividends received from associates and investments', '498', '489', '433'], ['Dividends paid to non-controlling shareholders in subsidiaries', '(584)', '(310)', '(413)'], ['Interest received and paid', '(502)', '(753)', '(830)'], ['Free cash flow (pre-spectrum)', '5443', '5417', '4056'], ['Licence and spectrum payments', '(837)', '(1123)', '(474)'], ['Restructuring payments', '(195)', '(250)', '(266)'], ['Free cash flow', '4411', '4044', '3316']]",
#   {'uid': '403df8e0-6045-4dba-90b3-5c9d8ca55bfb',
#    'table': [['', '2019', '2018', '2017'],
#     ['', '€m', '€m', '€m'],
#     ['Cash generated by operations (refer to note 18)',
#      '14,182',
#      '13,860',
#      '13,781'],
#     ['Capital additions', '(7,227)', '(7,321)', '(7,675)'],
#     ['Working capital movement in respect of capital additions',
#      '(89)',
#      '171',
#      '(822)'],
#     ['Disposal of property, plant and equipment', '45', '41', '43'],
# ...
#     ['Net income per diluted share (1)', '$3.50', '$4.33', '$0.85']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -993, 'scale': 'thousand'},
#   -993,
#   'thousand',
#   {'uid': '4b0f29ae-4a97-400c-9497-47440a02ebdd',
#    'order': 5,
#    'question': 'What was the change in the Assumed conversion of employee stock grants between 2017 and 2019?',
#    'answer': -993,
#    'derivation': '1,242-2,235',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['1'],
#    'req_comparison': False,
#    'scale': 'thousand'},
#   "def run():\n    result = (-993, 'thousand')\n    return result",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '4b0f29ae-4a97-400c-9497-47440a02ebdd', 'order': 5, 'question': 'What was the change in the Assumed conversion of employee stock grants between 2017 and 2019?', 'answer': -993, 'derivation': '1242-2235', 'answer_type': 'arithmetic', 'answer_from': 'table-text', 'rel_paragraphs': ['1'], 'req_comparison': False, 'scale': 'thousand'} \n Table: [['', '', 'Fiscal Years Ended March 31,', ''], ['', '2019', '2018', '2017'], ['Numerator', '', '', ''], ['Net income (1)', '206587', '254127', '47157'], ['Denominator:', '', '', ''], ['Weighted-average common shares outstanding:', '', '', ''], ['Basic', '57840', '52798', '46552'], ['Assumed conversion of employee stock grants', '1242', '2291', '2235'], ['Assumed conversion of warrants', '—', '3551', '6602'], ['Diluted', '59082', '58640', '55389'], ['Net income per basic share (1)', '3.57', '4.81', '1.01'], ['Net income per diluted share (1)', '3.50', '4.33', '0.85']]",
#   {'uid': '981e181b-57fa-42ff-a2d9-b8603eafdd4c',
#    'table': [['', '', 'Fiscal Years Ended March 31,', ''],
#     ['', '2019', '2018', '2017'],
#     ['Numerator', '', '', ''],
#     ['Net income (1)', '$206,587', '$254,127', '$47,157'],
#     ['Denominator:', '', '', ''],
#     ['Weighted-average common shares outstanding:', '', '', ''],
#     ['Basic', '57,840', '52,798', '46,552'],
#     ['Assumed conversion of employee stock grants', '1,242', '2,291', '2,235'],
#     ['Assumed conversion of warrants', '—', '3,551', '6,602'],
#     ['Diluted', '$59,082', '$58,640', '$55,389'],
#     ['Net income per basic share (1)', '$3.57', '$4.81', '$1.01'],
#     ['Net income per diluted share (1)', '$3.50', '$4.33', '$0.85']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -19.17, 'scale': 'percent'},
#   -19.17,
#   'percent',
#   {'uid': 'acde36c6-c718-4bfc-ae8d-0083d3dab3f0',
#    'order': 6,
#    'question': 'What was the percentage change in the Net income per diluted share between 2018 and 2019?',
#    'answer': -19.17,
#    'derivation': '(3.50-4.33)/4.33',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table-text',
#    'rel_paragraphs': ['1'],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    result = round(((3.50 - 4.33) / 4.33) * 100, 2)\n    return (result, 'percent')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'acde36c6-c718-4bfc-ae8d-0083d3dab3f0', 'order': 6, 'question': 'What was the percentage change in the Net income per diluted share between 2018 and 2019?', 'answer': -19.17, 'derivation': '(3.50-4.33)/4.33', 'answer_type': 'arithmetic', 'answer_from': 'table-text', 'rel_paragraphs': ['1'], 'req_comparison': False, 'scale': 'percent'} \n Table: [['', '', 'Fiscal Years Ended March 31,', ''], ['', '2019', '2018', '2017'], ['Numerator', '', '', ''], ['Net income (1)', '206587', '254127', '47157'], ['Denominator:', '', '', ''], ['Weighted-average common shares outstanding:', '', '', ''], ['Basic', '57840', '52798', '46552'], ['Assumed conversion of employee stock grants', '1242', '2291', '2235'], ['Assumed conversion of warrants', '—', '3551', '6602'], ['Diluted', '59082', '58640', '55389'], ['Net income per basic share (1)', '3.57', '4.81', '1.01'], ['Net income per diluted share (1)', '3.50', '4.33', '0.85']]",
#   {'uid': '981e181b-57fa-42ff-a2d9-b8603eafdd4c',
#    'table': [['', '', 'Fiscal Years Ended March 31,', ''],
#     ['', '2019', '2018', '2017'],
#     ['Numerator', '', '', ''],
#     ['Net income (1)', '$206,587', '$254,127', '$47,157'],
#     ['Denominator:', '', '', ''],
#     ['Weighted-average common shares outstanding:', '', '', ''],
#     ['Basic', '57,840', '52,798', '46,552'],
#     ['Assumed conversion of employee stock grants', '1,242', '2,291', '2,235'],
#     ['Assumed conversion of warrants', '—', '3,551', '6,602'],
#     ['Diluted', '$59,082', '$58,640', '$55,389'],
#     ['Net income per basic share (1)', '$3.57', '$4.81', '$1.01'],
#     ['Net income per diluted share (1)', '$3.50', '$4.33', '$0.85']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 39224, 'scale': ''},
#   39224,
#   '',
#   {'uid': 'c8ed0bf6-60c5-41e2-97e3-5ece54a1349b',
#    'order': 5,
#    'question': 'What is the change in total personnel expenses from 2018 to 2019?',
#    'answer': 39224,
#    'derivation': ' 227,727 - 188,503 ',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': ''},
#   "def run():\n    change = 227727 - 188503\n    return (change, '') \n\n# Call the function\nprint(run())",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'c8ed0bf6-60c5-41e2-97e3-5ece54a1349b', 'order': 5, 'question': 'What is the change in total personnel expenses from 2018 to 2019?', 'answer': 39224, 'derivation': ' 227727 - 188503 ', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': ''} \n Table: [['', 'December 31,', ''], ['', '2018', '2019'], ['Wages and salaries', '158371', '191459'], ['Social security', '14802', '17214'], ['Pension expenses', '6937', '8408'], ['Share-based payment expenses', '8215', '10538'], ['Restructuring expenses', '178', '108'], ['Total', '188503', '227727']]",
#   {'uid': '7a9fdd23-2adc-4cf5-8761-5c7fbec53e6e',
#    'table': [['', 'December 31,', ''],
#     ['', '2018', '2019'],
#     ['Wages and salaries', '158,371', '191,459'],
#     ['Social security', '14,802', '17,214'],
#     ['Pension expenses', '6,937', '8,408'],
#     ['Share-based payment expenses', '8,215', '10,538'],
#     ['Restructuring expenses', '178', '108'],
#     ['Total', '188,503', '227,727']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 20.81, 'scale': 'percent'},
#   20.81,
#   'percent',
#   {'uid': '4cdc8b2e-e3ea-4c36-bbda-7c409a84cc78',
#    'order': 6,
#    'question': 'What is the percentage change in total personnel expenses from 2018 to 2019?',
#    'answer': 20.81,
#    'derivation': ' (227,727 - 188,503 )/188,503',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'percent'},
#   "def run():\n    total_personnel_expenses_2018 = 188503\n    total_personnel_expenses_2019 = 227727\n    \n    percentage_change = ((total_personnel_expenses_2019 - total_personnel_expenses_2018) / total_personnel_expenses_2018) * 100\n    \n    return round(percentage_change, 2), 'percent'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '4cdc8b2e-e3ea-4c36-bbda-7c409a84cc78', 'order': 6, 'question': 'What is the percentage change in total personnel expenses from 2018 to 2019?', 'answer': 20.81, 'derivation': ' (227727 - 188503 )/188503', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'percent'} \n Table: [['', 'December 31,', ''], ['', '2018', '2019'], ['Wages and salaries', '158371', '191459'], ['Social security', '14802', '17214'], ['Pension expenses', '6937', '8408'], ['Share-based payment expenses', '8215', '10538'], ['Restructuring expenses', '178', '108'], ['Total', '188503', '227727']]",
#   {'uid': '7a9fdd23-2adc-4cf5-8761-5c7fbec53e6e',
#    'table': [['', 'December 31,', ''],
#     ['', '2018', '2019'],
#     ['Wages and salaries', '158,371', '191,459'],
#     ['Social security', '14,802', '17,214'],
#     ['Pension expenses', '6,937', '8,408'],
#     ['Share-based payment expenses', '8,215', '10,538'],
#     ['Restructuring expenses', '178', '108'],
#     ['Total', '188,503', '227,727']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': -0.2, 'scale': 'million'},
#   -0.2,
#   'million',
#   {'uid': 'ec696158-f93d-4608-903d-a6b9c4e7bfd5',
#    'order': 4,
#    'question': 'What is the increase / (decrease) in the telecommunication maintenance from 2018 to 2019?',
#    'answer': -0.2,
#    'derivation': '86.8 - 87.0',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    increase_decrease = round(float(86.8) - float(87.0), 2)\n    return (increase_decrease, 'million')",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': 'ec696158-f93d-4608-903d-a6b9c4e7bfd5', 'order': 4, 'question': 'What is the increase / (decrease) in the telecommunication maintenance from 2018 to 2019?', 'answer': -0.2, 'derivation': '86.8 - 87.0', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'million'} \n Table: [['Years Ended December 31,', '', ''], ['', '2019', '2018'], ['Telecommunication - Maintenance', '86.8', '87.0'], ['Telecommunication - Installation', '33.2', '41.5'], ['Power - Operations, Maintenance & Construction Support', '19.9', '31.0'], ['Power - Cable Installation & Repair', '32.6', '34.8'], ['Total revenue from contracts with customers', '172.5', '194.3'], ['Other revenue', '—', '—'], ['Total Marine Services segment revenue', '172.5', '194.3']]",
#   {'uid': '8db2d2a5-fdcd-45c2-be2f-813cba4fbca7',
#    'table': [['Years Ended December 31,', '', ''],
#     ['', '2019', '2018'],
#     ['Telecommunication - Maintenance', '$86.8', '$87.0'],
#     ['Telecommunication - Installation', '33.2', '41.5'],
#     ['Power - Operations, Maintenance & Construction Support', '19.9', '31.0'],
#     ['Power - Cable Installation & Repair', '32.6', '34.8'],
#     ['Total revenue from contracts with customers', '172.5', '194.3'],
#     ['Other revenue', '—', '—'],
#     ['Total Marine Services segment revenue', '$172.5', '$194.3']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 37.35, 'scale': 'million'},
#   37.35,
#   'million',
#   {'uid': '27911d6f-dfe5-487b-bc56-7e5cf16a32e0',
#    'order': 5,
#    'question': 'What is the average telecommunications installation?',
#    'answer': 37.35,
#    'derivation': '(33.2 + 41.5) / 2',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    average_telecom_installation = (33.2 + 41.5) / 2\n    return round(average_telecom_installation, 2), 'million'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '27911d6f-dfe5-487b-bc56-7e5cf16a32e0', 'order': 5, 'question': 'What is the average telecommunications installation?', 'answer': 37.35, 'derivation': '(33.2 + 41.5) / 2', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'million'} \n Table: [['Years Ended December 31,', '', ''], ['', '2019', '2018'], ['Telecommunication - Maintenance', '86.8', '87.0'], ['Telecommunication - Installation', '33.2', '41.5'], ['Power - Operations, Maintenance & Construction Support', '19.9', '31.0'], ['Power - Cable Installation & Repair', '32.6', '34.8'], ['Total revenue from contracts with customers', '172.5', '194.3'], ['Other revenue', '—', '—'], ['Total Marine Services segment revenue', '172.5', '194.3']]",
#   {'uid': '8db2d2a5-fdcd-45c2-be2f-813cba4fbca7',
#    'table': [['Years Ended December 31,', '', ''],
#     ['', '2019', '2018'],
#     ['Telecommunication - Maintenance', '$86.8', '$87.0'],
#     ['Telecommunication - Installation', '33.2', '41.5'],
#     ['Power - Operations, Maintenance & Construction Support', '19.9', '31.0'],
#     ['Power - Cable Installation & Repair', '32.6', '34.8'],
#     ['Total revenue from contracts with customers', '172.5', '194.3'],
#     ['Other revenue', '—', '—'],
#     ['Total Marine Services segment revenue', '$172.5', '$194.3']]},
#   None),
#  ({'answer_type': 'arithmetic', 'answer': 183.4, 'scale': 'million'},
#   183.4,
#   'million',
#   {'uid': '3b8e873e-64d5-4af0-904f-7197dc632773',
#    'order': 6,
#    'question': 'What is the average Total Marine Services segment revenue?',
#    'answer': 183.4,
#    'derivation': '(172.5 + 194.3) / 2',
#    'answer_type': 'arithmetic',
#    'answer_from': 'table',
#    'rel_paragraphs': [],
#    'req_comparison': False,
#    'scale': 'million'},
#   "def run():\n    total_revenue_2019 = 172.5\n    total_revenue_2018 = 194.3\n    average_total_marine_services_segment_revenue = (total_revenue_2019 + total_revenue_2018) / 2\n    return round(average_total_marine_services_segment_revenue, 2), 'million'",
#   "Generate a Python code that can answer the following question using the following table! The code must contain only one function called 'run', and no wrapping class. The function must return numeric float results with accuracy to two decimal places and format (value, scale). Do not write explanation, just code.\nQuestion: {'uid': '3b8e873e-64d5-4af0-904f-7197dc632773', 'order': 6, 'question': 'What is the average Total Marine Services segment revenue?', 'answer': 183.4, 'derivation': '(172.5 + 194.3) / 2', 'answer_type': 'arithmetic', 'answer_from': 'table', 'rel_paragraphs': [], 'req_comparison': False, 'scale': 'million'} \n Table: [['Years Ended December 31,', '', ''], ['', '2019', '2018'], ['Telecommunication - Maintenance', '86.8', '87.0'], ['Telecommunication - Installation', '33.2', '41.5'], ['Power - Operations, Maintenance & Construction Support', '19.9', '31.0'], ['Power - Cable Installation & Repair', '32.6', '34.8'], ['Total revenue from contracts with customers', '172.5', '194.3'], ['Other revenue', '—', '—'], ['Total Marine Services segment revenue', '172.5', '194.3']]",
#   {'uid': '8db2d2a5-fdcd-45c2-be2f-813cba4fbca7',
#    'table': [['Years Ended December 31,', '', ''],
#     ['', '2019', '2018'],
#     ['Telecommunication - Maintenance', '$86.8', '$87.0'],
#     ['Telecommunication - Installation', '33.2', '41.5'],
#     ['Power - Operations, Maintenance & Construction Support', '19.9', '31.0'],
#     ['Power - Cable Installation & Repair', '32.6', '34.8'],
#     ['Total revenue from contracts with customers', '172.5', '194.3'],
#     ['Other revenue', '—', '—'],
#     ['Total Marine Services segment revenue', '$172.5', '$194.3']]},
#   None)]

# %%
good, len(res)
# Out:
# (135, 182)

# %%
# Out:
# [['$ million', '2019', '2018', 'Change (%)'], ['Order intake1', '532.0', '470.0', '13.2'], ['Revenue', '503.6', '476.9', '5.6'], ['Gross profit', '368.6', '344.5', '7.0'], ['Gross margin (%)', '73.2', '72.2', '1.0'], ['Adjusted operating costs2', '275.7', '267.4', '3.1'], ['Adjusted operating profit2', '92.9', '77.1', '20.5'], ['Adjusted operating margin3 (%)', '18.4', '16.2', '2.2'], ['Reported operating profit', '88.6', '57.5', '54.1'], ['Effective tax rate4 (%)', '13.0', '15.4', '(2.4)'], ['Reported profit before tax', '89.6', '61.2', '46.4'], ['Adjusted basic earnings per share5 (cents)', '13.40', '10.86', '23.4'], ['Basic earnings per share (cents)', '12.79', '9.14', '39.9'], ['Free cash flow6', '100.1', '50.9', '96.7'], ['Closing cash', '183.2', '121.6', '50.7'], ['Final dividend per share7 (cents)', '3.45', '2.73', '26.4']]
# 3.45 3.45
# (0.72, 'million')

# %%
closing_cash_2019
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 closing_cash_2019
#
# NameError: name 'closing_cash_2019' is not defined
