# %%
# code gen + values list

#### import tatqa_utils
import pandas as pd
import table_convert
import pyreadstat
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

import utils
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document
import numpy as np
from progress.bar import Bar
# %load_ext autoreload
# %autoreload 2

# %%
import os
with open('dataset_raw/openai.api.key.2', 'r') as filek: 
    openai_key = filek.read()
os.environ["OPENAI_API_KEY"] =  openai_key

# %%
from langchain.globals import set_llm_cache
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAI
from langchain_community.cache import SQLiteCache

#llm = ChatOpenAI(temperature=0)
#llm = OpenAI(temperature=0) 
set_llm_cache(SQLiteCache(database_path=".langchain.db"))

# %%
devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')

# %%
def get_question(qid):
    for i, item in devdf.iterrows():
        for q in item['questions']:        
            if q['uid'] == qid:
                #table = item['table']['table']
                return (item['table'], q)
    return (None, None)

# %%
def gen_code3(llm, messages, question, value_list): 
    
    prompt = ChatPromptTemplate.from_messages(messages)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser
    
    response = chain.invoke({"value_list": value_list, "question":question})
    code =  response.replace('```python','').replace('```','')
    
    return (prompt.format(value_list = value_list, question = question), code)

def exec_code(code, value_list):  
        try: 
            loc = locals()   
            if not "run()" in code:
                exec(code + f"\nr = run({value_list})\n", globals(), loc)
            else: 
                exec(code + "\nr = run()\n", globals(), loc)
            return loc['r']
        except Exception as e:
                s = '[Error]'+ str(e)
                print(s)
                return (s,'')

def gen_code_table(llm, messages, question, table): 
    
    prompt = ChatPromptTemplate.from_messages(messages)

    output_parser = StrOutputParser()

    chain = prompt | llm | output_parser
    
    response = chain.invoke({"table": table, "question":question})
    code =  response.replace('```python','').replace('```','')
    
    return (prompt.format(table = table, question = question), code)

def exec_code_table(code, table):  
        try: 
            loc = locals()   
            if not "run()" in code:
                exec(code + f"\nr = run({table})\n", globals(), loc)
            else: 
                exec(code + "\nr = run()\n", globals(), loc)
            return loc['r']
        except Exception as e:
                s = '[Error]'+ str(e)
                print(s)
                return (s,'')

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

#llm = ChatOpenAI(model="gpt-3.5-turbo", temperature = 0, top_p = 1.0, seed=11)
llm = ChatOpenAI(model="gpt-3.5-turbo", 
temperature=0,
    #max_tokens=150,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0,
    seed=123)

# %%
def get_answer(llm, messages, table, q):
    values = table_convert.convert_multitable(table)    
    p, code = gen_code3(llm, messages, q, values)    
    #print(code)
    (v, s) = exec_code(code, values)
    return  (v, s, code)

# %%
from tqdm.notebook import tqdm as log_progress
import prompt_versions

devdf = pd.read_json('dataset_raw/tatqa_dataset_dev.json')
cnt = 0
res = []
for i, item in log_progress(devdf.iterrows()):
    try:
        #if cnt == 36:
        #    break;
        #print(item['table']['uid'])
        table = item['table']['table']
        value_list = table_convert.convert_multitable(table)    
        text = '\n'.join( [p['text'] for p in item['paragraphs']])
        for q in item['questions']:        
            if q['answer_type'] == 'arithmetic' and 'table' == q['answer_from']:   
                cnt = cnt + 1
                print(q['uid'])
                _table, _q =  get_question(q['uid'])
                
                table = _table['table']
                
                #[print(r) for r in table]
                
                q = _q['question']
                print(q, end='')
                
                
                r = []
                #for i in [0,1,2]:        
                #   r.append(get_answer(llm, messages, table, q))
                
                #if r[0][0] == r[1][0]:
                #    (v, s) = r[0]
                #elif r[1][0] == r[2][0]:
                #    (v, s) = r[1]
                #elif r[0][0] == r[2][0]:
                #    (v, s) = r[0]
                #else:
                #    (v, s) = (None, None)
                    
                #(v, s, code) = get_answer(llm, messages, table, q)    
                (pred_value, pred_scale, code) = get_answer(llm, prompt_versions.prompt_versions['V2'], table, q)    
                
                if 'in millions' in text.lower() and pred_scale == '':
                    pred_scale = 'million'
                    
                if  utils.eval_predicted_value(pred_value, _q['answer']):
                    print("\033[92m Success: " + str(pred_value)+'\033[0m')
                else:    
                    print("\033[91m failure: " + str(pred_value), 'good answer: ', _q['answer'],'\033[0m' )
                
                if isinstance(pred_value, tuple) and len(pred_value) == 2:
                    print('$$$$')
                    (pred_value, pred_scale) = pred_value
                if pred_scale == "%" or pred_scale == "percentage"  :
                    pred_scale = 'percent'
                if pred_scale not in ["", 'thousand', 'million', 'billion', 'percent']:
                    print('Invalid ', pred_scale)
                    pred_scale = ""    
                #if item['table']['uid'] in res_scale and pred_scale != 'percent':
                #    pred_scale = res_scale[item['table']['uid']]
                err=""
                if isinstance(pred_value, str):
                    #print("string")
                    if  pred_value.startswith('[Error]'):
                        err = pred_value
                        (pred_value, pred_scale) = ("", "")
                                                                              
                res.append(({"answer_type":_q["answer_type"], "answer": _q["answer"], 'scale': _q["scale"]}, pred_value, pred_scale, _q, code, table,value_list, err))
    except Exception as e:
        s = '[Outer Exception]'+ str(e)
        print(s)
        res.append(({"answer_type":_q["answer_type"], "answer": _q["answer"], 'scale': _q["scale"]}, "", "", _q, "", table,"", s))
# Out:
# 0it [00:00, ?it/s]
# b2786c1a-37de-4120-b03c-32bf5c81f157
# What was the change in the amount for Appliances in 2019 from 2018? Success: -94.0
# fe11f001-3bfe-4089-8108-412676f0a780
# What was the percentage change in the amount for Appliances in 2019 from 2018? Success: -12.14
# 5103aed0-b4e8-4fae-bf78-e2c9f4ba84cf
# What is the difference between the domestic and international discount rates as at September 30, 2019? Success: 2.1
# 4dc8be43-d8d9-4b08-9ffd-9c19012361ce
# What is the year on year percentage change in domestic discount rate between 2018 and 2019? Success: 6.67
# 6c44a1a8-0785-43a0-90ab-7e21df2c57d9
# What is the year on year percentage change in international expected return on plan assets between 2018 and 2019? Success: -8.11
# a0414f81-8dc2-44b2-a441-2c9d9c805c4d
# What is the 2019 average defined contribution schemes? Success: 172.0
# bf7abd62-d9cd-48d2-8826-1457684019a3
# What is the 2019 average defined benefit schemes? Success: 50.5
# 4d259081-6da6-44bd-8830-e4de0031744c
# What is the difference between 2019 average defined contribution schemes and 2019 average defined benefit schemes? failure: -1.0 good answer:  121.5
# bed1fce2-69cb-4d1e-a34a-01950a1770bd
# What is the percentage change in the operating loss carryforward from 2018 to 2019? Success: 26.82
# aea850af-68cb-4cc1-80b2-c9c2860b273e
# What is the percentage change in the net deferred tax asset from 2018 to 2019? Success: 2.98
# ba6783f3-8207-419a-b407-3f688682caef
# What is the ratio of IMFT’s total assets to total liabilities in 2019? Success: 2.93
# 263d03ec-83d2-48df-8376-1a72167798f7
# What is the proportion of IMFT’s property, plant, and equipment over total assets in 2018? Success: 0.87
# 78fc6d55-c20c-4f71-99fe-bc40a16e61d0
# What is the change of IMFT’s total assets from 2018 to 2019? Success: -361.0
# a4f782f1-de3b-47a3-87af-1cb33c112b39
# What was the percentage change in Value added tax receivables, net, noncurrent in 2019 from 2018? Success: 14.07
# dc5e217a-a7b3-4fc9-ac0f-13d328f26b20
# What is the 2019 average free cash flow? Success: 4227.5
# 7cd3aedf-1291-4fea-bc9d-a25c65727b7b
# What is the 2018 average free cash flow? failure: 4044.0 good answer:  3680
# 22e20f25-669a-46b9-8779-2768ba391955
# What is the change between 2018 and 2019 average free cash flow? failure: 4227.5 good answer:  547.5
# a983501d-2eec-486d-9661-e520c7c8af5e
# What was the average difference between EBITDA and underlying EBITDA for both FYs? failure: 2349.0 good answer:  3728
# 64c902c6-f426-4432-84b3-c10b3065716f
# What was the difference in net profit between both FYs? failure: 16458.0 good answer:  -16458
# 91812b92-5e94-414f-a447-4622aa3c2d10
# What was the average dividend yield for the 3 years from 2017 to 2019? Success: 1.57
# 29b63db7-4925-4629-b108-49bbb27fb565
# What was the average risk-free interest rate over the 3 year period from 2017 to 2019? Success: 1.9
# 6100c476-160a-4f1e-bfc1-a16f4cc18b52
# What was the increase / (decrease) in the cost from 2018 to 2019? Success: 18.0
# a81f1322-e74f-4e3c-a6cf-4b8d25d01cf5
# What is the average Selling, general and administrative? failure: 407.0 good answer:  399.33
# f7cac790-05ae-4a55-a41d-836a6b415f88
# What is the percentage increase / (decrease) of Research, development and engineering from 2018 to 2019? Success: 88.06
# 65ec782c-691e-45df-b541-caecb85154ff
# What was the change in Capital redemption reserve in 2019 from 2018? Success: 0.2
# 94916f79-4b6d-487f-8fa2-39f81a085760
# What was the percentage change in Capital redemption reserve in 2019 from 2018? Success: 40.0
# bbe335ff-414f-48b3-8126-5a2c7c505de3
# How much was the average operating income from 2015 to 2019? Success: 13237.4
# ef274d2b-fbd6-4e9f-95f9-79b37827d91c
# What was the total expenses for Oracle in 2018? Success: 35796.0
# 191c3926-7356-4ab8-a8f9-41e7b7c8a492
# What were the total Assets as reported? Success: 64509.0
# bd2d81eb-46fc-4e62-908d-aebfccf46246
# What were the total Liabilities and Stockholders' Equity as reported? Success: 62740.0
# 010df393-a62e-408d-888a-045a4e435e6a
# What is the difference in amount between Deferred Revenue and Other non-current liabilities as reported? failure: -14212.0 good answer:  14212
# 58adf6c4-41ae-4f3f-84cb-cf3469a80ce4
# What was the percentage change in Total Other operating expenses between 2018 and 2019? Success: -67.6
# 79f06004-f4fc-4e82-a9fe-3c389a2f81b6
# What was the change in the statutory federal income tax rate from 2018 to 2019? Success: 0.0
# a360cee9-ce60-4f29-988d-8c6c627bb51f
# What was the average State and local income tax rate, net of federal tax benefits between 2017-2019? Success: 3.0
# 5c8c999e-354f-4693-9b2d-29e3c03cb2af
# What was the change in the preferred stock disposition from 2018 to 2019?[Error]
#  failure: [Error] good answer:  -9.9
# 6cc73a99-0323-40d5-9d92-b285579b3482
# What was the percentage change in gross profit between 2018 and 2019? Success: -13.66
# fa43e8cd-7fea-4738-85ee-f61ae8529f96
# What was the change in the revenues from 2018 to 2019? Success: -21.7
# 2067daa1-9905-456b-bcbf-42bc66b47259
# What is the average net income for 2018 and 2019? failure: 995.7 good answer:  88.45
# a1912c87-d68c-42ea-b0da-98908097d227
# What was the change in closing cash? Success: 61.6
# 692ea65a-9a60-4210-bd75-d34231e2e113
# What is the average total current tax expense for 2017 and 2018?  Success: 984.0
# 7cba7400-af25-4f71-a49d-35d5eec31458
# What is the average total current tax expense for 2018 and 2019? Success: 1040.0
# 94ef7822-a201-493e-b557-a640f4ea4d83
# What is the change in the average total current tax expense between 2017-2018, and 2018-2019? Success: 56.0
# bfce0375-cbd0-4e25-9b82-0424058918f1
# What is the total number of nonvested shares as of December 31, 2019 and 2018? failure: 12122000.0 good answer:  12122
# 73693527-ed4b-4d07-941e-0e654095a43d
# What was the employee termination costs as a proportion of total costs in 2018? failure: 6.47 good answer:  0.9500000000000001
# 4a253bf4-b9fc-4ec3-b99b-d2744646a296
# What was the change in Total (loan) in 2019 from 2018? failure: 56.5 good answer:  -56.5
# 74183d5d-7633-43b5-bd7b-f0894fbe2299
# What was the percentage change in Total (loan) in 2019 from 2018? Success: -6.38
# 1238d807-aa57-48a3-93b6-591873788625
# What was the increase / (decrease) in the Statutory federal income tax (benefit) from 2018 to 2019? Success: -19411.0
# ef9d4839-5277-4614-bb73-f902fd8a38b6
# What was the average Tax exempt interest income? Success: -168.0
# fec503e8-6f91-483e-856d-bb1278bd031f
# What was the percentage change in the Domestic manufacturers deduction from 2017 to 2018? Success: -162.15
# a3e21403-222e-4328-8f7d-9383d2d91fe9
# What is the average dividend yield in 2017 and 2018? Success: 4.35
# a3637ae4-b286-44a5-a115-83867e4bb14e
# What is the average dividend yield in 2018 and 2019? Success: 4.55
# d3f04ae4-ced9-446d-87b7-bb9d193e3603
# What is the average expected volatility in 2017 and 2018? Success: 27.9
# 8b6a4479-3b77-4db7-a90c-8b1ca41a8997
# What was the change in net debt from 2018 to 2019? Success: 59.4
# 7b2b17a9-6409-45fb-907f-270832305974
# What was the percentage change in net debt from 2018 to 2019? Success: 25.19
# 3b5bb347-41c7-499a-b044-87b9a04b0833
# What was the percentage change in Total Other in 2018 from 2017? Success: 15.85
# 0d0c77cf-d32c-4b0e-8da0-dcaa3f681f59
# What is the percentage of Bell Wireless out of the Total BCE operating revenues in Q4 2019? Success: 39.47
# 259e18e8-4738-4f4d-b625-e352ca78a136
# What is the increase / (decrease) in the recorded investment from 2018 to 2019? Success: -8736.0
# 407d43ea-c405-4b88-95ae-d15b1f25fb25
# What is the average Specific allowance for credit losses? Success: 198.5
# 681dcc0f-a32e-46ca-9785-1289a6aba802
# What is the percentage increase / (decrease) in the Net financing receivables from 2018 to 2019? Success: -28.05
# d2969c34-708e-4ab0-8e21-32c0b18c544c
# What is the ratio of current deferred revenue to non-current deferred revenue as of end of period? Success: 1.3
# 59f13f19-4494-4c54-8e9a-1b499d50021a
# What is the total price of shares that were exercised or canceled between 2016 and 2017? failure: 2070862713946.92 good answer:  981341.34
# b382a11b-749b-425a-a77d-20e943e00f77
# What is the proportion of granted shares between 2017 and 2018 over outstanding shares at September 30, 2017? failure: 0.25 good answer:  0.11
# 741f8b2e-9312-4426-893d-69b99fab247b
# What is the price of outstanding shares on September 30, 2019? Success: 11808314.0
# cf89ffee-b551-4e34-9321-30325df32cc1
# What was the change in the Amount recognized in other comprehensive (loss) income from 2017 to 2018? failure: 17.0 good answer:  -17
# 147f7c09-a627-4719-93ad-33661b5a4543
# What was the change in Total interest expense, net presented in the consolidated statements of income in which the effects of cash flow hedges are recorded between 2017 and 2018?[Error]'[' was never closed (<string>, line 11)
#  failure: [Error]'[' was never closed (<string>, line 11) good answer:  -2
# 6a441650-9d8a-43a0-8906-bec97a73ca2c
# What is the total special termination benefits charge in 2018 and 2019? Success: 21.0
# eb1ecc18-e3d3-4dd6-a689-546998eb2784
# What is the percentage change in interest cost in 2019 from 2018? Success: 11.22
# 8a21f821-eaf6-421a-8c67-795e7e2d1f61
# What was the percentage change in Adjusted EBITDA between 2018 and 2019? Success: 16.36
# 07ec204e-3922-4b5c-b1fd-9cb9311a53e5
# What was the percentage change in the Total net deferred tax assets between 2018 and 2019? Success: -22.26
# f1034ee7-b182-48d5-bad8-1d9902500f57
# What is the difference in the number of rights 'granted during the period' between 2018 and 2019? failure: -1226114.0 good answer:  1226114
# 545cb01f-9b10-4a1b-8a7c-e9e74e725b26
# What is the average number of rights 'outstanding at end of period' for 2018 and 2019? Success: 12085176.0
# cc053817-3496-48b3-9bfc-83e9ba71bb57
# What is the percentage increase in the number of rights 'outstanding at the start of period' from 2018 to 2019?  Success: 58.71
# fda3b0cb-bc87-4cbc-bc8f-79604538a700
# What is the average Legal reserve within Appropriation of earnings? Success: 835623.0
# 8d8c9fb6-6316-4fad-881e-7cdb3cfa965a
# What is the increase/ (decrease) in Legal reserve within Appropriation of earnings from 2018 to 2019?(256648.0, 'thousand')
#  Success: 256648.0
# b4aabd48-5010-425f-be30-c63f1c648c85
# What is the increase/ (decrease) in Cash dividends within Appropriation of earnings from 2018 to 2019?(2849050.0, 'thousand')
#  Success: 2849050.0
# f12806ca-aa4c-4fe6-84fc-10cefca76a9e
# What is the change in the operating revenue under continuing operations from 2018 to 2019? Success: -22772.0
# f36e5912-f63c-4837-a9ed-ddbe73e5148b
# What is the percentage of the operating leases of more than 5 years in the total operating leases? failure: 6.01 good answer:  12.02
# 7ff6facd-1f7b-471c-9e38-5177c4eac9ba
# What is the percentage of capital leases in the total liabilities? Success: 0.62
# d13b3204-0428-41af-8e4a-771dde352c50
# What is the percentage of the purchase obligations of more than 5 years in the total purchase obligations? Success: 8.64
# e1ae4755-8038-4862-9f2f-b4197f9f2159
# What was the increase / (decrease) in the contractual obligation for operating leases from 2020 to 2021-2022? Success: 2968.0
# eb50d3aa-16da-4087-9ab2-10106ebd10e7
# What is the average annual Operating leases contractual obligations for 2020-2024? failure: 5309.6 good answer:  2988
# 61451090-3f7b-4fb1-b405-64a786d937d8
# What was the increase / (decrease) in the asset retirement obligation from 2021-2022 to 2022-2023? Success: 100.0
# 56a014a9-5b9c-41e5-9523-ebbd3a01dd6d
# What is the increase/ (decrease) in Statutory Audit, Certification, Audit of Individual and Consolidated Financial Statements from the period 2018 to 2019? Success: -451500.0
# 2af4c7cf-79a2-4bdf-81b8-dbaff5081bc3
# What is the increase/ (decrease) in Audit-Related Fees from the period 2018 to 2019? Success: 35071.0
# 856c56ac-e6f5-4cfc-8f29-69f67dc717da
# What is the increase/ (decrease) in total Fees from the period 2018 to 2019? Success: -416429.0
# 593a3304-3fbe-47d2-a004-f4459ef3d014
# In 2019, what is the percentage constitution of prepaid expenses among the total prepaid expenses and other? Success: 92.27
# 0f45cc67-fd57-4930-a0d0-f5d7174d7562
# What is the percentage change in the value of raw materials between 2018 and 2019? Success: 16.23
# a30ab3a2-f930-4bf4-9b52-35c9c504d992
# What is the percentage change in the value of work-in-process inventory between 2018 and 2019? Success: -19.09
# 7df5635a-6f79-4fd2-8dc4-a5040e04cf4c
# What is the percentage change in the value of finished goods between 2018 and 2019? Success: -6.7
# da716abd-9641-4038-8f1d-4233fcf405ee
# What is the percentage change in the long-lived assets in United States from 2018 to 2019? Success: 18.94
# 3561fe2c-d1b1-4968-9d89-b6fa2d24bbe7
# What is the percentage change in the long-lived assets in Korea from 2018 to 2019? Success: 15.99
# cd461457-bc43-45fe-9a82-147a7dd1c700
# What is the percentage change in the total long-lived assets from 2018 to 2019? Success: 17.34
# 440e65d7-7c5c-4a28-871c-a828fa9860f3
# What was the average Services for 2018 and 2019? Success: 244800.5
# f1d5753b-05a9-4752-b03a-493e97804fb7
# What is the average total cost of revenue for 2018 and 2019? failure: 310611.5 good answer:  310566.5
# 2e3d4fe2-96f3-4ad9-b23f-1c590897b6e5
# What is the increase / (decrease) in the RSUs Granted from 2018 to 2019? Success: 91.0
# 99f83ba7-2e57-44d8-ac0a-64ab3e9c7b47
# What is the average RSUs vested? Success: 424.0
# 8b2d5db2-7a47-4269-9df2-f44385bc0883
# What is the percentage increase / (decrease) in PSUs granted from 2018 to 2019? Success: 38.98
# 9963bd65-093e-4801-8050-d2524ff06e7f
# For 2018, what is the percentage of constitution of employee severance and related costs among the total cost? Success: 73.68
# f91f52fd-ed2d-448f-82ad-c95a10bc64d2
# What was the percentage change in total assets between 2015 and 2016? Success: 5.42
# 568f039b-5753-4e91-b3aa-17cbcbe9b259
# What was the change in the Pre-contract costs from 2018 to 2020? Success: -35.0
# 00a60f91-b2d2-4bc5-acc4-69121abf68a9
# What was the change in the Equity method investments from 2018 to 2020? Success: -7.0
# 9634107c-5ee5-4ad0-bc6e-47d6651b4d07
# What is the average sales for years F19 and F18? Success: 1641.5
# e18e3335-7e7a-4138-9f1b-813604e44c3c
# What is the nominal difference in EBITDA between F19 and F18? Success: 11.0
# 9750180c-588d-4ba3-bc94-297d64b50e44
# What is the percentage constitution of Depreciation and Amortisation in EBITDA in F19? failure: -29.84 good answer:  29.84
# 7e058249-0f63-4002-912b-598bb9c62352
# What is the total value of computer equipment and software at the end of 2018 and 2019 altogether? Success: 28747.0
# afab19a4-a914-4a88-bc9d-699662b7fd3d
# What is the average value of computer equipment and software in both 2018 and 2019? Success: 14373.5
# b11567d3-d651-40d8-9b9e-bc71eb37d7f9
# What was the percentage change in Transportation equipment in 2019 from 2018? Success: -3.62
# 93c3d11c-cf30-4464-a882-479f5f0b3f79
# What was the percentage change in total receivables, net between 2018 and 2019? Success: 6.52
# ffae65ab-7123-4c57-88a8-3bfec53e782a
# What was the change in Autodesk's goodwill from 2018 to 2019? Success: 830.6
# f4abaf73-faa0-430f-8a7c-c499b84550bf
# What is the total ending goodwill for the years 2018 and 2019? Success: 4071.0
# 9547b235-f8de-4c17-a9ac-e78277fcaf1a
# What is the average ending goodwill for the 2 year period from 2018 to 2019? Success: 2035.5
# 14381fab-36ac-482b-9f77-2c78f3f34ffb
# What was the change in Additions in 2019 from 2018? Success: 0.7
# 20092aeb-d39f-4b50-b927-0602b8a95c08
# What was the percentage change in Additions in 2019 from 2018? Success: 29.17
# 775c21fd-9c4c-44d7-9879-81c2ca6d2420
# What was the percentage change in cash and cash equivalents from 2018 to 2019 year end? Success: 25.39
# b70b2805-122b-436f-99cb-53be477a2b6e
# What was the percentage change in net inventories from 2018 to 2019 year end? Success: 34.61
# 732c81f8-a16d-4d34-9917-fa98c195feec
# What was the percentage change in accounts payables from 2018 to 2019 year end? Success: 103.67
# 182dd9ea-dd5f-4ea0-bc30-bb42ef1f801c
# What percentage of the total unrealized gain is generated from U.S. government obligations in 2018? Success: 2.84
# f6cb9974-2af7-43b3-9e1c-8cd5439dff67
# What percentage of the total amortized cost is made up of foreign government obligations in 2018? Success: 43.15
# f6ccfc15-3970-467d-b83e-e2ce0ff365e3
# What were the total expenses in 2019? failure: 86603.0 good answer:  82884
# 405f18a8-803b-4f68-be49-7490b74b3697
# What was the change in Earnings before interest and taxes EBIT in 2018/2019 from 2017/2018? Success: 115.0
# c5757bb4-a312-48ed-a244-29932669363c
# What was the percentage change in Earnings before interest and taxes EBIT in 2018/2019 from 2017/2018? Success: 16.13
# 1504af2b-2364-4a59-8883-634a4ef67a34
# What was the average orders for 2019 and 2018? Success: 12312.0
# 7a77310d-bdbd-4ddd-886d-15b70985e957
# What is the increase / (decrease) in revenue from 2018 to 2019? Success: 1105.0
# ef466edc-6087-429c-89ac-359e6cb0977f
# What is the increase / (decrease) in the Adjusted EBITDA margin from 2018 to 2019? Success: -0.6
# c36e2211-e46a-43d1-a0a8-ae87af347ae8
# What was the change in the Net cash provided by (used in) investing activities from 2017 to 2018? Success: -43.0
# 163f08ab-cfae-426a-9c03-4f84feba3bb6
# What was the average Net cash used in financing activities between fiscal years 2017-2019? failure: -568.0 good answer:  615
# e81574d8-f9e8-48b3-85ab-a7ed36f8cbb0
# What was the change in Acquisition and integration costs in 2019 from 2018? Success: 9.0
# 426e47ae-aff7-43e2-81be-0bb951b0def1
# What was the percentage change in Acquisition and integration costs in 2019 from 2018? failure: 259.8 good answer:  112.5
# 07148f97-1ced-46e4-a141-5cdffe6e6528
# What was the change in the (Loss)/profit before taxation from 2018 to 2019? Success: -63.6
# 88795fae-3c5b-48d4-ae2d-57fe04b15c31
# What is the average Non-deductible items for 2018 and 2019? Success: -0.5
# ed9e3e80-6941-4888-9e40-bbd1cb092485
# What was the average Adjustment for share-based payments for 2018 and 2019? failure: 0.0 good answer:  -0.5
# 5f282807-f3fe-4efd-a4ef-b88a3d580bf9
# What was the change in revenue from external customers from UK in 2019 from 2018? Success: 9.7
# 44f28f4e-ce84-4300-b8d1-1644dda31933
# What was the percentage change in revenue from external customers from UK in 2019 from 2018? Success: 13.2
# cfbbdf60-d0d7-458c-853c-d1ffa1e8356f
# What was the increase / (decrease) in the Furniture and equipment from 2018 to 2019? Success: 933.0
# a032279a-fde8-4152-9350-e5a9340f27c4
# What was the average Furniture and equipment for 2018 and 2019? Success: 11137.5
# f5eb2ada-9a3c-4bbd-b96d-a83844cef935
# What was the average leasehold improvements for 2018 and 2019? Success: 6900.0
# 5c59c850-a720-4b1f-b703-9e1d9ff8e242
# What was the change in Accrued pension liabilities in 2019 from 2018? Success: 0.1
# 4f1d7142-98fe-4e6a-b8ea-3c2c451f5037
# What was the percentage change in Accrued pension liabilities in 2019 from 2018? Success: 3.03
# e3041bef-c305-431f-b165-54cb8bca77fb
# What was the change in Inventory between 2018 and 2019? Success: 535.0
# 8c13eea0-3bc9-44d4-9352-e8380333a791
# What was the change in deferred compensation between 2018 and 2019? Success: 881.0
# 95d916dc-67ce-4af0-8a84-574dce094c84
# What was the percentage change in net deferred tax assets between 2018 and 2019? Success: -79.67
# c0d6605c-50c2-42b1-94f6-c4c601559918
# What was the change in the State income taxes, net of federal tax benefit from 2017 to 2018? Success: -21.0
# b194279c-16e5-4a17-9733-c8babb6e8281
# What is the average Excess tax benefits from stock-based compensation in 2018 and 2017? Success: -10.5
# 81cab6e1-acb6-4c1e-a5f7-ae283cbd1b53
# What is the net difference in sale of systems between 2017 and 2019? Success: -531925.0
# ff1e12e8-e148-470f-95a8-3f23e02fa62d
# What is the net difference in sale of modules between 2017 and 2019? Success: 653718.0
# a4be9eab-ad03-4d67-9136-62d7cbe40e1e
# What is the net percentage difference in net sales between 2017 and 2019? Success: 4.14
# 162f80b9-b689-4405-b6b2-5e98d3882ce7
# What is the change in Trade receivables from 2018 to 2019? Success: 716.0
# 0b7463b3-ed9e-47a0-b838-b26e0ab886eb
# What is the change in Allowance for expected credit losses from 2018 to 2019? failure: -112.0 good answer:  112
# acbacb07-2a66-418b-b6da-53424c35abd5
# What is the change in Other receivables from 2018 to 2019? Success: 141.0
# 49e5b466-62c9-4cab-8d70-8e9317e7a007
# In the first quarter of 2018, what is the difference between the low and high price?(2.41, '')
#  Success: 2.41
# 5beff07b-d9e0-4592-b11a-47bc4bbb5e07
# What is the average quarterly low price in 2018? Success: 3.83
# 7707ff1b-ca2c-4d72-aad1-81315a5f54ff
# What is the change in the value of Total inventories between October 31, 2019 and 2018? Success: 49872.0
# 12005950-7f78-497e-a1b4-cfc8c7389aa1
# What is the average value of Packaging materials for October 31, 2019 and 2018? Success: 7017.5
# 297b00ae-9c26-4401-82b5-a6de76674ee9
# What is the average value of Prepared chicken for October 31, 2019 and 2018? Success: 16811.5
# ebae8430-83a7-49c7-af14-99ddf4b1e376
# What is the total amount of audit fees in both 2018 and 2019? Success: 113000.0
# 1fe30b3b-c8d4-47e2-a4b2-d2a583da9ce7
# What is the percentage change in tax fees from 2018 to 2019? Success: -60.71
# 2d0072b8-5110-4323-ac2e-0d294045da92
# What is the percentage of audit fees in total fees in 2019? Success: 83.33
# c34555c9-39a6-4505-bc7e-fcabfa3ae6cd
# What is the net total underlying rights and other for both finite-lived and indefinite-lived intangible assets as of June 30, 2019? failure: 67.2 good answer:  16.4
# 2e569f93-d58b-44a7-a947-ea6784b0623d
# What is the increase/ (decrease) in Revenues from, 2019 to 2018? Success: 90494.0
# fd59c14d-0312-4725-92d8-5c30cd5c5c7a
# What is the increase/ (decrease) in Voyage expenses from, 2019 to 2018? failure: 6850.0 good answer:  -6850
# 4cf34f4c-68c1-40f0-bb79-80ee15b256ed
# What is the average tax related accruals for 2018 and 2019? Success: 34.6
# ea159bf1-8401-4540-b5a7-8fbdb5476944
# What is the average accrued payroll and employee benefits for 2018 and 2019? Success: 111.4
# 79f51c3d-59d3-4abc-b0cd-d9e28668fbf4
# What is the average derivative liabilities for 2018 and 2019? Success: 107.15
# 2b5044df-ad20-4146-a571-e778cfc88c8d
# What is the percentage change of the investments accounted for at cost, adjusted for observable price changes between 2018 and 2019? Success: 40.0
# 170c75fb-da08-4e9d-8c5a-7cbb94e4176e
# What percentage of total non-marketable investments were accounted for using the equity method in 2019? Success: 82.05
# b8afd327-b836-4276-8556-eac89746b09f
# What is the change in the Combustion of fuel and operation of facilities (Scope 1) from FY18 to FY19 for UK and Ireland only? Success: -6841.0
# 4946fa71-15ec-4d2f-8604-2d1f775950fc
# What is the average Electricity, heat, steam and cooling purchased for own use (Scope 2) for FY18 and FY19 for UK and Ireland only? failure: 63888.0 good answer:  30011
# 95497d9b-23d7-4c89-832c-bcf408981985
# What is the change in the Green tariff from FY18 to FY19 for UK and Ireland only? Success: -27603.0
# 27bc5656-93b7-4109-b1d2-25710ca3240f
# How much is the change in transfers between 2018 year end and 2019 year end? Success: 77395.0
# e314bfab-8cd6-4bb3-b0e6-df664300c380
# How much is the change in disposals between 2018 year end and 2019 year end? Success: -1859.0
# f96cce90-9703-4b6b-9ea4-1a650ac8765a
# What is the change in "impact of exchange rate" from FY 2018 to FY 2019? failure: 4.66 good answer:  9.9
# 127264c3-16b9-4324-aff1-722420c93b5d
# What is the average INR-GBP exchange rate in FY 2019? failure: 91.6 good answer:  0.01
# Invalid  Currency
# 3a467fa9-64d9-4214-9f5e-0e7a101efd57
# What is the average USD-EUR exchange rate in FY 2019? failure: 75.44 good answer:  0.87
# 9f7000b0-e7b7-48b2-bcc6-8f77209894f2
# What is the current ratio in 2019? Success: 0.78
# Invalid  ratio
# 6514b16b-bdc1-4fa7-8e3a-3ec766713975
# What is the debt-to-asset ratio in 2018? Success: 0.27
# a1631baf-106c-4867-8173-6ff98f4ec421
# What is the change in current ratio from 2018 to 2019? Success: -0.03
# bd8bb8d3-c7e9-4a7f-be23-97b27a29f74e
# What was the percentage change in the total between 2018 and 2019? Success: -4.59
# 81c99a9e-786b-4ab6-94ed-e3149d697347
# What is the percentage difference of total liabilities when comparing after adjustment to before adjustment? Success: 5.48
# 9332c840-68f6-43e1-a06c-902dae3fef81
# What is the total equity of the acquisation as of December 31, 2019? Success: 445.69999999999993
# e151e953-f5ab-4041-8e6f-7aec08ed5a60
# What is the liability to asset ratio as of December 31, 2019?[Error]division by zero
#  failure: [Error]division by zero good answer:  18.34
# 503dde52-a6e1-4c63-aca5-ff3d92ea2854
# What is the change in income from operations between 2019 and 2018? Success: 2904.0
# e2419503-003d-4893-947b-72c8161ec572
# What is the average amount of revenues for 2018 and 2019? Success: 67669.0
# e172ba38-34fa-477b-b535-bac8d65756fb
# What is the percentage change in revenues from 2018 to 2019? Success: 1.05
# 398246d7-5500-4560-8a8f-220a782b05e5
# What was the percentage change in net inventories between 2018 and 2019? Success: -2.87
# cf67e41d-d7f2-4804-97a2-5c81fa266ad3
# How much is the Revenue in the first quarter of Fiscal 2018 as a percentage of the total revenue that year? Success: 24.07
# 0b835494-2c10-4f6b-b54a-60aa73ebdabe
# What is the change in the Total Gross Margin between Fiscal 2018 and 2019?[Error]
#  failure: [Error] good answer:  0.6000000000000001
# 716a0054-4177-43f6-b320-8de375eb3642
# What was the average Expected term (years) for 2017-2019? Success: 4.77
# Invalid  years
# 4ba37f67-0474-4e5c-8f45-da51a2873072
# What is the change in the Expected volatility from 2018 to 2019? Success: 6.1
# bfb033dc-19dc-41cc-9253-aa7e03b61a62
# What was the difference in the Weighted-Average Useful Lives between Trademarks and tradenames and Other intangible assets? Success: 3.0
# f8011fb0-e5d3-464f-85c0-1d6752a8617c
# What is the increase/ (decrease) in Revenues of Teekay LNG from, 2019 to 2018? Success: 90494.0
# 214a2cb0-5810-4004-9020-33578ea08030
# What is the increase/ (decrease) in Revenues of Teekay Tankers from, 2019 to 2018? Success: 167424.0
# 58060f0e-fb29-4aaf-b4c7-7e43d16e009d
# What is the average Employee separation expenses for the year ended December 31, 2019 to 2018? Success: 1622.0
# 3258cedc-30b4-4048-bf67-9aa0b487e1b3
# What is the average Lease related expenses for the year ended December 31, 2019 to 2018? Success: 1454.5
# 3525bcc2-5684-45a3-9a2e-4b35de25551a
# What is the average Other for the year ended December 31, 2019 to 2018? Success: 160.5
# 4cee3e03-ed30-4e2c-8718-e65ad795d4e8
# What is the increase / (decrease) in the Gross Profit from 2018 to 2019? Success: -138187.0
# 3502f875-f816-4a00-986c-fef9b08c0f96
# What is the COGS for 2019? failure: 153988.17 good answer:  -168630
# 0cca40eb-3b7e-4ea2-83b0-c6be83190b12
# What is the percentage increase / (decrease) in average Urner Barry Spot Egg Market Quotations 1 in 2019 compared to 2018? Success: -17.45
# d06a5ade-d848-4325-a2a5-8f5ef427d246
# What is the average total basic earnings per share for both 2018 and 2019? failure: 1303.1 good answer:  169.4
# 87cdfd06-a9ef-48e8-a44e-9addd92a0d0c
# What is the percentage constitution of continuing operations in diluted earnings per share in 2019? failure: 8.65 good answer:  55.44
# 8c882f0d-684c-430e-8194-997c565a7258
# What is the nominal difference for basic earnings per share (cents per share) between 2018 and 2019? failure: 9.1 good answer:  73.6
# Invalid  cents
# 9a11777d-c146-4a13-aaa0-7676223a7849
# What is the increase / (decrease) in the Realized gains (losses) on maturity and/or partial termination of cross currency swap from 2018 to 2019?[Error]unsupported operand type(s) for -: 'NoneType' and 'float'
#  failure: [Error]unsupported operand type(s) for -: 'NoneType' and 'float' good answer:  42271
# f49252e2-158b-4a79-ac56-d21ea67082a8
# What was the average realized losses?(-10029.67, '$')
#  Success: -10029.67
# Invalid  $
# a58cbfcf-2568-4bd6-ae26-b64656f22dcf
# What is the percentage increase / (decrease) in the Unrealized (losses) gains from 2017 to 2018? Success: -74.31
# d8ef780b-5c02-4c2e-a0c5-b9fd8dba625c
# What is the difference between the high and low price in September 29, 2019? Success: 20.53
# e378f03f-8e13-4020-b4ba-641859e16e25
# What is the percentage increase in the high price from July 7, 2019 to September 29, 2019? Success: 3.94
# 3b3d21ab-f76f-4ae3-ae00-cecf04e0b499
# What is the difference in the low prices between September 30, 2018 and July 8, 2018? failure: -5.03 good answer:  2.64
# 8697d0a4-7073-4834-a055-44cccb3db95c
# What is the average Selling, general and administrative expense for December 31, 2018 and 2019? Success: 19582777.0
# 6c9d393a-c3d5-496f-a9d1-717fe1878c68
# What is the average Research, development and engineering expense for December 31, 2018 and 2019?(5631086.0, '$')
#  Success: 5631086.0
# Invalid  $
# c91ad938-6ad1-4481-8f6b-43ccd2f69926
# What is the nominal difference for ROFE between F19 and F18? failure: -1.9 good answer:  1.9
# 3c257d89-4281-43df-998a-f7850b4fda9c
# What is the average value for sales per square metre for both F19 and F18? Success: 18384.5
# 6586d5cf-16c3-444a-b946-f8485a5c2a82
# What is the average ROFE for the years F19 and F18? Success: 16.15
# d8637395-dbdb-4d49-a48b-ef14e97ebce5
# What is the average voyage revenue in 2018 and 2019?[Error]
#  failure: [Error] good answer:  303118
# bdcabe8e-6738-47d3-8412-40e5e9a359d0
# What is the average voyage expenses in 2018 and 2019? failure: -153391.0 good answer:  153391
# c1529a4c-f974-466d-b9e5-356cb9a7c928
# What is the average net voyage revenue in 2018 and 2019? Success: 149727.0
# 889488f7-d2a4-4612-b146-a5dd3db8ff2e
# How much was the average interest expenses in 2018 and 2019 ? Success: 2053.5
# 2e453484-3c53-4073-a29f-56a64364f4d9
# What was the difference in interest expenses in 2019 and 2018? Success: 57.0
# aa4b7a98-1ec7-4bd8-a258-e928e92c9f75
# What is the average of Net revenues by geographical region of shipment? failure: 9307.75 good answer:  9189
# fa5d745e-66cd-49cf-ac91-b6916a412c7d
# What is the average of Revenues from sale of services? Success: 144.0
# 699b2f87-84df-49a3-a9a1-41e26eed0577
# What is the average of Other revenues? Success: 39.33
# 805a22a0-bc6b-42e1-98a3-9f665b8b4eec
# What is the change in total cost of revenue between 2019 and 2018? failure: -3015.0 good answer:  -5.8100000000000005
# d9eba295-6903-457d-924d-663e41d20b46
# What is the total cost of revenue in both 2019 and 2018? failure: 201554.0 good answer:  100777
# dd31fc40-d055-4356-bcfc-c7348842bf3c
# What is the proportion of products as a percentage of the total cost of revenue in 2019? Success: 61.0
# ca5ace26-609f-4199-b5a0-68ccf25ba98e
# What was the sum of all Income tax net operating loss carryforwards? failure: 623111.0 good answer:  622908
# fe5839ad-4387-4abb-ae4b-9e61feacd97a
# What was the sum of all Tax credit carryforwards? failure: 58846.0 good answer:  58442
# a1fb1d57-243c-49e0-84ee-43d969cd41b0
# What was the domestic-state tax credit carryforwards as a ratio of domestic-federal tax credit carryforwards? Success: 0.08
# 54dd0e9e-c525-4bea-8bd7-b292e9dd9be3
# What is the percentage change in the net investment in finance lease from 2018 to 2019? Success: -33.33
# ab7c4466-0cd7-4f3b-8d2a-73bb9abf0053
# What is the percentage change in the amounts owed by members of Peel from 2018 to 2019? Success: 0.0
# 8c6bc2ca-b758-49f8-82e3-c1ede110102b
# What is the percentage change in the amounts owed to members of Peel from 2018 to 2019? Success: -0.0
# b5ede057-3e98-4851-a1e1-1774c52cd908
# What is the average salaries and fees between 2018 and 2019? Success: 4.0
# 7639efef-c768-4631-95b5-382a0fde501d
# What is the average incentive schemes between 2018 and 2019? Success: 2.5
# f86dbe96-d977-4f6f-8846-fe1b44c8e205
# What is the difference between average salaries and fees and average incentive schemes from 2018 to 2019? Success: 1.5
# 005da8e4-571e-4612-9333-6c77d03ed838
# What is the percentage change of total assets from 2018 to 2019? Success: 14.16
# af4ea6d6-4672-4ddb-8348-047ced2b5572
# What is the average total asset value for 2018 and 2019? failure: 1528.99 good answer:  5407.7
# ee74c321-b0e8-44f6-b15a-a4e8511b6183
# What was the change in total emissions? Success: -301.9
# d5656a8c-6ef7-4e56-a3d4-8e3dc2bd5bed
# What was the percentage change in total emissions? Success: -5.93
# 8fb4b76c-b4d9-40e9-8233-28a19d06df41
# What is the difference between the net cash provided by operating activities from 2018 to 2019? Success: -835.0
# 2438c6b7-f88b-46c9-a0d8-4031e6452955
# How much was the average net cash provided by operating activities from 2018 to 2019? Success: 14968.5
# 524463b6-b8d7-410d-926a-699f7b7cdd99
# What is the difference between the net cash used for financing activities in 2018 and 2019? Success: -32074.0
# 4990b27f-a8a6-4683-82f8-c1cf657ba9c1
# What is the average discount rate for 2018 and 2019? Success: 3.35
# 066fbf2d-e3e7-4f55-bbe0-a71ddeaa2685
# What is the change in expected rate of salary increase between 2018 and 2019? Success: 0.0
# 0f6a8eaa-3e1e-4c91-b175-22bcef454b35
# What is the average rate of price inflation for 2018 and 2019? Success: 2.0
# 078e34fa-b33a-43fe-afd3-d39b4cbd6a6b
# What was the change in percentage of sales represented by gross profit between 2018 and 2019? Success: -10.9
# 85bc877a-ecc1-4d1a-9e45-6ddb6d0a4dc3
# What was the change in percentage of sales represented by net other income between 2018 and 2019? failure: 1500.0 good answer:  1.5
# 37a06d19-6aec-40a6-862a-fa7629b64208
# What was the change in percentage of sales represented by provision for income taxes between 2018 and 2019? Success: -2.1
# e10133f7-0579-4a1d-b41c-c12210fc7559
# What is the percentage change in the total trade receivables from 2018 to 2019? Success: 11.45
# 34e0adca-febe-4862-a4db-8581df95e44b
# What is the percentage of the trade receivables that are three to six months of age in the total trade receivables in 2019? Success: 25.06
# c72f2f6d-3d88-406d-a482-0736ae4846b0
# What was the change in the amount in APJ in 2019 from 2018? Success: -4.9
# 634122ee-5fb5-4e38-a552-5673e23987cf
# What was the percentage change in the amount in APJ in 2019 from 2018? Success: -4.73
# 15cd82e8-7fe9-4529-a44f-eca0ce5137fb
# What is the Total net revenue for fiscal 2018 and 2017? Success: 3944.0
# 8f75bf3a-849c-4979-b82a-b53dbcf42509
# What is the average net revenue for fiscal year 2018 and 2017? Success: 1972.0
# b99d3748-44ec-44e8-9de7-12567ccbd479
# What is the average Operating income for Fiscal 2018 and 2017? Success: 975.0
# ff71e762-7a3d-4b9e-aa75-3ab148d8154c
# What was the change in the average life expectancy for a male member aged 65 in 2019 from 2018? Success: -0.5
# 8cf06f37-dccd-4b16-8f75-5359a9a55d93
# What was the percentage change in the average life expectancy for a male member aged 65 in 2019 from 2018? Success: -0.57
# df12359b-c35a-4c26-bfbf-a8c05f063be9
# How much more cloud and license revenues came from the Americas as compared to Asia Pacific in 2018? Success: 13182.0
# beabd8a7-9ed5-4121-8415-6198bb1d642f
# What was the total applications revenues in 2019 and 2018? failure: (11510.0, 'million') good answer:  22575
# $$$$
# 3cbbe606-2c3c-4e20-a266-3dc3fc00adb7
# What was the change in the Total amount in 2019 from 2018? Success: 3.5
# 0f59d1f7-562f-4f9a-a0ff-1abba61accbe
# What was the percentage change in the Total amount in 2019 from 2018? Success: 8.54
# 973464b5-a5fe-4381-9bc5-e225f5ba9a2c
# What was the absolute percentage change in risk-free interest rate between 2018 and 2019? Success: 0.8
# 4082086c-6f47-40b1-8ac1-757d437a502d
# What was the absolute percentage change in Expected volatility between 2019 and 2020? failure: 18.21 good answer:  -6.1
# 0dbcbf46-790f-465c-ae57-ffe0167aee5e
# What is the change in Revenue of Software delivery, support and maintenance between 2017 and 2018? failure: -596.0 good answer:  -1508
# 4608c69d-d134-4d16-b639-731f5d3b03cd
# What is the change in Cost of revenue of Software delivery, support and maintenance between 2018 and 2017?[Error]
#  failure: [Error] good answer:  -596
# 0550ae54-99f4-4b87-b1a7-11d402a94918
# What is the change in Cost of revenue of Client services from 2018 to 2017? failure: -640.0 good answer:  569
# e3f430ad-0f9f-4cfc-9976-3e99271555fa
# What was the change in services between 2018 and 2019? Success: -4931.0
# 7f111469-0ffc-4d6f-bde7-0f150bf0c93e
# What was the change in total revenue between 2018 and 2019? Success: -6216.0
# 0339e2bb-4a63-4f23-aaea-b9fa3cb29737
# From fiscal year 2020 - 2024, what is the difference in the number of ground leases and land and building leases expiring? Success: 316.0
# 73521986-bd59-404b-8eb5-c2a24e2bc8ee
# From fiscal year 2025 - 2029, what is the total number of ground leases and land and building leases expiring in total? Success: 468.0
# 258df1b4-3db1-4616-ae6b-c46a98b88dcf
# What is the difference of ground leases expiring between the periods 2020 - 2024 and 2025 - 2029? Success: 183.0
# 61c7a52b-6849-4e09-84e4-a5020e51c744
# What is the average discount rate over the 3 year period from 2017 to 2019? Success: 2.7
# c55030b2-41b7-4a9e-b954-03680ac7002f
# How much did the expected long term rate of return on plan assets decrease by from 2017 to 2019? Success: 1.0
# a6dca142-4691-4a05-9c78-9087cdc491f6
# What is the average discount rate over the 3 year period from 2017 to 2019? Success: 2.7
# a8ab5675-0560-4cd0-a294-76fd54b04ad6
# What was the change in the amount for Ireland? failure: 0.1 good answer:  -0.1
# 0ae9262d-c0fd-4b56-b896-2b37f90810bc
# What was the percentage change in the amount for Ireland? Success: -20.0
# e4f21617-1a84-40e4-bdf0-671df88cb862
# What is the percentage change in the working capital adjustment at June 30 and December 31, 2019? Success: -52.63
# 22ea63c7-2e41-48d8-8133-1fd9acebbb5b
# What is the percentage change in the total fair value of consideration transferred at June 30 and December 31, 2019? Success: 0.53
# bdfa7f74-0ec6-461f-a531-c164c7134a2f
# What is the percentage change in the audit fees from 2018 to 2019? Success: 32.69
# 153f3925-277e-4fe8-8edc-50a5089420ea
# What is the percentage of non-audit fees in the total fees paid to auditor in 2019? Success: 35.38
# d374633d-d7ff-41b7-9982-f0388c3d0323
# What is the percentage change in the total fees paid to auditor from 2018 to 2019? Success: 53.08
# 359f9c4c-b405-40e5-88b5-86bfa0069b89
# What was the percentage change in the Reductions related to a lapse of applicable statute of limitations between 2017 and 2018? Success: 185.3
# 9fa0bb46-4243-4629-81c2-3ba6e549fee0
# What was the change in the land value from 2018 to 2019? Success: 2.9
# 204ecd0e-d405-4a41-8163-10f670f987b5
# What is the average Buildings and Building Improvements value for 2018 and 2019? Success: 75.2
# f2f39c26-9c31-4b39-b9c1-d5b4508736d6
# What was the change in average price paid per share between the first to second month period? Success: 0.76
# e02b2c21-3972-41cc-b391-5478da7df9d8
# What was the change in the total number of shares purchased between the second to third month period? failure: 3642.0 good answer:  228
# 9a098fcb-9839-4b16-8eeb-7cf291463744
# What was the total number of shares purchased between the first month as a percentage of total shares purchased in the three month period? Success: 3.61
# 24395900-adc1-4c9d-8ce9-bd21c5a54808
# What was the percentage change in Net income attributable to American Tower Corporation stockholders between 2018 and 2019? Success: 52.69
# d1e84439-5663-4c28-9d59-3854a0104409
# What is the percentage increase in cash provided from financing activities between 2018 and 2019? Success: -21.92
# 6befb6ea-a586-43d2-80bd-14f0721dd6f1
# What is the percentage change in the total other non-current assets between 2018 and 2019? Success: 385.45
# c52dc053-375e-4b4d-b4ce-757bb39fa256
# What is the total value of other non-current assets between 2018 to 2019? Success: 50466.0
# 9df4e7cf-9a10-40e2-b52e-9278948fce53
# What is the total deposits in 2018 and 2019? Success: 4313.0
# 5a09d607-3502-4451-9d1a-a222dfc32968
# What is the average number of nonvested shares granted on January 1, 2017 and between December 30, 2018 and December 29, 2019? failure: 329.0 good answer:  242.5
# f9898b19-f84e-4cd8-9cd2-330767f39a38
# What is the average number of nonvested shares vested on January 1, 2017 and between December 30, 2018 and December 29, 2019? failure: 189.0 good answer:  80.5
# f140a65f-c408-45fc-8c60-e98e13530452
# What is the average number of nonvested shares forfeited on January 1, 2017 and between December 30, 2018 and December 29, 2019? failure: -26.0 good answer:  30
# 34144864-790c-4733-8323-91347f68f5ef
# What is the global increase / (decrease) in the hindi films from 2018 to 2019? Success: -3.0
# 6ba4045d-4222-4da0-a126-94b267a707ec
# What is the average global regional films (excluding Tamil films) from 2017-2019? Success: 21.33
# e9b75381-50b1-4717-a322-31ed1eef4259
# What is the global increase / (decrease) in the Tamil films from 2017 to 2018? Success: -2.0
# 070a9fb1-6d17-40ba-b34e-82d0fe14037b
# What is the percentage change in the research and development costs incurred from 2018 to 2019? Success: 3.85
# a8a7c154-567e-4b21-878e-85dab9d28fc9
# What is the percentage change in the total expense relating to operating leases from 2018 to 2019? Success: 20.6
# 9fce8f25-dd3b-4c50-9b7b-d200ced15ded
# What is the percentage change in the finance costs expensed from 2018 to 2019? Success: 222.58
# [Outer Exception]0 is not in list
# 06dfc869-b3e2-446e-9b9a-1b2374c63c04
# What is the percentage change in cash provided by financing activities between 2018 and 2019? Success: 59.99
# 521b36fd-2b60-466b-b420-fbf776531e37
# What is the total cash provided by financing activities between 2017 to 2019? Success: 17842.0
# 9238f11f-18d1-416b-ad2d-2692229c8d3a
# What is the total cash provided by all cash flow related activities between 2017 to 2019? Success: 16767.0
# c438e7d0-68d6-46c5-b5c7-6507889fa210
# What was the average Interest income for 2018 and 2019? Success: 21731.5
# 1427bbad-0def-4340-a537-4713dad96ea7
# What was the average interest expense for 2018 and 2019? failure: -11888.0 good answer:  11888
# 0a9b94be-b354-46e2-a448-e68b5f9f5e92
# What is the percentage change of net operating losses and credits from 2018 to 2019? Success: 84.53
# 33fd26df-9da7-489c-96e6-bd43a8b79d89
# What is the average Products and licensing costs for December 31, 2018 and 2019? Success: 12381521.0
# 032682c3-c3c1-4e3b-9554-05f68fdb4cc8
# What is the average Technology development costs for December 31, 2018 and 2019? Success: 17024818.0
# a3ea64bc-4447-4c0b-b76c-84575a3a0de2
# What is the average Research and development funding? Success: 83.0
# 33de3029-3056-4598-bdff-30d9be4f52c3
# What is the average gain on sale of businesses and non-current assets? Success: 6.33
# cd3367c7-d3bd-440c-8c51-90a6ee95cc77
# What is the increase/ (decrease) in Research and development funding from 2017 to 2019? Success: 67.0
# a8b031ed-58ec-418a-a229-89ad5444a6bb
# What was the change in Property, Plant, and Equipment, Net in 2019 from 2018? Success: 77.0
# c174c321-d180-4335-b562-e570536f0725
# What was the percentage change in Property, Plant, and Equipment, Net in 2019 from 2018? Success: 2.2
# 073c6499-cf72-47f2-8874-7dfc67f1e251
# What is the average of Net cash from operating activities? Success: 15.57
# bf683a17-9353-4784-94b3-8cf2a677b1f4
# What is the average of Cash, restricted cash and short-term marketable securities? Success: 11.33
# 4875e520-3ead-44f2-aefc-d1a9d087419d
# What is the average of Committed global credit facilities? Success: 15.3
# c0ba2609-ef77-4d95-883b-369d6d3258c7
# What was the change in Transportation Solutions in 2019 from 2018? Success: 74.0
# c48a89ed-da90-4c07-b51e-2e77b5817f3d
# What was the percentage change in Transportation Solutions in 2019 from 2018? Success: 1.57
# d76df306-5452-4d72-ba6a-968482943bee
# What was the average interest income for 2017 and 2018? Success: 910.0
# 12756239-28b8-482e-bfc8-c3dd6b2f2954
# What is the average Interest expense for 2017 and 2018? Success: -433.0
# 19bf32fd-847e-4449-84cf-f2f3df81b71b
# What is the percentage change in the total dividends paid from 2018 to 2019? Success: 9.73
# 9f000c2e-f928-401a-a3ba-2ef71b2bccf6
# What is the percentage change in the final dividend from 2018 to 2019? Success: 6.33
# 6fbcd1ee-5060-442b-a2d2-8d62ac822942
# What is the percentage change in the interim dividend from 2018 to 2019? Success: 12.99
# ff9b07aa-2cdc-425a-86b6-2f231421ce11
# What is the proportion (in percentage) of the sum of Grocery & Snacks and Refrigerated & Frozen’s net sales over total net sales in fiscal year 2018? Success: 76.09
# eca3afa3-cd52-44ed-9e62-2003038a0926
# What is the percentage change in total net sales of International and Foodservice from fiscal year 2018 to 2019? Success: -8.99
# 49dbbc90-5307-49ae-b802-e87d19214c40
# What is the change in total sales from fiscal 2018 to 2019? Success: 1600.1
# 2b77bd1e-17ee-4f74-9fb7-7cc4ad5142dd
# What is the percentage change in Other for deferred tax assets? Success: 4.34
# 190316bd-8f09-4e44-9648-e83d0bab44fb
# What was the change in Impairment losses between 2017 and 2018?[Error]
#  failure: [Error] good answer:  150092
# 5f289981-f13d-4160-8879-c81dc0b7381e
# What was the percentage change in the Share based compensation between 2017 and 2018?[Error]
#  failure: [Error] good answer:  6.05
# 4dc88328-739b-43e5-a61d-8492ec4552a6
# What is the increase / (decrease) in Outstanding, beginning of the year from 2018 to 2019? Success: 2161.0
# 90f9af10-77ac-441c-a53d-3167c15ad61b
# What was the average Issued from 2018 to 2019? Success: 8995.0
# b679f4bd-7a0f-4b2e-b8fc-12f08a5749fe
# What was the average dividend equivalent from 2018 to 2019? Success: 1071.5
# 4b1ab745-9b93-495b-9c45-ede4e32b7657
# What proportion of level 2 inputs is made up of money market funds?  failure: 0.0 good answer:  0.45
# 710bc8e8-3a6b-42ef-b122-a348250715f1
# What proportion of Total FairValue is made up of  level 2 inputs? failure: 100.0 good answer:  1
# 20b9f972-d7e9-4a47-a9ab-8c789db18f9d
# What is the percentage of other foreign borrowings and other domestic borrowings as a percentage of Total debt as of December 31, 2019 in fair values? Success: 2.49
# 57f38b17-ccdb-4d57-b075-9d1ff7dfb5e7
# What is the percentage difference between fair value and carrying amount of total debt as of December 31, 2018? Success: 1.75
# 77b14f34-b206-4b50-babb-aa9ee379410a
# What is the total carrying amount of Senior Notes due by December 2024 as of December 31, 2019? failure: 421.9 good answer:  1711.4
# 52b32d22-da73-4420-81e4-8cdad82d2125
# What was the change in the amount Outstanding at 1 April in 2019 from 2018?(421825.0, '')
#  Success: 421825.0
# 5c487c82-e20a-4c76-9f52-7831ab15075e
# What was the percentage change in the amount Outstanding at 1 April in 2019 from 2018? Success: 15.72
# 56327885-98fe-40db-93f8-f762b1bf5d20
# What was the percentage change in the ending balance between 2017 and 2018? Success: -31.58
# 90f6b6b5-3d82-459d-b9b7-d86dae985655
# What was the change in Net operating loss carryforwards from 2018 to 2019? Success: 590.0
# d547e798-a829-4b95-af68-e50705558993
# What was the average of Research and development credits in 2018 and 2019? Success: 77718.0
# ecf25a96-a643-4bed-a0bb-c6eaf4999269
# What is the 2019 average total amount falling due within one year? failure: 67225.14 good answer:  232328.5
# c07a4e8f-96eb-4b0d-b668-f7d6e64ed707
# What is the 2019 average total amount falling due after more than one year? failure: 67225.14 good answer:  2959.5
# ab50c5ce-cf88-45c7-acc8-2b73faa97d99
# What was the change in the number of shares granted in 2019 from 2018? Success: 93.8
# 43e6bb90-dd1b-4f54-bdb7-60556312ad4e
# What was the percentage change in the number of shares granted in 2019 from 2018? Success: 10.34
# 91f1515f-4771-403c-ba45-309079ea2723
# What is the change in Net Sales from Fiscal Year Ended April 28, 2018 to Fiscal Year Ended April 27, 2019? Success: 92.0
# 6a94f765-2c5a-4486-ba06-0057636740e0
# What is the change in Income before Income Taxes from Fiscal Year Ended April 28, 2018 to Fiscal Year Ended April 27, 2019? Success: -20.2
# 78f0aebe-c955-4e78-831e-0ffa77c0f50b
# What was the change in deferred revenue in 2019 from 2018? Success: -1.0
# 73618a72-ca8a-43f4-b384-409aec6bbb75
# What was the percentage change in deferred revenue in 2019 from 2018? Success: -20.0
# 643cfcef-6d2c-4df7-b538-3588e28b58e1
# What was the average losses recognized in other income (expense), net, across the 3 year period? failure: -236.0 good answer:  236
# f4a95f4d-5957-44e8-81b7-f0cd392c4409
# ...
# What is the increase/ (decrease) in Trade accounts receivable from 2018 to 2019? Success: 104.0
# f329027f-e65a-402c-908e-21f0a0d25fe0
# What is the increase / (decrease) in the primary service units  in net additions(losses) from 2018 to 2019? Success: -3270.0
# da0d6d2a-67e5-46ea-be1a-68797ec6b8ed
# What was the average increase / (decrease) in internet service customers between 2018 and 2019? Success: 21303.0
# 9c43de49-fcef-4ced-b07d-55fb6fff5f38
# What was the increase / (decrease) in the video service customers from 2018 to 2019? failure: 319315.0 good answer:  2063
# 438d631c-1dd3-4620-b851-d9ea5cec4ad5
# What was the change in the prepaid expenses and other from 2018 to 2019? Success: 495.0
# 565fb688-b453-46ce-ba8f-bfe2375a80d8
# What was the average of other assets for 2018 and 2019? Success: 1861.5
# 4ece6b8e-230b-475b-8354-b7d281332895
# What was the percentage change in the other assets from 2018 to 2019? Success: 5.46
# 6a964030-4a22-4fc0-a434-ebde9a551dbf
# What is the change between direct energy consumption (MWh) in 2018 and 2019 year end?(6292.13, 'MWh')
#  Success: 6292.13
# Invalid  MWh
# 24cd1ddb-a87d-4fde-9129-770a5fb65657
# What is the change between indirect energy consumption (MWh) in 2018 and 2019 year end? Success: 31311.65
# Invalid  MWh
# cd629cd1-a7ef-4d8c-a40a-a807f4564116
# What is the change between running water consumption (MWh) in 2018 and 2019 year end? Success: 310336.67
# Invalid  tonnes
# e3121b60-1b2f-4e65-92a2-cf3f02e60b46
# What is the increase / (decrease) in the Net cash from operating activities from 2018 to 2019? Success: 24.0
# 2cbf4301-6904-43a6-9fc0-0aa2869fff4f
# What is the average Net cash used in investing activities? Success: -1284.0
# ceb35697-abdc-4acf-a54f-5b6716749d2b
# What is the percentage increase / (decrease) in Free Cash Flow from 2018 to 2019?[Error]
#  failure: [Error] good answer:  -6.75
# 9f84812f-f352-4bdf-835d-e8d19254149a
# What is the nominal difference for the number of fully paid ordinary shares between 2018 and 2019? Success: 54633874
# 9c58a8eb-0bda-45fb-ac55-f13dae2ee285
# What is the average contributed equity at end of period for 2018 and 2019 in terms of $M?[Error]division by zero
#  failure: [Error]division by zero good answer:  5941.5
# 9a09df98-b30c-4f69-bf52-74532c8fdf9e
# What is the nominal difference in contributed equity between 2018 and 2019 in terms of $M ? failure: -56.6 good answer:  227
# 176587d4-2707-40ee-9bd5-cd2d75e17980
# What is the percentage change in net income between fiscal years 2019 and 2018? Success: -13.25
# 61c26008-59e3-4d44-b02e-2a473fb54600
# What is the percentage change in the cash and cash equivalents from 2018 to 2019? Success: -33.56
# b112827b-5e3d-43d3-a5a2-fb8fc885bd26
# What is the percentage change in the trade receivables and contract assets from 2018 to 2019? Success: -19.93
# a6cc136d-ceb2-49d7-9a0b-fae5b6d0424c
# What is the percentage change in the trail commission asset from 2018 to 2019? Success: 10.84
# add9076b-b167-4ff6-a071-fc94902d728d
# What was the change in Distribution in 2019 from 2018? Success: 4.7
# dab0e943-fc62-4e26-95e5-025b98ff9b57
# What was the percentage change in Distribution in 2019 from 2018? Success: 3.57
# 6f65d33d-c721-45f9-9519-9ea4f5d7e740
# What is the percentage change in Net cash used in investing activities between 2018 and 2019? Success: 368.13
# bb5be96c-78ed-4453-92cc-d07a3bf0b6ff
# What is the percentage change in net cash provided by operating activities between 2017 and 2018? Success: 33.69
# 058d1fa4-99b9-481d-a815-3c6df09cc031
# What is the percentage change in the net cost of land, property, and equipment in 2019 compared to 2018? Success: -18.93
# dba26022-09e9-486b-bc40-e2a9627384ed
# What is the proportion of land and leasehold improvements over the gross cost of land, property, and equipment in 2019? Success: 0.18
# aa016321-4bee-4f8c-a4a9-9abdfeddf9c2
# What is the ratio of the gross cost of land, property, and equipment in fiscal 2019 to fiscal 2018? Success: 0.97
# bbf04869-c442-4909-a65d-c7bc89b6e726
# What is the percentage increase in Swiss income from 2017 to 2018? Success: 10.15
# f46b6e30-d8a2-4d40-b485-b8c0c98d1b5b
# What percentage of the total income before taxes does Swiss income form a part of in 2019? failure: 29.65 good answer:  78.55
# 475616e0-6449-444e-8087-f9afc6da36be
# For Balance payable as at June 30, 2019, what is Workforce reduction expressed as a percentage of Facility costs? Success: 35.47
# 33437a5b-9c80-4961-a8c6-9a31c6458cf8
# What is the average percentage of net revenues of OEM? Success: 67.0
# a6bc87a3-0335-4914-bdc1-69fc6b941b69
# What is the average percentage of net revenues of Distribution? Success: 33.0
# 6a9b6186-6fea-4846-a230-053903f31e2d
# What is the increase/ (decrease) in percentage of net revenues of OEM from 2017 to 2019? failure: 6.06 good answer:  4
# b70433bd-7c92-413d-af00-cef3907cafe8
# What is the percentage constitution of cash in the total gains on the sale of company-operated restaurants in 2019?[Error]division by zero
#  failure: [Error]division by zero good answer:  93.7
# 73f75537-695c-431d-a917-18071def0090
# What was the change in the leasehold external valuation % from 2018 to 2019? Success: -37.0
# 98b13aba-4ca2-4369-87eb-a960c71b8a2c
# What is the average freehold internal valuation for 2018 and 2019? Success: 67.5
# eb86d5f5-d1b0-4761-ae4c-417b8775ce5b
# What is the change in the number of shares granted between 2018 and 2019? Success: 53113.0
# 8c47c1a7-0fea-4501-a9f3-8c2b3b5989b1
# What is the average shares vested between 2018 and 2019? Success: 202845.0
# 81bfcf69-2537-4d6b-8795-5dc91dc4e2d1
# What is the total provision for income taxes between 2017 to 2019? Success: 3695.0
# 13d32108-e758-457b-95a1-73f3bd918975
# What is the change in the current provision for income taxes at the state level between 2018 and 2019? failure: 5.0 good answer:  11.36
# 68107102-0fdc-4e64-850f-8eda6bcc892a
# What is the total federal tax expense between 2017 to 2019? Success: 16.0
# cbe6cbca-b772-4e12-b0ba-c32a7629d43e
# What is the Total change in general and administrative expenses from Fiscal year 2017 to 2019? failure: 32192.0 good answer:  37556
# 2581c0dc-1e8d-49b5-90a0-dd8a0f0ecfef
# What is the average annual Total change in general and administrative expenses for fiscal year 2017 to 2019?  failure: 3095.0 good answer:  18778
# fa15cd27-153d-44a0-b315-1fd0e6022714
# What is the difference in the increase of Travel and communication expense in fiscal years 2019 and 2018 as compared to 2018 and 2017?  Success: 714.0
# 6ba75fbd-3fd8-4756-b583-f696a50e39a7
# What is the average net change in cash balance across the 2 years? Success: -10.5
# abe51f5c-86e3-43cd-8e55-fd387d978321
# What is the average Cost of sales? failure: -3350.26 good answer:  5579.33
# 4758b4f3-871c-42e4-a606-284e26845ed1
# What is the average Gross profit? failure: 2168.54 good answer:  3609.67
# a648d9e3-1fea-40c9-a7e1-37dab9e1f934
# What is the average Gross margin (as percentage of net revenues)? Success: 39.3
# ac017bd6-9ee5-4d08-b96c-19fc5bb9d1ed
# What is the percentage change in gross deferred tax assets in 2019 compared to 2018? Success: 0.13
# 08ec32ab-4f3e-4549-876c-f4e668439ad9
# What is the proportion, in percentage, of deferred revenue and accrued warranty over gross deferred tax assets in 2019? Success: 1.18
# 32cbd9ff-637d-4b5f-b10b-92243f2e1a93
# What is the ratio of inventory reserves to accrued compensation in 2018? Success: 2.65
# 24f8613a-5516-4f0e-9839-8f6e31480785
# What was the percentage of total financial assets in Euro over the Group total? Success: 26.83
# fb2036af-5359-4b80-975f-3604f1ad67d5
# What was the percentage of financial assets on which interest is earned over the total financial assets forEuro? failure: 4.52 good answer:  15.53
# 0e22cef8-0342-4085-b5ad-a9ea512a8b3f
# What was the average Interest expense? failure: 717.63 good answer:  1033.5
# 312a9328-b83f-43c6-b652-59547090cd30
# What is the increase / (decrease) in Acquisition-related charges from 2018 to 2019?  failure: 0.0 good answer:  -228
# 276f39d7-5428-46cf-b808-7dd9eefab430
# What is the increase / (decrease) in the Operating (non-GAAP) interest expense from 2018 to 2019? failure: 0.0 good answer:  393
# f027451d-00f0-4ac1-8dd4-941404139f04
# What is the value of the company's total financing obligations as a percentage of its total purchase obligations? Success: 9.12
# a8306bab-9758-4e8b-be9a-f797a6601422
# What is the percentage increase in Total assets after adoption of new standard? Success: 0.72
# 1f619243-959e-4b47-a656-1d16b03e2ca5
# What is the percentage increase in Total stockholders’ equity after adoption of new standard? Success: 4.4
# 78d004fb-a7b1-4ad5-8870-a7e0462e999e
# What is the percentage increase in Retained earnings after adoption of new standard? failure: -63.99 good answer:  36.01
# 55a6f613-38bc-4bf6-b53a-bf2ef01c6ed2
# What is the company's average revenue from software license between 2018 and 2019? Success: 279371.0
# dc1e344f-db11-4415-af80-728cd87e1b6b
# What is the company's average revenue from maintenance between 2018 and 2019? Success: 247117.0
# d3dc2462-fd1b-4871-a0f6-6b4837100c05
# What is the company's average revenue from cloud between 2018 and 2019? Success: 56568.0
# ce61f92d-668f-47cd-9b72-2265209f67a2
# What was the average orders for 2019 and 2018? Success: 19213.0
# 3d8a0eb1-e9be-49e7-855c-cce8b1f2ee03
# What is the increase / (decrease) in revenue from 2018 to 2019? Success: -462.0
# 276ac70b-a4ae-4163-bf39-bdb6ed29a4be
# What is the increase / (decrease) in the Adjusted EBITDA margin from 2018 to 2019? Success: -0.2
# 5512e4f4-6808-464d-884d-95db34563593
# What was the average interest income for 2018 and 2019? Success: 1912.5
# 5de0027a-4080-4423-8987-a11e2a2fc793
# What was the average interest expense for 2018 and 2019? Success: -3269.0
# 311dc93c-93b4-49a5-ba50-5d97cc16e4fa
# What is the average investment income between 2018 and 2019?  Success: 559.0
# 9c364cfe-84e4-479d-b3ca-dab2b412e8c4
# What is the average financing costs between 2018 and 2019? Success: -1581.0
# 10e936a6-8d76-4bbe-b058-86f12091b447
# What is the difference between the average investment income and average financing costs? Success: 2140.0
# f9c8ce19-71ce-48aa-b3f3-9414d7112a4b
# What is the change in Total Fees from 2018 to 2019? Success: 472663.0
# e6655bf9-a024-476a-b3dc-4aaf6ae67ba0
# What is the percentage change in audit-related fees in 2019? Success: 43.81
# 86f8addb-85de-4f61-86d5-da4b6eca413a
# What is the percentage change of  Total Revenue from 2018 to 2019? Success: -86.26
# 8b3a0a0b-cbef-40a4-81f4-0d55a2e65b85
# What is the  Royalty Bearing Licenses for 2019 expressed as a percentage of  Total Revenue for 2019? Success: 95.72
# 6c4b20ff-34f4-4d53-aa16-de4fecd30f3e
# What was the total USD denominated monetary assets as at 31 December 2019? failure: 48784.0 good answer:  28101
# aab66af5-afb9-4f2f-b45b-68f16542760b
# What was the total non-USD denominated monetary liabilities as at 31 December 2019? failure: -34488.0 good answer:  20471
# 60b10a63-4d7d-4ef8-9400-f0d8a6ee3ffe
# What was the total USD denominated monetary assets as at 31 December 2018? Success: 20683.0
# ba16499f-3c96-4faa-81b0-874f9ace7c8c
# What was the change in the basic net income per share between 2017 and 2018? failure: 1.32 good answer:  -1.32
# 9d2aa4d9-194f-417a-9ed7-95cf4f5c95cd
# What is the change in accumulated depreciation for PPE between December 31, 2018 and 2019? failure: -209.5 good answer:  7.6
# 25fc46b8-4381-4d77-9c83-b69bcda8e189
# What is the total network equiption between 2018 to 2019? Success: 7957.9
# 14120019-ba0a-483f-9046-2f2d4118761c
# How much is the change in additions of financial assets from 2018 to 2019? Success: -12069.0
# 71162a9c-f1b1-42fa-a137-c79fa19030ae
# What is the 2019 financial assets closing balance expressed as a percentage of 2018 financial assets closing balance? Success: 146.65
# bb6966e0-61e6-44c6-87ad-69f952453829
# How much is the change between 2018 and 2019 currency translation differences of financial assets? Success: -3206.0
# 64d8c7e4-99d6-4d2e-ac39-dbee2a0dbc85
# What is the sum of finance leases from 2020 to 2024? Success: 140.0
# edfd8e56-88a7-402a-bd78-b867bf509fa8
# What is the percentage change in the amount of operating leases in 2021 from 2020? Success: -21.52
# 16f3274f-d35e-459a-9216-4d83b725f9b6
# How much is the change between 2018 to 2019 carrying amount of the interest rate swaps? Success: -2157.0
# c9b0fa1e-6fe7-403e-b0f1-9367e6485fcf
# How much is the change between 2018 and 2019 notional amount of the interest rate swaps? Success: -48207.0
# 8cb754f8-8411-4846-b6f8-8e2467ce08f3
# How many percent did the weighted average hedged rate for the year change by from 2018 to 2019?[Error]unsupported operand type(s) for *: 'int' and 'NoneType'
#  failure: [Error]unsupported operand type(s) for *: 'int' and 'NoneType' good answer:  0.5
# 12a99674-3d7b-43b8-acce-98a83bd7c70e
# What is the percentage change of revenue from Hong Kong from 2017 to 2018, based on the geographic location of the customer’s headquarters? Success: 23.23
# f1a33e83-3a96-410a-8878-5e1fd1773a6d
# What is the total percentage of revenue from Taiwan and Japan over total revenue in 2019, based on the geographic location of the customer's headquarters? Success: 15.64
# eccadabb-b970-47f6-8537-27907d2408c6
# What is the total earnings in 2019? failure: 4566156.0 good answer:  4570576.14
# 803799b7-519c-4ca2-8e72-a76fe69b2e6a
# What is the total goodwill acquired in the Network Software & Systems segment from 2018 to 2019? Success: 1336.7
# 4c5a0a4f-9e3f-434f-831b-530327547a01
# What is the proportion of balances in the Application Software and Process Technologies segments over total balances in all segments at December 31, 2018? Success: 0.59
# 890e40b2-3009-449f-b806-49d0a4fa82cd
# What is the percentage change in the total balance of goodwill of the Network Software & Systems segment in 2019 compared to 2018?[Error]division by zero
#  failure: [Error]division by zero good answer:  49.92
# ca7623cd-811b-4b33-8e3d-b78b0ec1f58e
# What is the average annual GAAP-based Professional Service and Other Gross Margin %? Success: 19.43
# b56cfe42-d808-4b3e-8f81-83acafb052f4
# What is the average annual GAAP-based Professional Service and Other Gross Profit?  failure: 36694.0 good answer:  54510.33
# feb46963-3b1f-4eaa-8325-74044812e35b
# What is the percentage increase of GAAP-based Professional Service and Other Gross Profit of fiscal year 2017 to 2019? Success: 49.4
# 6ce427fa-d1ff-481d-b6ba-7950d43e7c22
# What is the proportion of long-term debt payments due in 5 years or below?  failure: 1.0 good answer:  0.48
# Invalid  ratio
# ff90c9d7-de34-46da-a7b2-c7c2747fab0a
# What is the ratio (in percentage) of total notes payable to total capital lease obligations? Success: 0.6
# 7e8041b3-4b8c-4e47-8c83-af0b9a6fdb4c
# What was the increase / (decrease) in the FCC licenses from 2018 to 2019? Success: 15.6
# 65581c66-9e18-4e1b-979a-dcd2a873d998
# What was the average State licenses? Success: 2.5
# 82c155de-a907-4b3f-b89f-1984bd97ddc5
# What is the percentage increase / (decrease) in the total from 2018 to 2019? Success: 12.67
# 5b48fea5-61de-401b-aea9-b2b90b7a0eeb
# What is the percentage of non-vested shares granted in 2019 as a percentage of the total non-vested shares at December 31, 2019? Success: 36.9
# 8a7ef462-5a25-48c9-8a49-3fb543a73785
# What is the percentage of non-vested shares vested in 2019 as a percentage of the total non-vested shares at December 31, 2019? Success: 28.46
# 240b5a32-819a-4cbe-8420-0ab6dfe3b2eb
# What is the percentage of non-vested shares forfeited in 2019 as a percentage of the total non-vested shares at December 31, 2019? Success: 0.98
# c8ed0bf6-60c5-41e2-97e3-5ece54a1349b
# What is the change in total personnel expenses from 2018 to 2019? Success: 39224.0
# 4cdc8b2e-e3ea-4c36-bbda-7c409a84cc78
# What is the percentage change in total personnel expenses from 2018 to 2019? Success: 20.81
# ec696158-f93d-4608-903d-a6b9c4e7bfd5
# What is the increase / (decrease) in the telecommunication maintenance from 2018 to 2019? Success: -0.2
# 27911d6f-dfe5-487b-bc56-7e5cf16a32e0
# What is the average telecommunications installation? Success: 37.35
# 3b8e873e-64d5-4af0-904f-7197dc632773
# What is the average Total Marine Services segment revenue? Success: 183.4

# %%
from tatqa_metric import TaTQAEmAndF1

metrics = TaTQAEmAndF1()

for ans, pred, pred_scale, _,_, _,_,_ in res:
    metrics(ans, pred, pred_scale)
pred_em, pred_f1, scale_score, op_score = metrics.get_overall_metric(reset=False)
print( pred_em, pred_f1, scale_score)
# Out:
# 0.6626506024096386 0.6626506024096386 0.8072289156626506

# %%
import re
res2 = []
for ans, pred, pred_scale, q,code, table,value_list,err in res:
    good = utils.eval_predicted_value(pred, ans['answer'])
    regex = re.compile("\\(\\d+,?\\d+", re.VERBOSE)    
    match = regex.search(str(table))
    
    match = match != None
    if pred == None:
        pred = 0
    res2.append( {'qid': q['uid'], 'question' : q['question'], 'derivation': q['derivation'], 'pred' : pred, 'pred_scale': pred_scale,  'answer': ans['answer'],  'scale':  ans['scale'],  'abs': 'abs(' in code, 'inv' : ans['answer'] == -1*pred,  'good': good, 'parenth': match})
res2 = pd.DataFrame(res2)
print(len(res2.query('good == True'))/len(res2))
# Out:
# 0.7891566265060241

# %%
metrics._details
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': -94,
#   'scale': 'million',
#   'pred': [-94.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12.14,
#   'scale': 'percent',
#   'pred': [-12.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.1,
#   'scale': 'percent',
#   'pred': [2.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.67,
#   'scale': 'percent',
#   'pred': [6.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8.11,
#   'scale': 'percent',
#   'pred': [-8.11],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [172.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [50.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [-1.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.82,
#   'scale': 'percent',
#   'pred': [26.82],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.98,
#   'scale': 'percent',
#   'pred': [2.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.93,
#   'scale': '',
#   'pred': [2.93],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [0.87],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-361.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14.07,
#   'scale': 'percent',
#   'pred': [14.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [4044.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [2349.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [16458.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.57,
#   'scale': 'percent',
#   'pred': [1.57],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [18.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 399.33,
#   'scale': 'million',
#   'pred': [407.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.06,
#   'scale': 'percent',
#   'pred': [88.06],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.2,
#   'scale': 'million',
#   'pred': [0.2],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13237.4,
#   'scale': 'million',
#   'pred': [13237.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35796,
#   'scale': 'million',
#   'pred': [35796.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 64509,
#   'scale': 'thousand',
#   'pred': [64509.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 62740,
#   'scale': 'thousand',
#   'pred': [62740.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14212,
#   'scale': 'thousand',
#   'pred': [-14212.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -67.6,
#   'scale': 'percent',
#   'pred': [-67.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0,
#   'scale': 'percent',
#   'pred': 0.0,
#   'pred_scale': 'percent',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': 'percent',
#   'pred': [3.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -9.9,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -13.66,
#   'scale': 'percent',
#   'pred': [-13.66],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.7,
#   'scale': 'million',
#   'pred': [-21.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.45,
#   'scale': 'million',
#   'pred': [995.7],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61.6,
#   'scale': 'million',
#   'pred': [61.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 984,
#   'scale': 'million',
#   'pred': [984.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1040,
#   'scale': 'million',
#   'pred': [1040.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56,
#   'scale': 'million',
#   'pred': [56.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12122,
#   'scale': 'thousand',
#   'pred': [12122000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.9500000000000001,
#   'scale': '',
#   'pred': [6.47],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -56.5,
#   'scale': 'million',
#   'pred': [56.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.38,
#   'scale': 'percent',
#   'pred': [-6.38],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19411,
#   'scale': 'thousand',
#   'pred': [-19411.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168,
#   'scale': 'thousand',
#   'pred': [-168.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -162.15,
#   'scale': 'percent',
#   'pred': [-162.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.35,
#   'scale': 'percent',
#   'pred': [4.35],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.55,
#   'scale': 'percent',
#   'pred': [4.55],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 27.9,
#   'scale': 'percent',
#   'pred': [27.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 59.4,
#   'scale': 'million',
#   'pred': [59.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.19,
#   'scale': 'percent',
#   'pred': [25.19],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.85,
#   'scale': 'percent',
#   'pred': [15.85],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.47,
#   'scale': 'percent',
#   'pred': [39.47],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8736,
#   'scale': 'million',
#   'pred': [-8736.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 198.5,
#   'scale': 'million',
#   'pred': [198.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -28.05,
#   'scale': 'percent',
#   'pred': [-28.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.3,
#   'scale': '',
#   'pred': [1.3],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 981341.34,
#   'scale': '',
#   'pred': [2070862713946.92],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.11,
#   'scale': '',
#   'pred': [0.25],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11808314,
#   'scale': '',
#   'pred': [11808314.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17,
#   'scale': 'million',
#   'pred': [17.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 21,
#   'scale': 'million',
#   'pred': [21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.22,
#   'scale': 'percent',
#   'pred': [11.22],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.36,
#   'scale': 'percent',
#   'pred': [16.36],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22.26,
#   'scale': 'percent',
#   'pred': [-22.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1226114,
#   'scale': '',
#   'pred': [-1226114.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12085176,
#   'scale': '',
#   'pred': [12085176.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 58.71,
#   'scale': 'percent',
#   'pred': [58.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 835623,
#   'scale': 'thousand',
#   'pred': [835623.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 256648,
#   'scale': 'thousand',
#   'pred': [256648.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2849050,
#   'scale': 'thousand',
#   'pred': [2849050.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22772,
#   'scale': 'thousand',
#   'pred': [-22772.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.02,
#   'scale': 'percent',
#   'pred': [6.01],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.62,
#   'scale': 'percent',
#   'pred': [0.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 8.64,
#   'scale': 'percent',
#   'pred': [8.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2968,
#   'scale': 'thousand',
#   'pred': [2968.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2988,
#   'scale': 'thousand',
#   'pred': [5309.6],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100,
#   'scale': 'thousand',
#   'pred': [100.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -451500,
#   'scale': '',
#   'pred': [-451500.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35071,
#   'scale': '',
#   'pred': [35071.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -416429,
#   'scale': '',
#   'pred': [-416429.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 92.27,
#   'scale': 'percent',
#   'pred': [92.27],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.23,
#   'scale': 'percent',
#   'pred': [16.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19.09,
#   'scale': 'percent',
#   'pred': [-19.09],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.7,
#   'scale': 'percent',
#   'pred': [-6.7],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.94,
#   'scale': 'percent',
#   'pred': [18.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.99,
#   'scale': 'percent',
#   'pred': [15.99],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 17.34,
#   'scale': 'percent',
#   'pred': [17.34],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 244800.5,
#   'scale': 'thousand',
#   'pred': [244800.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 310566.5,
#   'scale': 'thousand',
#   'pred': [310611.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 91,
#   'scale': 'million',
#   'pred': [91.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 424,
#   'scale': 'million',
#   'pred': [424.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 38.98,
#   'scale': 'percent',
#   'pred': [38.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.68,
#   'scale': 'percent',
#   'pred': [73.68],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.42,
#   'scale': 'percent',
#   'pred': [5.42],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -35,
#   'scale': 'million',
#   'pred': [-35.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -7,
#   'scale': 'million',
#   'pred': [-7.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1641.5,
#   'scale': 'million',
#   'pred': [1641.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11,
#   'scale': 'million',
#   'pred': [11.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.84,
#   'scale': 'percent',
#   'pred': [-29.84],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28747,
#   'scale': '',
#   'pred': [28747.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14373.5,
#   'scale': '',
#   'pred': [14373.5],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3.62,
#   'scale': 'percent',
#   'pred': [-3.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.52,
#   'scale': 'percent',
#   'pred': [6.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 830.6,
#   'scale': 'million',
#   'pred': [830.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4071,
#   'scale': 'million',
#   'pred': [4071.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2035.5,
#   'scale': 'million',
#   'pred': [2035.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': 'million',
#   'pred': [0.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.17,
#   'scale': 'percent',
#   'pred': [29.17],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.39,
#   'scale': 'percent',
#   'pred': [25.39],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.61,
#   'scale': 'percent',
#   'pred': [34.61],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 103.67,
#   'scale': 'percent',
#   'pred': [103.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.84,
#   'scale': 'percent',
#   'pred': [2.84],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.15,
#   'scale': 'percent',
#   'pred': [43.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82884,
#   'scale': 'million',
#   'pred': [86603.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 115,
#   'scale': 'million',
#   'pred': [115.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.13,
#   'scale': 'percent',
#   'pred': [16.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12312,
#   'scale': 'million',
#   'pred': [12312.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1105,
#   'scale': 'million',
#   'pred': [1105.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.6000000000000001,
#   'scale': 'percent',
#   'pred': [-0.6],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -43,
#   'scale': 'million',
#   'pred': [-43.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 615,
#   'scale': 'million',
#   'pred': [-568.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9,
#   'scale': 'million',
#   'pred': [9.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112.5,
#   'scale': 'percent',
#   'pred': [259.8],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -63.6,
#   'scale': 'million',
#   'pred': [-63.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.7,
#   'scale': 'million',
#   'pred': [9.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13.2,
#   'scale': 'percent',
#   'pred': [13.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 933,
#   'scale': 'thousand',
#   'pred': [933.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11137.5,
#   'scale': 'thousand',
#   'pred': [11137.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6900,
#   'scale': 'thousand',
#   'pred': [6900.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.1,
#   'scale': 'million',
#   'pred': [0.1],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.03,
#   'scale': 'percent',
#   'pred': [3.03],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 535,
#   'scale': 'thousand',
#   'pred': [535.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 881,
#   'scale': 'thousand',
#   'pred': [881.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -79.67,
#   'scale': 'percent',
#   'pred': [-79.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21,
#   'scale': 'million',
#   'pred': [-21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -531925,
#   'scale': 'thousand',
#   'pred': [-531925.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 653718,
#   'scale': 'thousand',
#   'pred': [653718.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.14,
#   'scale': 'percent',
#   'pred': [4.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 716,
#   'scale': 'thousand',
#   'pred': [716.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112,
#   'scale': 'thousand',
#   'pred': [-112.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 141,
#   'scale': 'thousand',
#   'pred': [141.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.41,
#   'scale': '',
#   'pred': [2.41],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.83,
#   'scale': '',
#   'pred': [3.83],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49872,
#   'scale': 'thousand',
#   'pred': [49872.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7017.5,
#   'scale': 'thousand',
#   'pred': [7017.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16811.5,
#   'scale': 'thousand',
#   'pred': [16811.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 113000,
#   'scale': '',
#   'pred': [113000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -60.71,
#   'scale': 'percent',
#   'pred': [-60.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 83.33,
#   'scale': 'percent',
#   'pred': [83.33],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.4,
#   'scale': 'million',
#   'pred': [67.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6850,
#   'scale': 'thousand',
#   'pred': [6850.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.6,
#   'scale': '',
#   'pred': [34.6],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 111.4,
#   'scale': '',
#   'pred': [111.4],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 107.15,
#   'scale': '',
#   'pred': [107.15],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82.05,
#   'scale': 'percent',
#   'pred': [82.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6841,
#   'scale': '',
#   'pred': [-6841.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 30011,
#   'scale': '',
#   'pred': [63888.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -27603,
#   'scale': '',
#   'pred': [-27603.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 77395,
#   'scale': 'million',
#   'pred': [77395.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1859,
#   'scale': 'million',
#   'pred': [-1859.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.9,
#   'scale': 'percent',
#   'pred': [4.66],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.01,
#   'scale': '',
#   'pred': [91.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [75.44],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.78,
#   'scale': '',
#   'pred': [0.78],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.27,
#   'scale': '',
#   'pred': [0.27],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.03,
#   'scale': '',
#   'pred': [-0.03],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -4.59,
#   'scale': 'percent',
#   'pred': [-4.59],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.48,
#   'scale': 'percent',
#   'pred': [5.48],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 445.7,
#   'scale': 'million',
#   'pred': [445.69999999999993],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.34,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2904,
#   'scale': 'thousand',
#   'pred': [2904.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 67669,
#   'scale': 'thousand',
#   'pred': [67669.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.05,
#   'scale': 'percent',
#   'pred': [1.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2.87,
#   'scale': 'percent',
#   'pred': [-2.87],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 24.07,
#   'scale': 'percent',
#   'pred': [24.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.77,
#   'scale': '',
#   'pred': [4.77],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.1,
#   'scale': 'percent',
#   'pred': [6.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': '',
#   'pred': [3.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 167424,
#   'scale': 'thousand',
#   'pred': [167424.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1622,
#   'scale': 'thousand',
#   'pred': [1622.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1454.5,
#   'scale': 'thousand',
#   'pred': [1454.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 160.5,
#   'scale': 'thousand',
#   'pred': [160.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -138187,
#   'scale': 'thousand',
#   'pred': [-138187.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168630,
#   'scale': 'thousand',
#   'pred': [153988.17],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17.45,
#   'scale': 'percent',
#   'pred': [-17.45],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 169.4,
#   'scale': '',
#   'pred': [1303.1],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 55.44,
#   'scale': 'percent',
#   'pred': [8.65],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.6,
#   'scale': '',
#   'pred': [9.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 42271,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10029.67,
#   'scale': 'thousand',
#   'pred': [-10029.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -74.31,
#   'scale': 'percent',
#   'pred': [-74.31],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.53,
#   'scale': '',
#   'pred': [20.53],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.94,
#   'scale': 'percent',
#   'pred': [3.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.64,
#   'scale': '',
#   'pred': [-5.03],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19582777,
#   'scale': '',
#   'pred': [19582777.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5631086,
#   'scale': '',
#   'pred': [5631086.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [-1.9],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18384.5,
#   'scale': 'million',
#   'pred': [18384.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.15,
#   'scale': 'percent',
#   'pred': [16.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 303118,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 153391,
#   'scale': 'thousand',
#   'pred': [-153391.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 149727,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2053.5,
#   'scale': 'million',
#   'pred': [2053.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 57,
#   'scale': 'million',
#   'pred': [57.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9189,
#   'scale': '',
#   'pred': [9307.75],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 144,
#   'scale': '',
#   'pred': [144.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.33,
#   'scale': '',
#   'pred': [39.33],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -5.8100000000000005,
#   'scale': 'percent',
#   'pred': [-3015.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100777,
#   'scale': 'thousand',
#   'pred': [201554.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
# ...
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3695,
#   'scale': 'thousand',
#   'pred': [3695.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.36,
#   'scale': 'percent',
#   'pred': [5.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16,
#   'scale': '',
#   'pred': [16.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37556,
#   'scale': 'thousand',
#   'pred': [32192.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18778,
#   'scale': 'thousand',
#   'pred': [3095.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 714,
#   'scale': 'thousand',
#   'pred': [714.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5579.33,
#   'scale': 'million',
#   'pred': [-3350.26],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3609.67,
#   'scale': 'million',
#   'pred': [2168.54],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.3,
#   'scale': 'percent',
#   'pred': [39.3],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.13,
#   'scale': 'percent',
#   'pred': [0.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.18,
#   'scale': 'percent',
#   'pred': [1.18],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.65,
#   'scale': '',
#   'pred': [2.65],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.83,
#   'scale': 'percent',
#   'pred': [26.83],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.53,
#   'scale': 'percent',
#   'pred': [4.52],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1033.5,
#   'scale': 'million',
#   'pred': [717.63],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -228,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 393,
#   'scale': 'million',
#   'pred': 0.0,
#   'pred_scale': 'million',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.12,
#   'scale': 'percent',
#   'pred': [9.12],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.72,
#   'scale': 'percent',
#   'pred': [0.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.4,
#   'scale': 'percent',
#   'pred': [4.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.01,
#   'scale': 'percent',
#   'pred': [-63.99],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 279371,
#   'scale': 'thousand',
#   'pred': [279371.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 247117,
#   'scale': 'thousand',
#   'pred': [247117.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56568,
#   'scale': 'thousand',
#   'pred': [56568.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19213,
#   'scale': 'million',
#   'pred': [19213.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -462,
#   'scale': 'million',
#   'pred': [-462.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'percent',
#   'pred': [-0.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1912.5,
#   'scale': 'thousand',
#   'pred': [1912.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3269,
#   'scale': 'thousand',
#   'pred': [-3269.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 559,
#   'scale': 'million',
#   'pred': [559.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1581,
#   'scale': 'million',
#   'pred': [-1581.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2140,
#   'scale': 'million',
#   'pred': [2140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 472663,
#   'scale': '',
#   'pred': [472663.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.81,
#   'scale': 'percent',
#   'pred': [43.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -86.26,
#   'scale': 'percent',
#   'pred': [-86.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 95.72,
#   'scale': 'percent',
#   'pred': [95.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28101,
#   'scale': 'million',
#   'pred': [48784.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20471,
#   'scale': 'million',
#   'pred': [-34488.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20683,
#   'scale': 'million',
#   'pred': [20683.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1.32,
#   'scale': '',
#   'pred': [1.32],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7.6,
#   'scale': 'percent',
#   'pred': [-209.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7957.9,
#   'scale': 'million',
#   'pred': [7957.9],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12069,
#   'scale': 'million',
#   'pred': [-12069.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 146.65,
#   'scale': 'percent',
#   'pred': [146.65],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3206,
#   'scale': 'million',
#   'pred': [-3206.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 140,
#   'scale': 'million',
#   'pred': [140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.52,
#   'scale': 'percent',
#   'pred': [-21.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2157,
#   'scale': 'million',
#   'pred': [-2157.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -48207,
#   'scale': 'million',
#   'pred': [-48207.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.5,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 23.23,
#   'scale': 'percent',
#   'pred': [23.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.64,
#   'scale': 'percent',
#   'pred': [15.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4570576.14,
#   'scale': '',
#   'pred': [4566156.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1336.7,
#   'scale': '',
#   'pred': [1336.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.59,
#   'scale': '',
#   'pred': [0.59],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.92,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19.43,
#   'scale': 'percent',
#   'pred': [19.43],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 54510.33,
#   'scale': 'thousand',
#   'pred': [36694.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.4,
#   'scale': 'percent',
#   'pred': [49.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.48,
#   'scale': '',
#   'pred': [1.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': [0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.6,
#   'scale': 'million',
#   'pred': [15.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.5,
#   'scale': 'million',
#   'pred': [2.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.67,
#   'scale': 'percent',
#   'pred': [12.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.9,
#   'scale': 'percent',
#   'pred': [36.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28.46,
#   'scale': 'percent',
#   'pred': [28.46],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.98,
#   'scale': 'percent',
#   'pred': [0.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39224,
#   'scale': '',
#   'pred': [39224.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.81,
#   'scale': 'percent',
#   'pred': [20.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'million',
#   'pred': [-0.2],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37.35,
#   'scale': 'million',
#   'pred': [37.35],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 183.4,
#   'scale': 'million',
#   'pred': [183.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]

# %%
metrics._details[0]['pred'][0] == -94
# Out:
# True

# %%
scale_err =  [item for item in metrics._details if item['em'] != 1.0 and item['pred_scale'] != item['scale']]
only_scale_err =  [item for item in metrics._details if item['em'] != 1.0 and isinstance(item['pred'], list)  and  item['pred'][0] == item['answer']]
err =  [item for item in metrics._details if item['em'] != 1.0]
len (metrics._details), len(err), len(scale_err), len(only_scale_err)
# Out:
# (166, 56, 31, 20)

# %%
res = {}
for item in metrics._details:
  

    pred = item['pred']
    pred_scale = item['pred_scale']

    key = pred_scale +'|' + item['scale']
    if key not in res:
        res [key] = 1
    res[key]=res[key] +1


    if  item['em'] == 1.0:
        None
        #print("\033[92m Success: " + str(pred)+'\033[0m')
    else:           
 
        
        if isinstance(item['pred'], list) and  pred[0] == item['answer']:
           
            print("\033[93m", '|', " failure: ", '| ',str(pred[0]),  '| ', str(pred_scale), '| ', 'good answer: ', '| ', item['answer'], '| ', item['scale'], '\033[0m' )
        else:    
            None
            #print("\033[91m failure: " + str(pred),  str(pred_scale), 'good answer: ',item['answer'],item['scale'], '\033[0m' )
# Out:
#  |  failure:  |  62740.0 |   |  good answer:  |  62740 |  thousand
#  |  failure:  |  -19411.0 |   |  good answer:  |  -19411 |  thousand
#  |  failure:  |  12085176.0 |  thousand |  good answer:  |  12085176 |
#  |  failure:  |  28747.0 |  thousand |  good answer:  |  28747 |
#  |  failure:  |  113000.0 |  thousand |  good answer:  |  113000 |
#  |  failure:  |  111.4 |  million |  good answer:  |  111.4 |
#  |  failure:  |  107.15 |  million |  good answer:  |  107.15 |
#  |  failure:  |  -27603.0 |  thousand |  good answer:  |  -27603 |
#  |  failure:  |  3.0 |  million |  good answer:  |  3 |
#  |  failure:  |  -10029.67 |   |  good answer:  |  -10029.67 |  thousand
#  |  failure:  |  39.33 |  million |  good answer:  |  39.33 |
#  |  failure:  |  0.08 |  thousand |  good answer:  |  0.08 |  percent
#  |  failure:  |  16767.0 |   |  good answer:  |  16767 |  thousand
#  |  failure:  |  0.1 |   |  good answer:  |  0.1 |  million
#  |  failure:  |  54633874 |  thousand |  good answer:  |  54633874 |
#  |  failure:  |  0.18 |  thousand |  good answer:  |  0.18 |
#  |  failure:  |  0.97 |  thousand |  good answer:  |  0.97 |
#  |  failure:  |  3695.0 |  million |  good answer:  |  3695 |  thousand
#  |  failure:  |  39.3 |  million |  good answer:  |  39.3 |  percent
#  |  failure:  |  2.65 |  thousand |  good answer:  |  2.65 |
#  |  failure:  |  -0.2 |  million |  good answer:  |  -0.2 |  percent
#  |  failure:  |  1336.7 |  thousand |  good answer:  |  1336.7 |

# %%
res
# Out:
# {'million|million': 121,
#  'percent|percent': 177,
#  '|': 65,
#  'thousand|thousand': 82,
#  '|thousand': 11,
#  '|percent': 14,
#  'percent|': 3,
#  '|million': 5,
#  'thousand|': 11,
#  'million|percent': 5,
#  'million|': 9,
#  'thousand|percent': 2,
#  'billion|billion': 4,
#  'million|thousand': 2}

# %%
res
# Out:
# {'|thousand': 5,
#  'thousand|': 10,
#  'million|': 4,
#  'thousand|percent': 2,
#  '|million': 7,
#  'million|thousand': 2,
#  'million|percent': 3}

# %%
metrics._details
# Out:
# [{'answer_type': 'arithmetic',
#   'answer': -94,
#   'scale': 'million',
#   'pred': [-94.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12.14,
#   'scale': 'percent',
#   'pred': [-12.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.1,
#   'scale': 'percent',
#   'pred': [2.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.67,
#   'scale': 'percent',
#   'pred': [6.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8.11,
#   'scale': 'percent',
#   'pred': [-8.11],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 172,
#   'scale': 'million',
#   'pred': [172.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 50.5,
#   'scale': 'million',
#   'pred': [50.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 121.5,
#   'scale': 'million',
#   'pred': [121.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.82,
#   'scale': 'percent',
#   'pred': [26.82],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.98,
#   'scale': 'percent',
#   'pred': [2.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.93,
#   'scale': '',
#   'pred': [2.93],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [0.87],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -361,
#   'scale': '',
#   'pred': [-361.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14.07,
#   'scale': 'percent',
#   'pred': [14.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4227.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3680,
#   'scale': 'million',
#   'pred': [3680.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 547.5,
#   'scale': 'million',
#   'pred': [4227.5],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3728,
#   'scale': 'thousand',
#   'pred': [3728.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -16458,
#   'scale': 'thousand',
#   'pred': [-16458.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.57,
#   'scale': 'percent',
#   'pred': [1.57],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [1.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18,
#   'scale': 'million',
#   'pred': [18.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 399.33,
#   'scale': 'million',
#   'pred': [407.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.06,
#   'scale': 'percent',
#   'pred': [88.06],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.2,
#   'scale': 'million',
#   'pred': [0.2],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13237.4,
#   'scale': 'million',
#   'pred': [13237.4],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35796,
#   'scale': 'million',
#   'pred': [35796.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 64509,
#   'scale': 'thousand',
#   'pred': [64509.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 62740,
#   'scale': 'thousand',
#   'pred': [62740.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14212,
#   'scale': 'thousand',
#   'pred': [-14212.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -67.6,
#   'scale': 'percent',
#   'pred': [-67.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0,
#   'scale': 'percent',
#   'pred': 0.0,
#   'pred_scale': 'percent',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': 'percent',
#   'pred': [3.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -9.9,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -13.66,
#   'scale': 'percent',
#   'pred': [-13.66],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.7,
#   'scale': 'million',
#   'pred': [-21.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 88.45,
#   'scale': 'million',
#   'pred': [88.45],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61.6,
#   'scale': 'million',
#   'pred': [61.6],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 984,
#   'scale': 'million',
#   'pred': [984.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1040,
#   'scale': 'million',
#   'pred': [1040.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56,
#   'scale': 'million',
#   'pred': [56.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12122,
#   'scale': 'thousand',
#   'pred': [12136.91],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.9500000000000001,
#   'scale': '',
#   'pred': [0.95],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -56.5,
#   'scale': 'million',
#   'pred': [-56.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.38,
#   'scale': 'percent',
#   'pred': [-6.38],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19411,
#   'scale': 'thousand',
#   'pred': [-19411.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168,
#   'scale': 'thousand',
#   'pred': [-168.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -162.15,
#   'scale': 'percent',
#   'pred': [-162.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.35,
#   'scale': 'percent',
#   'pred': [4.35],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.55,
#   'scale': 'percent',
#   'pred': [4.55],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 27.9,
#   'scale': 'percent',
#   'pred': [27.9],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 59.4,
#   'scale': 'million',
#   'pred': [59.4],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.19,
#   'scale': 'percent',
#   'pred': [25.19],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.85,
#   'scale': 'percent',
#   'pred': [15.85],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.47,
#   'scale': 'percent',
#   'pred': [39.47],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -8736,
#   'scale': 'million',
#   'pred': [-8736.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 198.5,
#   'scale': 'million',
#   'pred': [198.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -28.05,
#   'scale': 'percent',
#   'pred': [-28.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.3,
#   'scale': '',
#   'pred': [1.3],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 981341.34,
#   'scale': '',
#   'pred': [2070862713946.92],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.11,
#   'scale': '',
#   'pred': [0.25],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11808314,
#   'scale': '',
#   'pred': [11808314.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17,
#   'scale': 'million',
#   'pred': [-17.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2,
#   'scale': 'million',
#   'pred': [2.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 21,
#   'scale': 'million',
#   'pred': [21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.22,
#   'scale': 'percent',
#   'pred': [11.22],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.36,
#   'scale': 'percent',
#   'pred': [16.36],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22.26,
#   'scale': 'percent',
#   'pred': [-22.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1226114,
#   'scale': '',
#   'pred': [-1226114.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12085176,
#   'scale': '',
#   'pred': [12085176.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 58.71,
#   'scale': 'percent',
#   'pred': [58.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 835623,
#   'scale': 'thousand',
#   'pred': [835623.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 256648,
#   'scale': 'thousand',
#   'pred': [256648.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2849050,
#   'scale': 'thousand',
#   'pred': [2849050.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -22772,
#   'scale': 'thousand',
#   'pred': [-22772.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.02,
#   'scale': 'percent',
#   'pred': [6.01],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.62,
#   'scale': 'percent',
#   'pred': [0.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 8.64,
#   'scale': 'percent',
#   'pred': [8.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2968,
#   'scale': 'thousand',
#   'pred': [2968.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2988,
#   'scale': 'thousand',
#   'pred': [4859.25],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100,
#   'scale': 'thousand',
#   'pred': [100.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -451500,
#   'scale': '',
#   'pred': [-451500.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 35071,
#   'scale': '',
#   'pred': [35071.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -416429,
#   'scale': '',
#   'pred': [-416429.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 92.27,
#   'scale': 'percent',
#   'pred': [92.27],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.23,
#   'scale': 'percent',
#   'pred': [16.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -19.09,
#   'scale': 'percent',
#   'pred': [-19.09],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6.7,
#   'scale': 'percent',
#   'pred': [-6.7],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.94,
#   'scale': 'percent',
#   'pred': [18.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.99,
#   'scale': 'percent',
#   'pred': [15.99],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 17.34,
#   'scale': 'percent',
#   'pred': [17.34],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 244800.5,
#   'scale': 'thousand',
#   'pred': [36.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 310566.5,
#   'scale': 'thousand',
#   'pred': [310611.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 91,
#   'scale': 'million',
#   'pred': [91.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 424,
#   'scale': 'million',
#   'pred': [424.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 38.98,
#   'scale': 'percent',
#   'pred': [38.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.68,
#   'scale': 'percent',
#   'pred': [73.68],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.42,
#   'scale': 'percent',
#   'pred': [5.42],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -35,
#   'scale': 'million',
#   'pred': [-35.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -7,
#   'scale': 'million',
#   'pred': [-7.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1641.5,
#   'scale': 'million',
#   'pred': [1641.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11,
#   'scale': 'million',
#   'pred': [11.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.84,
#   'scale': 'percent',
#   'pred': [-29.84],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28747,
#   'scale': '',
#   'pred': [28747.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 14373.5,
#   'scale': '',
#   'pred': [14373.5],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3.62,
#   'scale': 'percent',
#   'pred': [-3.62],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.52,
#   'scale': 'percent',
#   'pred': [6.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 830.6,
#   'scale': 'million',
#   'pred': [830.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4071,
#   'scale': 'million',
#   'pred': [4071.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2035.5,
#   'scale': 'million',
#   'pred': [2035.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.7000000000000001,
#   'scale': 'million',
#   'pred': [0.7],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 29.17,
#   'scale': 'percent',
#   'pred': [29.17],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 25.39,
#   'scale': 'percent',
#   'pred': [25.39],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.61,
#   'scale': 'percent',
#   'pred': [34.61],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 103.67,
#   'scale': 'percent',
#   'pred': [103.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.84,
#   'scale': 'percent',
#   'pred': [2.84],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.15,
#   'scale': 'percent',
#   'pred': [43.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82884,
#   'scale': 'million',
#   'pred': [86603.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 115,
#   'scale': 'million',
#   'pred': [115.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.13,
#   'scale': 'percent',
#   'pred': [16.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12312,
#   'scale': 'million',
#   'pred': [12312.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1105,
#   'scale': 'million',
#   'pred': [1105.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.6000000000000001,
#   'scale': 'percent',
#   'pred': [-0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -43,
#   'scale': 'million',
#   'pred': [-43.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 615,
#   'scale': 'million',
#   'pred': [-615.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9,
#   'scale': 'million',
#   'pred': [9.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112.5,
#   'scale': 'percent',
#   'pred': [112.5],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -63.6,
#   'scale': 'million',
#   'pred': [-63.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.5,
#   'scale': 'million',
#   'pred': [-0.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.7,
#   'scale': 'million',
#   'pred': [9.7],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 13.2,
#   'scale': 'percent',
#   'pred': [13.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 933,
#   'scale': 'thousand',
#   'pred': [933.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11137.5,
#   'scale': 'thousand',
#   'pred': [11137.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6900,
#   'scale': 'thousand',
#   'pred': [6900.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.1,
#   'scale': 'million',
#   'pred': [0.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.03,
#   'scale': 'percent',
#   'pred': [3.03],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 535,
#   'scale': 'thousand',
#   'pred': [535.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 881,
#   'scale': 'thousand',
#   'pred': [881.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -79.67,
#   'scale': 'percent',
#   'pred': [-79.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21,
#   'scale': 'million',
#   'pred': [-21.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -531925,
#   'scale': 'thousand',
#   'pred': [-531925.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 653718,
#   'scale': 'thousand',
#   'pred': [653718.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.14,
#   'scale': 'percent',
#   'pred': [4.14],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 716,
#   'scale': 'thousand',
#   'pred': [716.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 112,
#   'scale': 'thousand',
#   'pred': [-112.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 141,
#   'scale': 'thousand',
#   'pred': [141.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.41,
#   'scale': '',
#   'pred': [2.41],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.83,
#   'scale': '',
#   'pred': [3.83],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49872,
#   'scale': 'thousand',
#   'pred': [49872.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7017.5,
#   'scale': 'thousand',
#   'pred': [7017.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16811.5,
#   'scale': 'thousand',
#   'pred': [16811.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 113000,
#   'scale': '',
#   'pred': [113000.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -60.71,
#   'scale': 'percent',
#   'pred': [-60.71],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 83.33,
#   'scale': 'percent',
#   'pred': [83.33],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.4,
#   'scale': 'million',
#   'pred': [67.2],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6850,
#   'scale': 'thousand',
#   'pred': [6850.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 34.6,
#   'scale': '',
#   'pred': [34.6],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 111.4,
#   'scale': '',
#   'pred': [111.4],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 107.15,
#   'scale': '',
#   'pred': [107.15],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 40,
#   'scale': 'percent',
#   'pred': [40.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 82.05,
#   'scale': 'percent',
#   'pred': [82.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -6841,
#   'scale': '',
#   'pred': [-16105.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 30011,
#   'scale': '',
#   'pred': [42592.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -27603,
#   'scale': '',
#   'pred': [-27603.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 77395,
#   'scale': 'million',
#   'pred': [77395.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1859,
#   'scale': 'million',
#   'pred': [-1859.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.9,
#   'scale': 'percent',
#   'pred': [4.66],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.01,
#   'scale': '',
#   'pred': [91.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.87,
#   'scale': '',
#   'pred': [75.44],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.78,
#   'scale': '',
#   'pred': [0.78],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.27,
#   'scale': '',
#   'pred': [0.27],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.03,
#   'scale': '',
#   'pred': [-0.03],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -4.59,
#   'scale': 'percent',
#   'pred': [-4.59],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5.48,
#   'scale': 'percent',
#   'pred': [5.48],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 445.7,
#   'scale': 'million',
#   'pred': [445.7],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18.34,
#   'scale': 'percent',
#   'pred': [0.18],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2904,
#   'scale': 'thousand',
#   'pred': [2904.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 67669,
#   'scale': 'thousand',
#   'pred': [67669.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.05,
#   'scale': 'percent',
#   'pred': [1.05],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2.87,
#   'scale': 'percent',
#   'pred': [-2.87],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 24.07,
#   'scale': 'percent',
#   'pred': [24.07],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.77,
#   'scale': '',
#   'pred': [4.77],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 6.1,
#   'scale': 'percent',
#   'pred': [6.1],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3,
#   'scale': '',
#   'pred': [3.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 90494,
#   'scale': 'thousand',
#   'pred': [90494.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 167424,
#   'scale': 'thousand',
#   'pred': [167424.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1622,
#   'scale': 'thousand',
#   'pred': [1622.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1454.5,
#   'scale': 'thousand',
#   'pred': [1454.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 160.5,
#   'scale': 'thousand',
#   'pred': [160.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -138187,
#   'scale': 'thousand',
#   'pred': [-138187.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -168630,
#   'scale': 'thousand',
#   'pred': [153988.17],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -17.45,
#   'scale': 'percent',
#   'pred': [-17.45],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 169.4,
#   'scale': '',
#   'pred': [700.45],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 55.44,
#   'scale': 'percent',
#   'pred': [113.65],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 73.6,
#   'scale': '',
#   'pred': [-9.1],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 42271,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10029.67,
#   'scale': 'thousand',
#   'pred': [-10029.67],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -74.31,
#   'scale': 'percent',
#   'pred': [-74.31],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.53,
#   'scale': '',
#   'pred': [20.53],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3.94,
#   'scale': 'percent',
#   'pred': [3.94],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.64,
#   'scale': '',
#   'pred': [-5.03],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19582777,
#   'scale': '',
#   'pred': [19582777.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5631086,
#   'scale': '',
#   'pred': [5631086.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.9,
#   'scale': 'percent',
#   'pred': [-1.9],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18384.5,
#   'scale': 'million',
#   'pred': [18384.5],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16.15,
#   'scale': 'percent',
#   'pred': [16.15],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 303118,
#   'scale': 'thousand',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 153391,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 149727,
#   'scale': 'thousand',
#   'pred': [149727.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2053.5,
#   'scale': 'million',
#   'pred': [2053.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 57,
#   'scale': 'million',
#   'pred': [57.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9189,
#   'scale': '',
#   'pred': [9548.5],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 144,
#   'scale': '',
#   'pred': [144.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.33,
#   'scale': '',
#   'pred': [39.33],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -5.8100000000000005,
#   'scale': 'percent',
#   'pred': [-3015.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 100777,
#   'scale': 'thousand',
#   'pred': [100777.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 61,
#   'scale': 'percent',
#   'pred': [61.0],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 622908,
#   'scale': 'thousand',
#   'pred': [623111.0],
# ...
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 202845,
#   'scale': '',
#   'pred': [202845.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3695,
#   'scale': 'thousand',
#   'pred': [11085.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 11.36,
#   'scale': 'percent',
#   'pred': [5.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 16,
#   'scale': '',
#   'pred': [16.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37556,
#   'scale': 'thousand',
#   'pred': [32192.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 18778,
#   'scale': 'thousand',
#   'pred': [3095.0],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 714,
#   'scale': 'thousand',
#   'pred': [714.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -10.5,
#   'scale': 'million',
#   'pred': [-10.5],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 5579.33,
#   'scale': 'million',
#   'pred': [-3350.26],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 3609.67,
#   'scale': 'million',
#   'pred': [2168.54],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39.3,
#   'scale': 'percent',
#   'pred': [39.3],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.13,
#   'scale': 'percent',
#   'pred': [0.13],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1.18,
#   'scale': 'percent',
#   'pred': [1.18],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.65,
#   'scale': '',
#   'pred': [2.65],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 26.83,
#   'scale': 'percent',
#   'pred': [26.83],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.53,
#   'scale': 'percent',
#   'pred': [42.23],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1033.5,
#   'scale': 'million',
#   'pred': [717.63],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -228,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 393,
#   'scale': 'million',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 9.12,
#   'scale': 'percent',
#   'pred': [9.12],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.72,
#   'scale': 'percent',
#   'pred': [0.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4.4,
#   'scale': 'percent',
#   'pred': [4.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.01,
#   'scale': 'percent',
#   'pred': [36.01],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 279371,
#   'scale': 'thousand',
#   'pred': [279371.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 247117,
#   'scale': 'thousand',
#   'pred': [247117.0],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 56568,
#   'scale': 'thousand',
#   'pred': [56568.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19213,
#   'scale': 'million',
#   'pred': [19213.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -462,
#   'scale': 'million',
#   'pred': [-462.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'percent',
#   'pred': [-0.2],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1912.5,
#   'scale': 'thousand',
#   'pred': [1912.5],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3269,
#   'scale': 'thousand',
#   'pred': [-3269.0],
#   'pred_scale': 'thousand',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 559,
#   'scale': 'million',
#   'pred': [559.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1581,
#   'scale': 'million',
#   'pred': [-1022.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2140,
#   'scale': 'million',
#   'pred': [2140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 472663,
#   'scale': '',
#   'pred': [472663.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 43.81,
#   'scale': 'percent',
#   'pred': [43.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -86.26,
#   'scale': 'percent',
#   'pred': [-86.26],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 95.72,
#   'scale': 'percent',
#   'pred': [95.72],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28101,
#   'scale': 'million',
#   'pred': [28101.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20471,
#   'scale': 'million',
#   'pred': [-34488.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20683,
#   'scale': 'million',
#   'pred': [20683.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -1.32,
#   'scale': '',
#   'pred': [-1.32],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7.6,
#   'scale': 'percent',
#   'pred': [-209.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 7957.9,
#   'scale': 'million',
#   'pred': [7957.9],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -12069,
#   'scale': 'million',
#   'pred': [-12069.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 146.65,
#   'scale': 'percent',
#   'pred': [146.65],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -3206,
#   'scale': 'million',
#   'pred': [-3206.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 140,
#   'scale': 'million',
#   'pred': [140.0],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -21.52,
#   'scale': 'percent',
#   'pred': [-21.52],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -2157,
#   'scale': 'million',
#   'pred': [-2157.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -48207,
#   'scale': 'million',
#   'pred': [-48207.0],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.5,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 23.23,
#   'scale': 'percent',
#   'pred': [23.23],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.64,
#   'scale': 'percent',
#   'pred': [15.64],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 4570576.14,
#   'scale': '',
#   'pred': [4566156.0],
#   'pred_scale': 'million',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 1336.7,
#   'scale': '',
#   'pred': [1336.7],
#   'pred_scale': 'thousand',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.59,
#   'scale': '',
#   'pred': [0.59],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.92,
#   'scale': 'percent',
#   'pred': '',
#   'pred_scale': '',
#   'em': 0,
#   'f1': 0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 19.43,
#   'scale': 'percent',
#   'pred': [19.43],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 54510.33,
#   'scale': 'thousand',
#   'pred': [61584.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 49.4,
#   'scale': 'percent',
#   'pred': [49.4],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.48,
#   'scale': '',
#   'pred': [0.5],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.6000000000000001,
#   'scale': 'percent',
#   'pred': [0.6],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 15.6,
#   'scale': 'million',
#   'pred': [15.6],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 2.5,
#   'scale': 'million',
#   'pred': [2.5],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 12.67,
#   'scale': 'percent',
#   'pred': [12.67],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 36.9,
#   'scale': 'percent',
#   'pred': [100.0],
#   'pred_scale': 'percent',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 28.46,
#   'scale': 'percent',
#   'pred': [28.46],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 0.98,
#   'scale': 'percent',
#   'pred': [0.98],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 39224,
#   'scale': '',
#   'pred': [39224.0],
#   'pred_scale': '',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 20.81,
#   'scale': 'percent',
#   'pred': [20.81],
#   'pred_scale': 'percent',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': -0.2,
#   'scale': 'million',
#   'pred': [-0.2],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 37.35,
#   'scale': 'million',
#   'pred': [37.35],
#   'pred_scale': '',
#   'em': 0.0,
#   'f1': 0.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0},
#  {'answer_type': 'arithmetic',
#   'answer': 183.4,
#   'scale': 'million',
#   'pred': [183.4],
#   'pred_scale': 'million',
#   'em': 1.0,
#   'f1': 1.0,
#   'pred_span': None,
#   'gold_span': None,
#   'span_em': 0,
#   'span_f1': 0}]
